# %% [markdown]
# # Part 0 & 1

# %% [markdown]
# # Load dataset

# %%
from datasets import load_dataset

dataset = load_dataset('rotten_tomatoes')
train_dataset = dataset['train']
validation_dataset = dataset['validation']
test_dataset = dataset['test']

# %%
train_df = train_dataset.to_pandas()

# %%
# # Load augmented dataset
# import pandas as pd
# 
# train_df = pd.read_csv('augmented_combined_train_dataset.csv')

# %%
train_df.head()
# Out:
#                                                 text  label
# 0  the rock is destined to be the 21st century's ...      1
# 1  the gorgeously elaborate continuation of " the...      1
# 2                     effective but too-tepid biopic      1
# 3  if you sometimes like to go to the movies to h...      1
# 4  emerges as something rare , an issue movie tha...      1

# %% [markdown]
# # Create vocab from training dataset

# %%
import nltk


def build_vocab(train_dataset):
    # Create set, unique words only
    vocab = set()
    train_dataset_pos = []
    
    # Loop thru each sentence in training dataset
    for sentence in train_dataset['text']:
        # Basic text processing
        
        # Case folding
        sentence = sentence.lower()
        
        # NLTK tokenizer does a good job at separating meaningful words + punctuations
        # Better than defining regex ourselves
        word_list = nltk.tokenize.word_tokenize(sentence)
        
        # Further split words into separate words
        # e.g., 'well-being' -> 'well', 'being'
        # e.g., 'music/song' -> 'music', 'song'
        split_word_list = []
        for word in word_list:
            # If the word contains a hyphen or a slash, split it further
            if '-' in word or '/' in word:
                split_word_list.extend(word.replace('-', ' ').replace('/', ' ').split())
            else:
                split_word_list.append(word)
        
        # Dont remove all special characters, some are meaningful
        # Some words are surrounded by single/double quotes
        final_word_list = [word.strip("'\"") for word in split_word_list]
        
        # Add into set
        vocab.update(final_word_list)
        
        # Get pos tags
        # Also build POS tags
        pos_tags = nltk.pos_tag(final_word_list)
        train_dataset_pos.append(pos_tags)
        
    vocab.discard('')
    return vocab, train_dataset_pos

# %%
vocab, train_dataset_pos = build_vocab(train_df)

print(vocab)
# Out:
# {'determination', 'simple', 'taking', 'sooner', 'timeless', 'subtlety', 'sleepwalk', 'ostentatious', 'shtick', 'snow', 'with', 'sadistic', 'koury', 'haneke', 'rachel', 'loathe', 'harvests', 'whine', 'nap', 'simply', 'button', 'que', 'büttner', 'progression', 'enriches', 'bleakly', 'brosnan', 'sending', 'dodgy', 'alarms', 'conniving', 'deficiency', 'appears', 'image', 'breeziness', 'preoccupied', 'directed', 'underlay', 'midlife', 'indomitable', 'psychologizing', 'glitter', 'points', 'duck', 'induced', 'realistically', 'holiday', 'struggling', 'contain', 'tenderly', 'star', 'jeopardy', 'idiots', 'schaeffer', 'meyer', 'claw', 'goers', 'playful', 'triumph', 'accumulated', 'judgment', 'questions', 'shrieky', 'natives', 'saying', 'pulpy', 'estudo', "fun's", 'mum', 'glimmer', 'adroit', 'renders', 'pissed', 'glaring', 'thunderous', 'seizures', 'tragedies', 'details', 'hopping', 'quirkiness', 'ample', 'educates', 'spader', 'bush', 'just', 'tempt', 'thumbs', 'shocked', 'eisenberg', 'outrunning', 'sociopathy', 'gordy', 'machine', 'legendary', 'unfulfilling', 'wailing', 'willams', 'stole', 'pap', 'template', 'dope', 'harmon', 'extant', 'bohemian', 'fledgling', 'agendas', 'numbing', 'crystals', 'dollars', 'subsided', 'bling', 'graze', 'cardboard', 'objectionable', 's.', 'nicole', 'edit', 'soft', 'muted', 'winces', 'youthful', 'walks', 'orchestrates', 'horner', 'augustinian', 'glenn', 'undermine', 'donna', 'improvement', 'aburrido', 'ferocity', 'aggrandizement', 'meaningness', 'armageddon', 'momentary', 'opting', 'lillard', 'arrive', 'laziness', 'zeitgeist', 'killed', 'capitalism', 'interrupting', 'buffoonery', 'crawled', 'participant', 'decreases', 'weight', 'chamber', 'brockovich', 'beause', 'movement', 'patronizing', 'behaviour', 'accused', 'choking', 'shifting', 'softened', 'motions', 'remarks', 'evolução', 'stops', 'asked', 'poster', 'measures', 'harbor', 'stopped', 'audiard', 'roisterous', 'suburbs', 'responds', 'eastern', 'columns', 'sexploitation', 'remembered', 'heremakono', 'brine', 'studied', 'indigestion', 'chao', 'slowed', 'cool', 'overkill', 'blue', 'remain', 'ribisi', 'after', '8', 'astronaut', 'instilled', 'a.', 'shhh', 'duty', 'revisited', 'inducingly', 'intriguingly', 'fortify', 'comforting', 'miles', 'miami', 'dumbed', 'evolves', 'ellis', 'curmudgeon', 'portions', 'rowling', 'bravura', 'uncontrolled', 'sustained', 'pta', 'glee', 'entretenimiento', 'formalism', 'register', 'são', 'theatre', 'renounces', 'nicely', 'demonstrated', 'place', 'intermissions', 'toe', 'steinberg', 'besides', 'savvier', 'monologue', 'claptraps', 'hurley', 'gilligan', 'les', 'gone', 'answering', 'passage', 'deadline', 'relic', 'wishy', 'underappreciated', 'strides', 'ivans', 'magazine', 'paraphrase', 'permeate', 'basis', 'strength', 'rampantly', 'shambles', 'vaporize', 'upcoming', 'defied', 'carefree', 'baker', 'investigation', 'wet', 'gibney', 'explodes', 'listening', 'meager', 'clichéd', 'tonto', 'jumping', 'abusers', 'stability', 'businesses', 'demise', 'pervade', 'countercultural', 'growls', 'position', 'warner', 'popped', 'homicide', 'catchy', 'rhapsodic', 'encyclopedia', 'track', 'postapocalyptic', 'gargantuan', 'luminous', 'decree', 'catastrophe', 'giddily', 'cooler', 'tack', 'electric', 'unsettling', 'rendered', 'buddies', 'falling', 'delusional', 'presence', 'transport', 'subgenre', 'blend', 'feces', 'introduces', 'chance', 'amount', 'raimondi', 'recount', 'puree', 'tempered', 'elicit', 'oh', 'now', 'fudged', 'lay', 'prizes', 'splendor', 'coating', 'violent', 'stacy', 'gosford', 'red', 'discoveries', 'awards', 'protect', 'carlito', 'parka', 'humble', 'honor', 'use', 'whippersnappers', 'jarvis', 'gods', 'receiving', 'cure', 'entrée', 'xerox', 'acknowledging', 'imitations', 'virtuosity', 'responses', 'hit', 'bundy', 'pomo', 'curlers', 'agey', 'drunken', 'creaking', 'jive', 'zillionth', '[', 'disconnection', 'morals', 'eagerness', 'oft', 'mark', 'lying', 'rancorous', 'levar', 'sophistication', 'nevertheless', 'yoda', 'sunny', 'filmed', 'brok ...

# %%
print(train_dataset_pos[0])
# Out:
# [('the', 'DT'), ('rock', 'NN'), ('is', 'VBZ'), ('destined', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('21st', 'JJ'), ('century', 'NN'), ('s', 'VBD'), ('new', 'JJ'), ('``', '``'), ('conan', 'JJ'), ('``', '``'), ('and', 'CC'), ('that', 'IN'), ('he', 'PRP'), ('s', 'VBZ'), ('going', 'VBG'), ('to', 'TO'), ('make', 'VB'), ('a', 'DT'), ('splash', 'NN'), ('even', 'RB'), ('greater', 'JJR'), ('than', 'IN'), ('arnold', 'RB'), ('schwarzenegger', 'NN'), (',', ','), ('jean', 'JJ'), ('claud', 'NN'), ('van', 'NN'), ('damme', 'NN'), ('or', 'CC'), ('steven', 'JJ'), ('segal', 'NN'), ('.', '.')]

# %% [markdown]
# ## (a) What is the size of the vocabulary formed from your training data?

# %%
print(f'Vocab size/Unique words: {len(vocab)}')
# Out:
# Vocab size/Unique words: 17884

# %% [markdown]
# # Part 1: Preparing Word Embeddings

# %% [markdown]
# ## Download GloVe embeddings: https://nlp.stanford.edu/projects/glove/
# - Uncased means all words are lowercase

# %%
# Load GloVe embeddings
import numpy as np

def load_glove_embeddings(path):
    glove_embeddings = {}
    with open(path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype='float64')
            glove_embeddings[word] = vector
            
    return glove_embeddings

# %%
glove_embeddings = load_glove_embeddings('glove.6B.200d.txt')

# %%
print(f'Glove embedding matrix for "the":\n {glove_embeddings["the"]}')
# Out:
# Glove embedding matrix for "the":
#  [-7.1549e-02  9.3459e-02  2.3738e-02 -9.0339e-02  5.6123e-02  3.2547e-01
#  -3.9796e-01 -9.2139e-02  6.1181e-02 -1.8950e-01  1.3061e-01  1.4349e-01
#   1.1479e-02  3.8158e-01  5.4030e-01 -1.4088e-01  2.4315e-01  2.3036e-01
#  -5.5339e-01  4.8154e-02  4.5662e-01  3.2338e+00  2.0199e-02  4.9019e-02
#  -1.4132e-02  7.6017e-02 -1.1527e-01  2.0060e-01 -7.7657e-02  2.4328e-01
#   1.6368e-01 -3.4118e-01 -6.6070e-02  1.0152e-01  3.8232e-02 -1.7668e-01
#  -8.8153e-01 -3.3895e-01 -3.5481e-02 -5.5095e-01 -1.6899e-02 -4.3982e-01
#   3.9004e-02  4.0447e-01 -2.5880e-01  6.4594e-01  2.6641e-01  2.8009e-01
#  -2.4625e-02  6.3302e-01 -3.1700e-01  1.0271e-01  3.0886e-01  9.7792e-02
#  -3.8227e-01  8.6552e-02  4.7075e-02  2.3511e-01 -3.2127e-01 -2.8538e-01
#   1.6670e-01 -4.9707e-03 -6.2714e-01 -2.4904e-01  2.9713e-01  1.4379e-01
#  -1.2325e-01 -5.8178e-02 -1.0290e-03 -8.2126e-02  3.6935e-01 -5.8442e-04
#   3.4286e-01  2.8426e-01 -6.8599e-02  6.5747e-01 -2.9087e-02  1.6184e-01
#   7.3672e-02 -3.0343e-01  9.5733e-02 -5.2860e-01 -2.2898e-01  6.4079e-02
#   1.5218e-02  3.4921e-01 -4.3960e-01 -4.3983e-01  7.7515e-01 -8.7767e-01
#  -8.7504e-02  3.9598e-01  6.2362e-01 -2.6211e-01 -3.0539e-01 -2.2964e-02
#   3.0567e-01  6.7660e-02  1.5383e-01 -1.1211e-01 -9.1540e-02  8.2562e-02
#   1.6897e-01 -3.2952e-02 -2.8775e-01 -2.2320e-01 -9.0426e-02  1.2407e+00
#  -1.8244e-01 -7.5219e-03 -4.1388e-02 -1.1083e-02  7.8186e-02  3.8511e-01
#   2.3334e-01  1.4414e-01 -9.1070e-04 -2.6388e-01 -2.0481e-01  1.0099e-01
#   1.4076e-01  2.8834e-01 -4.5429e-02  3.7247e-01  1.3645e-01 -6.7457e-01
#   2.2786e-01  1.2599e-01  2.9091e-02  3.0428e-02 -1.3028e-01  1.9408e-01
#   4.9014e-01 -3.9121e-01 -7.5952e-02  7.4731e-02  1.8902e-01 -1.6922e-01
#  -2.6019e-01 -3.9771e-02 -2.4153e-01  1.0875e-01  3.0434e-01  3.6009e-02
#   1.4264e+00  1.2759e-01 -7.3811e-02 -2.0418e-01  8.0016e-03  1.5381e-01
#   2.0223e-01  2.8274e-01  9.6206e-02 -3.3634e-01  5.0983e-01  3.2625e-01
#  -2.6535e-01  3.7400e-01 -3.0388e-01 -4.0033e-01 -4.2910e-02 -6.7897e-02
#  -2.9332e-01  1.0978e-01 -4.5365e-02  2.3222e-01 -3.1134e-01 -2.8983e-01
#  -6.6687e-01  5.3097e-01  1.9461e-01  3.6670e-01  2.6185e-01 -6.5187e-01
#   1.0266e-01  1.1363e-01 -1.2953e-01 -6.8246e-01 -1.8751e-01  1.4760e-01
#   1.0765e+00 -2.2908e-01 -9.3435e-03 -2.0651e-01 -3.5225e-01 -2.6720e-01
#  -3.4307e-03  2.5906e-01  2.1759e-01  6.6158e-01  1.2180e-01  1.9957e-01
#  -2.0303e-01  3.4474e-01 -2.4328e-01  1.3139e-01 -8.8767e-03  3.3617e-01
#   3.0591e-02  2.5577e-01]

# %%
# Print size of the matrix
print(f'Number of unique words in embedding matrix: {len(glove_embeddings)}')

print(f'Number of Dimension/Features of Glove embedding matrix: {glove_embeddings["the"].shape[0]}')
# Out:
# Number of unique words in embedding matrix: 400000
# Number of Dimension/Features of Glove embedding matrix: 200

# %% [markdown]
# ## Create embedding matrix

# %%
# Finalize vocab
vocab_word_to_index = {word: idx for idx, word in enumerate(vocab)}

# %%
vocab_word_to_index
# Out:
# {'determination': 0,
#  'simple': 1,
#  'taking': 2,
#  'sooner': 3,
#  'timeless': 4,
#  'subtlety': 5,
#  'sleepwalk': 6,
#  'ostentatious': 7,
#  'shtick': 8,
#  'snow': 9,
#  'with': 10,
#  'sadistic': 11,
#  'koury': 12,
#  'haneke': 13,
#  'rachel': 14,
#  'loathe': 15,
#  'harvests': 16,
#  'whine': 17,
#  'nap': 18,
#  'simply': 19,
#  'button': 20,
#  'que': 21,
#  'büttner': 22,
#  'progression': 23,
#  'enriches': 24,
#  'bleakly': 25,
#  'brosnan': 26,
#  'sending': 27,
#  'dodgy': 28,
#  'alarms': 29,
#  'conniving': 30,
#  'deficiency': 31,
#  'appears': 32,
#  'image': 33,
#  'breeziness': 34,
#  'preoccupied': 35,
#  'directed': 36,
#  'underlay': 37,
#  'midlife': 38,
#  'indomitable': 39,
#  'psychologizing': 40,
#  'glitter': 41,
#  'points': 42,
#  'duck': 43,
#  'induced': 44,
#  'realistically': 45,
#  'holiday': 46,
#  'struggling': 47,
#  'contain': 48,
#  'tenderly': 49,
#  'star': 50,
#  'jeopardy': 51,
#  'idiots': 52,
#  'schaeffer': 53,
#  'meyer': 54,
#  'claw': 55,
#  'goers': 56,
#  'playful': 57,
#  'triumph': 58,
#  'accumulated': 59,
#  'judgment': 60,
#  'questions': 61,
#  'shrieky': 62,
#  'natives': 63,
#  'saying': 64,
#  'pulpy': 65,
#  'estudo': 66,
#  "fun's": 67,
#  'mum': 68,
#  'glimmer': 69,
#  'adroit': 70,
#  'renders': 71,
#  'pissed': 72,
#  'glaring': 73,
#  'thunderous': 74,
#  'seizures': 75,
#  'tragedies': 76,
#  'details': 77,
#  'hopping': 78,
#  'quirkiness': 79,
#  'ample': 80,
#  'educates': 81,
#  'spader': 82,
#  'bush': 83,
#  'just': 84,
#  'tempt': 85,
#  'thumbs': 86,
#  'shocked': 87,
#  'eisenberg': 88,
#  'outrunning': 89,
#  'sociopathy': 90,
#  'gordy': 91,
#  'machine': 92,
#  'legendary': 93,
#  'unfulfilling': 94,
#  'wailing': 95,
#  'willams': 96,
#  'stole': 97,
#  'pap': 98,
#  'template': 99,
#  'dope': 100,
#  'harmon': 101,
#  'extant': 102,
#  'bohemian': 103,
#  'fledgling': 104,
#  'agendas': 105,
#  'numbing': 106,
#  'crystals': 107,
#  'dollars': 108,
#  'subsided': 109,
#  'bling': 110,
#  'graze': 111,
#  'cardboard': 112,
#  'objectionable': 113,
#  's.': 114,
#  'nicole': 115,
#  'edit': 116,
#  'soft': 117,
#  'muted': 118,
#  'winces': 119,
#  'youthful': 120,
#  'walks': 121,
#  'orchestrates': 122,
#  'horner': 123,
#  'augustinian': 124,
#  'glenn': 125,
#  'undermine': 126,
#  'donna': 127,
#  'improvement': 128,
#  'aburrido': 129,
#  'ferocity': 130,
#  'aggrandizement': 131,
#  'meaningness': 132,
#  'armageddon': 133,
#  'momentary': 134,
#  'opting': 135,
#  'lillard': 136,
#  'arrive': 137,
#  'laziness': 138,
#  'zeitgeist': 139,
#  'killed': 140,
#  'capitalism': 141,
#  'interrupting': 142,
#  'buffoonery': 143,
#  'crawled': 144,
#  'participant': 145,
#  'decreases': 146,
#  'weight': 147,
#  'chamber': 148,
#  'brockovich': 149,
#  'beause': 150,
#  'movement': 151,
#  'patronizing': 152,
#  'behaviour': 153,
#  'accused': 154,
#  'choking': 155,
#  'shifting': 156,
#  'softened': 157,
#  'motions': 158,
#  'remarks': 159,
#  'evolução': 160,
#  'stops': 161,
#  'asked': 162,
#  'poster': 163,
#  'measures': 164,
#  'harbor': 165,
#  'stopped': 166,
#  'audiard': 167,
#  'roisterous': 168,
#  'suburbs': 169,
#  'responds': 170,
#  'eastern': 171,
#  'columns': 172,
#  'sexploitation': 173,
#  'remembered': 174,
#  'heremakono': 175,
#  'brine': 176,
#  'studied': 177,
#  'indigestion': 178,
#  'chao': 179,
#  'slowed': 180,
#  'cool': 181,
#  'overkill': 182,
#  'blue': 183,
#  'remain': 184,
#  'ribisi': 185,
#  'after': 186,
#  '8': 187,
#  'astronaut': 188,
#  'instilled': 189,
#  'a.': 190,
#  'shhh': 191,
#  'duty': 192,
#  'revisited': 193,
#  'inducingly': 194,
#  'intriguingly': 195,
#  'fortify': 196,
#  'comforting': 197,
#  'miles': 198,
#  'miami': 199,
#  'dumbed': 200,
#  'evolves': 201,
#  'ellis': 202,
#  'curmudgeon': 203,
#  'portions': 204,
#  'rowling': 205,
#  'bravura': 206,
#  'uncontrolled': 207,
#  'sustained': 208,
#  'pta': 209,
#  'glee': 210,
#  'entretenimiento': 211,
#  'formalism': 212,
#  'register': 213,
#  'são': 214,
#  'theatre': 215,
#  'renounces': 216,
#  'nicely': 217,
#  'demonstrated': 218,
#  'place': 219,
#  'intermissions': 220,
#  'toe': 221,
#  'steinberg': 222,
#  'besides': 223,
#  'savvier': 224,
#  'monologue': 225,
#  'claptraps': 226,
#  'hurley': 227,
#  'gilligan': 228,
#  'les': 229,
#  'gone': 230,
#  'answering': 231,
#  'passage': 232,
#  'deadline': 233,
#  'relic': 234,
#  'wishy': 235,
#  'underappreciated': 236,
#  'strides': 237,
#  'ivans': 238,
#  'magazine': 239,
#  'paraphrase': 240,
#  'permeate': 241,
#  'basis': 242,
#  'strength': 243,
#  'rampantly': 244,
#  'shambles': 245,
#  'vaporize': 246,
#  'upcoming': 247,
#  'defied': 248,
#  'carefree': 249,
#  'baker': 250,
#  'investigation': 251,
#  'wet': 252,
#  'gibney': 253,
#  'explodes': 254,
#  'listening': 255,
#  'meager': 256,
#  'clichéd': 257,
#  'tonto': 258,
#  'jumping': 259,
#  'abusers': 260,
#  'stability': 261,
#  'businesses': 262,
#  'demise': 263,
#  'pervade': 264,
#  'countercultural': 265,
#  'growls': 266,
#  'position': 267,
#  'warner': 268,
#  'popped': 269,
#  'homicide': 270,
#  'catchy': 271,
#  'rhapsodic': 272,
#  'encyclopedia': 273,
#  'track': 274,
#  'postapocalyptic': 275,
#  'gargantuan': 276,
#  'luminous': 277,
#  'decree': 278,
#  'catastrophe': 279,
#  'giddily': 280,
#  'cooler': 281,
#  'tack': 282,
#  'electric': 283,
#  'unsettling': 284,
#  'rendered': 285,
#  'buddies': 286,
#  'falling': 287,
#  'delusional': 288,
#  'presence': 289,
#  'transport': 290,
#  'subgenre': 291,
#  'blend': 292,
#  'feces': 293,
#  'introduces': 294,
#  'chance': 295,
#  'amount': 296,
#  'raimondi': 297,
#  'recount': 298,
#  'puree': 299,
#  'tempered': 300,
#  'elicit': 301,
#  'oh': 302,
#  'now': 303,
#  'fudged': 304,
#  'lay': 305,
#  'prizes': 306,
#  'splendor': 307,
#  'coating': 308,
#  'violent': 309,
#  'stacy': 310,
#  'gosford': 311,
#  'red': 312,
#  'discoveries': 313,
#  'awards': 314,
#  'protect': 315,
#  'carlito': 316,
#  'parka': 317,
#  'humble': 318,
#  'honor': 319,
#  'use': 320,
#  'whippersnappers': 321,
#  'jarvis': 322,
#  'gods': 323,
#  'receiving': 324,
#  'cure': 325,
#  'entrée': 326,
#  'xerox': 327,
#  'acknowledging': 328,
#  'imitations': 329,
#  'virtuosity': 330,
#  'responses': 331,
#  'hit': 332,
#  'bundy': 333,
#  'pomo': 334,
#  'curlers': 335,
#  'agey': 336,
#  'drunken': 337,
#  'creaking': 338,
#  'jive': 339,
#  'zillionth': 340,
#  '[': 341,
#  'disconnection': 342,
#  'morals': 343,
#  'eagerness': 344,
#  'oft': 345,
#  'mark': 346,
#  'lying': 347,
#  'rancorous': 348,
#  'levar': 349,
#  'sophistication': 350,
#  'nevertheless': 351,
#  'yoda': 352,
#  'sunny': 353,
#  'filmed': 354,
#  'broken': 355,
#  'definitive': 356,
#  'pé': 357,
#  'exaggerating': 358,
#  'axel': 359,
#  'species': 360,
#  'kang': 361,
#  'filmmaking': 362,
#  'guilt': 363,
#  'snooze': 364,
#  'mcklusky': 365,
#  'suffocated': 366,
#  'graphic': 367,
#  'idiocy': 368,
#  'thud': 369,
#  'cinematographic': 370,
#  'château': 371,
#  'beer': 372,
#  'ex': 373,
#  'stuttering': 374,
#  'irresponsible': 375,
#  'crosses': 376,
#  'cell': 377,
#  'displaying': 378,
#  'productions': 379,
#  'nightclub': 380,
#  'reasonable': 381,
#  'bashing': 382,
#  'kingdom': 383,
#  'herd': 384,
#  'alongside': 385,
#  'assayas': 386,
#  'hard': 387,
#  'seaworthy': 388,
#  'scenario': 389,
#  'bizzarre': 390,
#  'awaits': 391,
#  'lord': 392,
#  'weariness': 393,
#  'witted': 394,
#  'organize': 395,
#  'dared': 396,
#  'leonard': 397,
#  'seems': 398,
#  'grotesque': 399,
#  'unqualified': 400,
#  'hell': 401,
#  'transporting': 402,
#  'mawkishness': 403,
#  'daydreams': 404,
#  'desert': 405,
#  'liza': 406,
#  'rushed': 407,
#  'drained': 408,
#  'degrades': 409,
#  'avarice': 410,
#  'liberating': 411,
#  'tune': 412,
#  'brotherly': 413,
#  'endlessly': 414,
#  'fine': 415,
#  'spaces': 416,
#  'landing': 417,
#  'dangers': 418,
#  'afterlife': 419,
#  'reinforces': 420,
#  'trope': 421,
#  'tackle': 422,
#  'represented': 423,
#  'pranks': 424,
#  'anomaly': 425,
#  'rubin': 426,
#  'navajos': 427,
#  'colleague': 428,
#  'halos': 429,
#  'hoops': 430,
#  'loitering': 431,
#  'cried': 432,
#  'puns': 433,
#  'bryan': 434,
#  'trauma': 435,
#  'gasm': 436,
#  'growling': 437,
#  'sucker': 438,
#  'zone': 439,
#  '\x91what': 440,
#  'somnambulant': 441,
#  'indistinct': 442,
#  'laudable': 443,
#  'messy': 444,
#  'distraction': 445,
#  'sank': 446,
#  'fundamentally': 447,
#  'mush': 448,
#  'pungent': 449,
#  'conforms': 450,
#  'earnestness': 451,
#  'ambitious': 452,
#  'revered': 453,
#  'snipe': 454,
#  'chewy': 455,
#  'paying': 456,
#  'multi': 457,
#  'scams': 458,
#  'conspirators': 459,
#  'objects': 460,
#  'memories': 461,
#  'chart': 462,
#  'wears': 463,
#  'sentimental': 464,
#  'transcend': 465,
#  'deeply': 466,
#  'revisionist': 467,
#  'monopoly': 468,
#  'shabby': 469,
#  'pabst': 470,
#  'hardhearted': 471,
#  'banter': 472,
#  'rein': 473,
#  'buzz': 474,
#  'speed': 475,
#  'qualify': 476,
#  'wisely': 477,
#  'program': 478,
#  'pretension': 479,
#  'once': 480,
#  'papai': 481,
#  'sharpie': 482,
#  'pogue': 483,
#  'achingly': 484,
#  'wooden': 485,
#  'butchered': 486,
#  'playground': 487,
#  'heartless': 488,
#  'eagles': 489,
#  'imbued': 490,
#  'recalls': 491,
#  'incurably': 492,
#  'spoiler': 493,
#  'overexposed': 494,
#  'here': 495,
#  'unmemorable': 496,
#  'sight': 497,
#  'joie': 498,
#  'cabeza': 499,
#  'último': 500,
#  'cannibal': 501,
#  'preemptive': 502,
#  'processor': 503,
#  'kissing': 504,
#  'sprouts': 505,
#  'clima': 506,
#  'cahill': 507,
#  'mythic': 508,
#  'indians': 509,
#  'irrational': 510,
#  'clears': 511,
#  'holy': 512,
#  'première': 513,
#  'sophomoronic': 514,
#  'heels': 515,
#  'erects': 516,
#  'hogan': 517,
#  'blandly': 518,
#  'please': 519,
#  'shooting': 520,
#  'brian': 521,
#  'clint': 522,
#  'listless': 523,
#  'cria': 524,
#  'barely': 525,
#  'commitment': 526,
#  'recreation': 527,
#  'lookin': 528,
#  'rebellious': 529,
#  'publicists': 530,
#  'jammies': 531,
#  'stereotyped': 532,
#  'biased': 533,
#  'perceptiveness': 534,
#  'inspiration': 535,
#  'newness': 536,
#  'pushes': 537,
#  'espectacular': 538,
#  'conformity': 539,
#  'minus': 540,
#  'squashed': 541,
#  'afterschool': 542,
#  'bazadona': 543,
#  'girlfriend': 544,
#  'clunkiness': 545,
#  'soar': 546,
#  'humiliated': 547,
#  'bare': 548,
#  'flames': 549,
#  'annoyed': 550,
#  'recoil': 551,
#  'reworked': 552,
#  'enviará': 553,
#  'taut': 554,
#  'preamble': 555,
#  'yearnings': 556,
#  'watch': 557,
#  'sampling': 558,
#  'licking': 559,
#  'intently': 560,
#  'respond': 561,
#  'grotesquely': 562,
#  'wilts': 563,
#  'great': 564,
#  'nigh': 565,
#  'acknowledges': 566,
#  'vital': 567,
#  'noblest': 568,
#  'refined': 569,
#  'incident': 570,
#  'luscious': 571,
#  'tug': 572,
#  'vivre': 573,
#  'winged': 574,
#  'tranquility': 575,
#  'insecurity': 576,
#  'instant': 577,
#  'slaughtered': 578,
#  'freshened': 579,
#  'loosens': 580,
#  'landbound': 581,
#  'identity': 582,
#  'building': 583,
#  'videos': 584,
#  'feet': 585,
#  'roars': 586,
#  'sound': 587,
#  'host': 588,
#  'soured': 589,
#  'arriving': 590,
#  'revived': 591,
#  'pressed': 592,
#  'severe': 593,
#  'beaten': 594,
#  'operate': 595,
#  'existence': 596,
#  'appeals': 597,
#  'travail': 598,
#  'sparring': 599,
#  'splashed': 600,
#  'manipulador': 601,
#  'humourless': 602,
#  'insecure': 603,
#  'northwest': 604,
#  'pr': 605,
#  'majority': 606,
#  'wistful': 607,
#  'carrier': 608,
#  'uninhibited': 609,
#  'idolized': 610,
#  'challenging': 611,
#  'alcatraz': 612,
#  'screed': 613,
#  'competent': 614,
#  'splits': 615,
#  'neck': 616,
#  'minor': 617,
#  'budget': 618,
#  'slapped': 619,
#  'scary': 620,
#  'pegs': 621,
#  'affectation': 622,
#  'end': 623,
#  'peas': 624,
#  'be': 625,
#  'unflaggingly': 626,
#  'advised': 627,
#  'wending': 628,
#  'fest': 629,
#  'only': 630,
#  'gleefully': 631,
#  'scooby': 632,
#  'ride': 633,
#  'typical': 634,
#  'enthusiastic': 635,
#  'saturation': 636,
#  'admirer': 637,
#  'different': 638,
#  'actor': 639,
#  'cheeked': 640,
#  'undiminished': 641,
#  'screen': 642,
#  'stained': 643,
#  'semitism': 644,
#  'continued': 645,
#  'possui': 646,
#  'bleak': 647,
#  'odoriferous': 648,
#  'croatia': 649,
#  'bawdy': 650,
#  'fanged': 651,
#  'literary': 652,
#  'han': 653,
#  'overtones': 654,
#  'delhomme': 655,
#  'development': 656,
#  'imagination': 657,
#  'darwinian': 658,
#  'beings': 659,
#  'misfires': 660,
#  'short': 661,
#  'biting': 662,
#  'inauspicious': 663,
#  'rewrite': 664,
#  'blind': 665,
#  'sailor': 666,
#  'salute': 667,
#  'solemn': 668,
#  'possible': 669,
#  'flatter': 670,
#  'madman': 671,
#  'eaters': 672,
#  'joshua': 673,
#  'condensation': 674,
#  'panther': 675,
#  'esoteric': 676,
#  'strenuously': 677,
#  'reinforce': 678,
#  'discomfort': 679,
#  'mejores': 680,
#  'reveal': 681,
#  'tolkien': 682,
#  'passably': 683,
#  'harlem': 684,
#  'brit': 685,
#  'abel': 686,
#  'needs': 687,
#  'spare': 688,
#  'loop': 689,
#  'improvisation': 690,
#  'backwater': 691,
#  'fairness': 692,
#  'ensnared': 693,
#  'straightforward': 694,
#  'manhattan': 695,
#  'comprise': 696,
#  'suicidal': 697,
#  'establishes': 698,
#  'barry': 699,
#  'graduation': 700,
#  'exit': 701,
#  'impressed': 702,
#  'slob': 703,
#  'paris': 704,
#  'leftover': 705,
#  'egotistical': 706,
#  'neverland': 707,
#  'griping': 708,
#  'israel': 709,
#  'parking': 710,
#  'railed': 711,
#  'começamos': 712,
#  'nair': 713,
#  'attachment': 714,
#  'uproarious': 715,
#  'april': 716,
#  'detainees': 717,
#  'motivations': 718,
#  'betty': 719,
#  'trippy': 720,
#  'spiced': 721,
#  'dragged': 722,
#  'hemmingway': 723,
#  'pure': 724,
#  'ripping': 725,
#  'bearded': 726,
#  'failed': 727,
#  'grandfather': 728,
#  'capturing': 729,
#  'vida': 730,
#  'industrial': 731,
#  'dragonfly': 732,
#  'csoka': 733,
#  'repairing': 734,
#  'provokes': 735,
#  'cracker': 736,
#  'b': 737,
#  'filter': 738,
#  'pena': 739,
#  'weighed': 740,
#  'murdered': 741,
#  'sillyly': 742,
#  'plating': 743,
#  'pearce': 744,
#  'ills': 745,
#  'stubbornness': 746,
#  'spend': 747,
#  'climbing': 748,
#  'influential': 749,
#  'mess': 750,
#  'overview': 751,
#  'effect': 752,
#  'urine': 753,
#  'suppressing': 754,
#  'linking': 755,
#  'ten': 756,
#  'enfrentados': 757,
#  'curiously': 758,
#  'laptops': 759,
#  'theorizing': 760,
#  'heed': 761,
#  'trapped': 762,
#  'collect': 763,
#  'paradiso': 764,
#  'goths': 765,
#  'grows': 766,
#  'slow': 767,
#  'grizzled': 768,
#  'immune': 769,
#  'unsentimental': 770,
#  'statham': 771,
#  'hustler': 772,
#  'mucking': 773,
#  'newcomer': 774,
#  'episodes': 775,
#  'criterion': 776,
#  'cruise': 777,
#  'rez': 778,
#  'cynic': 779,
#  'downtown': 780,
#  'confounding': 781,
#  'savored': 782,
#  'solaris': 783,
#  'sorts': 784,
#  'welcomes': 785,
#  'prompting': 786,
#  'smelly': 787,
#  'cartoons': 788,
#  'morris': 789,
#  'snapshots': 790,
#  'commonly': 791,
#  'melds': 792,
#  'lobbyists': 793,
#  'freshly': 794,
#  'sloppily': 795,
#  'longley': 796,
#  'tragedy': 797,
#  'runaway': 798,
#  'creepyness': 799,
#  'placement': 800,
#  'lawn': 801,
#  'stand': 802,
#  'winds': 803,
#  'luminary': 804,
#  'whence': 805,
#  'beatrice': 806,
#  'candidly': 807,
#  'invite': 808,
#  'northern': 809,
#  'underlying': 810,
#  'pesky': 811,
#  'pairing': 812,
#  'título': 813,
#  'john': 814,
#  'partially': 815,
#  'frei': 816,
#  'aliens': 817,
#  'sectarian': 818,
#  'gaping': 819,
#  'marketable': 820,
#  'too': 821,
#  'femininity': 822,
#  'pumpkin': 823,
#  'flies': 824,
#  'unlikely': 825,
#  'reminds': 826,
#  'criticizing': 827,
#  'fashionedness': 828,
#  'newfangled': 829,
#  'separate': 830,
#  'learnt': 831,
#  'preceded': 832,
#  'insults': 833,
#  'uninspiring': 834,
#  'sneaks': 835,
#  'exotic': 836,
#  'dizzy': 837,
#  'blithe': 838,
#  'worshipful': 839,
#  'leaps': 840,
#  'hormonal': 841,
#  'movilizador': 842,
#  'matron': 843,
#  'forgive': 844,
#  'singers': 845,
#  'nervous': 846,
#  'way': 847,
#  'glitches': 848,
#  'clenching': 849,
#  'our': 850,
#  'clothes': 851,
#  'figurative': 852,
#  'murdock': 853,
#  'addessi': 854,
#  'illegal': 855,
#  'freud': 856,
#  'overhead': 857,
#  'fatalist': 858,
#  'athleticism': 859,
#  'wither': 860,
#  'philadelphia': 861,
#  'grouper': 862,
#  'magnifique': 863,
#  'amiably': 864,
#  'strays': 865,
#  'lofty': 866,
#  'shots': 867,
#  'tracks': 868,
#  'rings': 869,
#  'rootlessness': 870,
#  'heartrending': 871,
#  'portraying': 872,
#  'shoulders': 873,
#  'heaviness': 874,
#  'compensates': 875,
#  'dysfunctional': 876,
#  'victories': 877,
#  'groaner': 878,
#  'granting': 879,
#  'indeed': 880,
#  'dyspeptic': 881,
#  '11': 882,
#  'fato': 883,
#  'creepiest': 884,
#  'pornographic': 885,
#  'stern': 886,
#  'baboon': 887,
#  'turgid': 888,
#  'marching': 889,
#  'thomas': 890,
#  'schiffer': 891,
#  'comedia': 892,
#  'unnatural': 893,
#  'impatience': 894,
#  'brilliant': 895,
#  'shot': 896,
#  'bombardment': 897,
#  'hundreds': 898,
#  'impertinent': 899,
#  'immediately': 900,
#  'sly': 901,
#  'sublime': 902,
#  'strike': 903,
#  'excessive': 904,
#  'regular': 905,
#  'snide': 906,
#  'combines': 907,
#  'reaffirming': 908,
#  'austrian': 909,
#  'bondish': 910,
#  'gere': 911,
#  'stone': 912,
#  'interviewed': 913,
#  'core': 914,
#  'rattled': 915,
#  'perseverance': 916,
#  'dollar': 917,
#  'shocker': 918,
#  'cargo': 919,
#  'mother': 920,
#  'saves': 921,
#  'marker': 922,
#  'calming': 923,
#  'brett': 924,
#  'dysfunction': 925,
#  'bravado': 926,
#  'examination': 927,
#  'embark': 928,
#  'wetsuit': 929,
#  'beijing': 930,
#  'terribly': 931,
#  'doing': 932,
#  'provide': 933,
#  'horns': 934,
#  'intelligent': 935,
#  'penchant': 936,
#  'nohe': 937,
#  'elemento': 938,
#  'available': 939,
#  'jumpsuit': 940,
#  'bustingly': 941,
#  'keel': 942,
#  'hardest': 943,
#  'heroism': 944,
#  'combined': 945,
#  'dicey': 946,
#  'buyer': 947,
#  'ears': 948,
#  'charges': 949,
#  'robinson': 950,
#  'merit': 951,
#  'deposits': 952,
#  'seriousness': 953,
#  'cynics': 954,
#  'tiger': 955,
#  'fencing': 956,
#  'fondly': 957,
#  'dismember': 958,
#  'ranging': 959,
#  'mixtures': 960,
#  'priceless': 961,
#  'verisimilitude': 962,
#  'injuries': 963,
#  'dolorous': 964,
#  'decaying': 965,
#  'reverence': 966,
#  'arliss': 967,
#  'crypt': 968,
#  'mattered': 969,
#  'flattery': 970,
#  'tok': 971,
#  'every': 972,
#  'based': 973,
#  'simplified': 974,
#  'bumps': 975,
#  'geriatric': 976,
#  'stalk': 977,
#  'halloween': 978,
#  'starred': 979,
#  'earthbound': 980,
#  'was': 981,
#  'legs': 982,
#  'faultlessly': 983,
#  'nerds': 984,
#  'rehearsal': 985,
#  'preordained': 986,
#  'u.': 987,
#  'stylishly': 988,
#  'laissez': 989,
#  'twist': 990,
#  'trash': 991,
#  'franz': 992,
#  'terrors': 993,
#  'busby': 994,
#  'sommers': 995,
#  'fighters': 996,
#  'passed': 997,
#  'sus': 998,
#  'yuck': 999,
#  ...}

# %%
def create_embedding_matrix(word_to_index, glove_embeddings):
    # Initialize embedding matrix with zeros
    # 50d
    embedding_matrix = np.zeros((len(vocab), 200), dtype='float64')
    
    # Loop thru each word in vocab
    for word, idx in word_to_index.items():
        # Check if word exists in glove embeddings
        if word in glove_embeddings:
            # Copy glove embedding to embedding matrix
            embedding_matrix[idx] = glove_embeddings[word]
            # If OOV, assign None first
            
    return embedding_matrix

# %%
embedding_matrix = create_embedding_matrix(vocab_word_to_index, glove_embeddings)

# %%
embedding_matrix
# Out:
# array([[ 0.25093  ,  0.83451  ,  0.25677  , ...,  0.31425  , -0.24449  ,
#         -0.0023992],
#        [ 0.57959  ,  0.14576  ,  0.32607  , ...,  0.050995 , -0.24176  ,
#         -0.1596   ],
#        [-0.049447 ,  0.14972  , -0.2371   , ..., -0.11361  ,  0.048788 ,
#         -0.19525  ],
#        ...,
#        [ 0.51337  , -0.081174 ,  0.044873 , ...,  0.25791  ,  0.15017  ,
#          0.27543  ],
#        [ 0.92436  , -0.15478  , -0.49867  , ..., -0.067343 ,  0.44588  ,
#          0.060262 ],
#        [-0.38574  ,  0.77289  , -0.22022  , ..., -0.5598   ,  0.23399  ,
#          0.16738  ]])

# %% [markdown]
# ## (b) We use OOV (out-of-vocabulary) to refer to those words appeared in the training data but not in the Word2vec (or Glove) dictionary. How many OOV words exist in your training data?

# %%
def get_oov_words(embedding_matrix, vocab_word_to_index):
    oov_words = []
    
    for word, idx in vocab_word_to_index.items():
        # Check if zero matrix
        if np.sum(embedding_matrix[idx]) == 0:
            oov_words.append(word)

    return oov_words

# %%
oov_words = get_oov_words(embedding_matrix, vocab_word_to_index)

# %%
oov_words.sort()
oov_words[:200]
# Out:
# ['1899.',
#  '1952.',
#  '1975.',
#  '1995.',
#  '2002.',
#  '28k',
#  '5ths',
#  '8217',
#  'abandone',
#  'aborbing',
#  'absolutamente',
#  'aburrido',
#  'acabamos',
#  'accomodates',
#  'aceitou',
#  'achival',
#  'achronological',
#  'acidically',
#  'acontecimentos',
#  'actorious',
#  'actorish',
#  'actory',
#  'actuación',
#  'actuada',
#  'addessi',
#  'adorability',
#  'adventues',
#  'affirmational',
#  "ain't",
#  'alientation',
#  'allodi',
#  'amoses',
#  'amusedly',
#  'andamento',
#  'animé',
#  'anteing',
#  'apallingly',
#  'apesar',
#  'aproveitar',
#  'aqueles',
#  "aren't",
#  'arriesgado',
#  'artnering',
#  'artsploitation',
#  'artístico',
#  'assistir',
#  'atacar',
#  'atacarse',
#  'atreve',
#  'auteil',
#  'autocritique',
#  'awakener',
#  'b+',
#  'bazadona',
#  'bergmanesque',
#  'beseechingly',
#  'bibbidy',
#  'bierbichler',
#  'birot',
#  'bizzarre',
#  'bjorkness',
#  'blighter',
#  'blutarsky',
#  'bobbidi',
#  'bondish',
#  'bornin',
#  'bottomlessly',
#  'bruckheimeresque',
#  'brûlée',
#  "bull's",
#  'burningly',
#  'bustingly',
#  'butterfingered',
#  'cadness',
#  "cam'ron",
#  'camareras',
#  'cannier',
#  'captivatingly',
#  'capturou',
#  'carefreeness',
#  'carente',
#  'caricatural',
#  'cativante',
#  'certamente',
#  'chabrolian',
#  'chopsocky',
#  'choquart',
#  'cineasts',
#  'cinemantic',
#  'ciphered',
#  'cipherlike',
#  'cirulnick',
#  'claptraps',
#  'claustrophic',
#  'clericks',
#  'cletis',
#  'clichês',
#  'clutchy',
#  'collinswood',
#  'collosum',
#  'colocar',
#  'colonics',
#  'colosal',
#  'começamos',
#  'compleja',
#  'complejos',
#  'complementares',
#  'condensada',
#  'confusedred',
#  'conmovedora',
#  'consegue',
#  'constatação',
#  'contando',
#  'contemplarse',
#  'continuação',
#  'contructed',
#  'contrária',
#  'convencional',
#  'copmovieland',
#  'coriat',
#  'corniest',
#  'corpse—stays',
#  'corruscating',
#  'costumey',
#  'covardia',
#  'crappola',
#  'creepyness',
#  'criar',
#  'crowdpleaser',
#  'crummles',
#  'csoka',
#  'culminando',
#  'daneses',
#  'datedness',
#  'dateflick',
#  'deadeningly',
#  'debuter',
#  'decasia',
#  'decidiram',
#  'decirles',
#  'defeatingly',
#  'delibrately',
#  'delicia',
#  'demencial',
#  'democracie',
#  'denlopp',
#  'derivativeness',
#  'desaponta',
#  'desarrollarse',
#  'desee',
#  'deseos',
#  'desfecho',
#  'desnudo',
#  'destinees',
#  'deutchland',
#  'diciness',
#  'diferença',
#  'digno',
#  'direto',
#  'diretor',
#  'direção',
#  'disfrutable',
#  'disposible',
#  'divertida',
#  'divertingly',
#  'djeinaba',
#  'document—its',
#  'does—but',
#  'dogwalker',
#  'dominatrixes',
#  "don't",
#  'dooper',
#  'dramatisms',
#  'dreadfulness',
#  'drecks',
#  'drek',
#  'dridi',
#  'drippiness',
#  'dudds',
#  'dudsville',
#  'dullingly',
#  'dumbfoundingly',
#  'duración',
#  'dysfunctionally',
#  'dès',
#  'efteriades',
#  'elegiacally',
#  'elemento',
#  'emocionalmente',
#  'emocionante',
#  'emotiva',
#  'emptily',
#  'enamoring',
#  'enfrentados',
#  'enfrentará',
#  'engaña',
#  'enrapturing',
#  'enternecedora',
#  'entretenida',
#  'entreter']

# %%
print(f"Number of OOV words: {len(oov_words)}")
# Out:
# Number of OOV words: 678

# %%
train_dataset_pos
# Out:
# [[('the', 'DT'),
#   ('rock', 'NN'),
#   ('is', 'VBZ'),
#   ('destined', 'VBN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('the', 'DT'),
#   ('21st', 'JJ'),
#   ('century', 'NN'),
#   ('s', 'VBD'),
#   ('new', 'JJ'),
#   ('``', '``'),
#   ('conan', 'JJ'),
#   ('``', '``'),
#   ('and', 'CC'),
#   ('that', 'IN'),
#   ('he', 'PRP'),
#   ('s', 'VBZ'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('a', 'DT'),
#   ('splash', 'NN'),
#   ('even', 'RB'),
#   ('greater', 'JJR'),
#   ('than', 'IN'),
#   ('arnold', 'RB'),
#   ('schwarzenegger', 'NN'),
#   (',', ','),
#   ('jean', 'JJ'),
#   ('claud', 'NN'),
#   ('van', 'NN'),
#   ('damme', 'NN'),
#   ('or', 'CC'),
#   ('steven', 'JJ'),
#   ('segal', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('gorgeously', 'RB'),
#   ('elaborate', 'JJ'),
#   ('continuation', 'NN'),
#   ('of', 'IN'),
#   ('``', '``'),
#   ('the', 'DT'),
#   ('lord', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('rings', 'NNS'),
#   ('``', '``'),
#   ('trilogy', 'NN'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('huge', 'JJ'),
#   ('that', 'IN'),
#   ('a', 'DT'),
#   ('column', 'NN'),
#   ('of', 'IN'),
#   ('words', 'NNS'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('adequately', 'RB'),
#   ('describe', 'VB'),
#   ('co', 'JJ'),
#   ('writer', 'NN'),
#   ('director', 'NN'),
#   ('peter', 'NN'),
#   ('jackson', 'NN'),
#   ('s', 'NN'),
#   ('expanded', 'VBD'),
#   ('vision', 'NN'),
#   ('of', 'IN'),
#   ('j', 'NN'),
#   ('.', '.'),
#   ('r', 'NN'),
#   ('.', '.'),
#   ('r', 'NN'),
#   ('.', '.'),
#   ('tolkien', 'NN'),
#   ('s', 'NN'),
#   ('middle', 'JJ'),
#   ('earth', 'NN'),
#   ('.', '.')],
#  [('effective', 'JJ'),
#   ('but', 'CC'),
#   ('too', 'RB'),
#   ('tepid', 'JJ'),
#   ('biopic', 'NN')],
#  [('if', 'IN'),
#   ('you', 'PRP'),
#   ('sometimes', 'VBP'),
#   ('like', 'IN'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('movies', 'NNS'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('fun', 'NN'),
#   (',', ','),
#   ('wasabi', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('place', 'NN'),
#   ('to', 'TO'),
#   ('start', 'VB'),
#   ('.', '.')],
#  [('emerges', 'NNS'),
#   ('as', 'IN'),
#   ('something', 'NN'),
#   ('rare', 'JJ'),
#   (',', ','),
#   ('an', 'DT'),
#   ('issue', 'NN'),
#   ('movie', 'NN'),
#   ('that', 'WDT'),
#   ('s', 'VBZ'),
#   ('so', 'RB'),
#   ('honest', 'JJ'),
#   ('and', 'CC'),
#   ('keenly', 'RB'),
#   ('observed', 'VBD'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('does', 'VBZ'),
#   ("n't", 'RB'),
#   ('feel', 'VB'),
#   ('like', 'IN'),
#   ('one', 'CD'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('film', 'NN'),
#   ('provides', 'VBZ'),
#   ('some', 'DT'),
#   ('great', 'JJ'),
#   ('insight', 'NN'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('neurotic', 'JJ'),
#   ('mindset', 'NN'),
#   ('of', 'IN'),
#   ('all', 'DT'),
#   ('comics', 'NNS'),
#   ('even', 'RB'),
#   ('those', 'DT'),
#   ('who', 'WP'),
#   ('have', 'VBP'),
#   ('reached', 'VBN'),
#   ('the', 'DT'),
#   ('absolute', 'JJ'),
#   ('top', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('game', 'NN'),
#   ('.', '.')],
#  [('offers', 'NNS'),
#   ('that', 'WDT'),
#   ('rare', 'VBP'),
#   ('combination', 'NN'),
#   ('of', 'IN'),
#   ('entertainment', 'NN'),
#   ('and', 'CC'),
#   ('education', 'NN'),
#   ('.', '.')],
#  [('perhaps', 'RB'),
#   ('no', 'DT'),
#   ('picture', 'NN'),
#   ('ever', 'RB'),
#   ('made', 'VBD'),
#   ('has', 'VBZ'),
#   ('more', 'RBR'),
#   ('literally', 'RB'),
#   ('showed', 'VBD'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('road', 'NN'),
#   ('to', 'TO'),
#   ('hell', 'VB'),
#   ('is', 'VBZ'),
#   ('paved', 'VBN'),
#   ('with', 'IN'),
#   ('good', 'JJ'),
#   ('intentions', 'NNS'),
#   ('.', '.')],
#  [('steers', 'NNS'),
#   ('turns', 'VBZ'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('snappy', 'JJ'),
#   ('screenplay', 'NN'),
#   ('that', 'WDT'),
#   ('curls', 'VBZ'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   (';', ':'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('so', 'RB'),
#   ('clever', 'JJ'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('hate', 'VB'),
#   ('it', 'PRP'),
#   ('.', '.'),
#   ('but', 'CC'),
#   ('he', 'PRP'),
#   ('somehow', 'RB'),
#   ('pulls', 'VBZ'),
#   ('it', 'PRP'),
#   ('off', 'RP'),
#   ('.', '.')],
#  [('take', 'VB'),
#   ('care', 'NN'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('cat', 'NN'),
#   ('offers', 'VBZ'),
#   ('a', 'DT'),
#   ('refreshingly', 'RB'),
#   ('different', 'JJ'),
#   ('slice', 'NN'),
#   ('of', 'IN'),
#   ('asian', 'JJ'),
#   ('cinema', 'NN'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('film', 'NN'),
#   ('well', 'RB'),
#   ('worth', 'IN'),
#   ('seeing', 'VBG'),
#   (',', ','),
#   ('talking', 'VBG'),
#   ('and', 'CC'),
#   ('singing', 'VBG'),
#   ('heads', 'NNS'),
#   ('and', 'CC'),
#   ('all', 'DT'),
#   ('.', '.')],
#  [('what', 'WP'),
#   ('really', 'RB'),
#   ('surprises', 'VBZ'),
#   ('about', 'IN'),
#   ('wisegirls', 'NN'),
#   ('is', 'VBZ'),
#   ('its', 'PRP$'),
#   ('low', 'JJ'),
#   ('key', 'JJ'),
#   ('quality', 'NN'),
#   ('and', 'CC'),
#   ('genuine', 'JJ'),
#   ('tenderness', 'NN'),
#   ('.', '.')],
#  [('(', '('),
#   ('wendigo', 'NN'),
#   ('is', 'VBZ'),
#   (')', ')'),
#   ('why', 'WRB'),
#   ('we', 'PRP'),
#   ('go', 'VBP'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('cinema', 'NN'),
#   (':', ':'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('fed', 'VBN'),
#   ('through', 'IN'),
#   ('the', 'DT'),
#   ('eye', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('heart', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('mind', 'NN'),
#   ('.', '.')],
#  [('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('greatest', 'JJS'),
#   ('family', 'NN'),
#   ('oriented', 'VBN'),
#   (',', ','),
#   ('fantasy', 'JJ'),
#   ('adventure', 'NN'),
#   ('movies', 'NNS'),
#   ('ever', 'RB'),
#   ('.', '.')],
#  [('ultimately', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('ponders', 'VBZ'),
#   ('the', 'DT'),
#   ('reasons', 'NNS'),
#   ('we', 'PRP'),
#   ('need', 'VBP'),
#   ('stories', 'NNS'),
#   ('so', 'RB'),
#   ('much', 'RB'),
#   ('.', '.')],
#  [('an', 'DT'),
#   ('utterly', 'JJ'),
#   ('compelling', 'NN'),
#   ('who', 'WP'),
#   ('wrote', 'VBD'),
#   ('it', 'PRP'),
#   ('', 'NNP'),
#   ('in', 'IN'),
#   ('which', 'WDT'),
#   ('the', 'DT'),
#   ('reputation', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('famous', 'JJ'),
#   ('author', 'NN'),
#   ('who', 'WP'),
#   ('ever', 'RB'),
#   ('lived', 'VBD'),
#   ('comes', 'VBZ'),
#   ('into', 'IN'),
#   ('question', 'NN'),
#   ('.', '.')],
#  [('illuminating', 'VBG'),
#   ('if', 'IN'),
#   ('overly', 'RB'),
#   ('talky', 'JJ'),
#   ('documentary', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('masterpiece', 'JJ'),
#   ('four', 'CD'),
#   ('years', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('making', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('movie', 'NN'),
#   ('s', 'NN'),
#   ('ripe', 'NN'),
#   (',', ','),
#   ('enrapturing', 'VBG'),
#   ('beauty', 'NN'),
#   ('will', 'MD'),
#   ('tempt', 'VB'),
#   ('those', 'DT'),
#   ('willing', 'JJ'),
#   ('to', 'TO'),
#   ('probe', 'VB'),
#   ('its', 'PRP$'),
#   ('inscrutable', 'JJ'),
#   ('mysteries', 'NNS'),
#   ('.', '.')],
#  [('offers', 'NNS'),
#   ('a', 'DT'),
#   ('breath', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('fresh', 'JJ'),
#   ('air', 'NN'),
#   ('of', 'IN'),
#   ('true', 'JJ'),
#   ('sophistication', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('thoughtful', 'JJ'),
#   (',', ','),
#   ('provocative', 'JJ'),
#   (',', ','),
#   ('insistently', 'RB'),
#   ('humanizing', 'VBG'),
#   ('film', 'NN'),
#   ('.', '.')],
#  [('with', 'IN'),
#   ('a', 'DT'),
#   ('cast', 'NN'),
#   ('that', 'WDT'),
#   ('includes', 'VBZ'),
#   ('some', 'DT'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('top', 'JJ'),
#   ('actors', 'NNS'),
#   ('working', 'VBG'),
#   ('in', 'IN'),
#   ('independent', 'JJ'),
#   ('film', 'NN'),
#   (',', ','),
#   ('lovely', 'RB'),
#   ('&', 'CC'),
#   ('amazing', 'VBG'),
#   ('involves', 'VBZ'),
#   ('us', 'PRP'),
#   ('because', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('incisive', 'JJ'),
#   (',', ','),
#   ('so', 'RB'),
#   ('bleakly', 'JJ'),
#   ('amusing', 'VBG'),
#   ('about', 'IN'),
#   ('how', 'WRB'),
#   ('we', 'PRP'),
#   ('go', 'VBP'),
#   ('about', 'IN'),
#   ('our', 'PRP$'),
#   ('lives', 'NNS'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('disturbing', 'NN'),
#   ('and', 'CC'),
#   ('frighteningly', 'RB'),
#   ('evocative', 'JJ'),
#   ('assembly', 'NN'),
#   ('of', 'IN'),
#   ('imagery', 'NN'),
#   ('and', 'CC'),
#   ('hypnotic', 'JJ'),
#   ('music', 'NN'),
#   ('composed', 'VBN'),
#   ('by', 'IN'),
#   ('philip', 'NN'),
#   ('glass', 'NN'),
#   ('.', '.')],
#  [('not', 'RB'),
#   ('for', 'IN'),
#   ('everyone', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('those', 'DT'),
#   ('with', 'IN'),
#   ('whom', 'WP'),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('connect', 'VB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('s', 'VBD'),
#   ('a', 'DT'),
#   ('nice', 'JJ'),
#   ('departure', 'NN'),
#   ('from', 'IN'),
#   ('standard', 'JJ'),
#   ('moviegoing', 'VBG'),
#   ('fare', 'NN'),
#   ('.', '.')],
#  [('scores', 'NNS'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('points', 'NNS'),
#   ('for', 'IN'),
#   ('doing', 'VBG'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('does', 'VBZ'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('dedicated', 'JJ'),
#   ('and', 'CC'),
#   ('good', 'JJ'),
#   ('hearted', 'VBN'),
#   ('professionalism', 'NN'),
#   ('.', '.')],
#  [('occasionally', 'RB'),
#   ('melodramatic', 'JJ'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('also', 'RB'),
#   ('extremely', 'RB'),
#   ('effective', 'JJ'),
#   ('.', '.')],
#  [('spiderman', 'NN'), ('rocks', 'NNS')],
#  [('an', 'DT'),
#   ('idealistic', 'JJ'),
#   ('love', 'NN'),
#   ('story', 'NN'),
#   ('that', 'WDT'),
#   ('brings', 'VBZ'),
#   ('out', 'RP'),
#   ('the', 'DT'),
#   ('latent', 'NN'),
#   ('15', 'CD'),
#   ('year', 'NN'),
#   ('old', 'JJ'),
#   ('romantic', 'JJ'),
#   ('in', 'IN'),
#   ('everyone', 'NN'),
#   ('.', '.')],
#  [('at', 'IN'),
#   ('about', 'RB'),
#   ('95', 'CD'),
#   ('minutes', 'NNS'),
#   (',', ','),
#   ('treasure', 'NN'),
#   ('planet', 'NN'),
#   ('maintains', 'VBZ'),
#   ('a', 'DT'),
#   ('brisk', 'JJ'),
#   ('pace', 'NN'),
#   ('as', 'IN'),
#   ('it', 'PRP'),
#   ('races', 'VBZ'),
#   ('through', 'IN'),
#   ('the', 'DT'),
#   ('familiar', 'JJ'),
#   ('story', 'NN'),
#   ('.', '.'),
#   ('however', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('lacks', 'VBZ'),
#   ('grandeur', 'NN'),
#   ('and', 'CC'),
#   ('that', 'IN'),
#   ('epic', 'VBP'),
#   ('quality', 'NN'),
#   ('often', 'RB'),
#   ('associated', 'VBN'),
#   ('with', 'IN'),
#   ('stevenson', 'NN'),
#   ('s', 'JJ'),
#   ('tale', 'NN'),
#   ('as', 'RB'),
#   ('well', 'RB'),
#   ('as', 'IN'),
#   ('with', 'IN'),
#   ('earlier', 'JJR'),
#   ('disney', 'NN'),
#   ('efforts', 'NNS'),
#   ('.', '.')],
#  [('it', 'PRP'),
#   ('helps', 'VBZ'),
#   ('that', 'IN'),
#   ('lil', 'NN'),
#   ('bow', 'NN'),
#   ('wow', 'NN'),
#   ('.', '.'),
#   ('.', '.'),
#   ('.', '.'),
#   ('tones', 'NNS'),
#   ('down', 'RP'),
#   ('his', 'PRP$'),
#   ('pint', 'NN'),
#   ('sized', 'VBD'),
#   ('gangsta', 'JJ'),
#   ('act', 'NN'),
#   ('to', 'TO'),
#   ('play', 'VB'),
#   ('someone', 'NN'),
#   ('who', 'WP'),
#   ('resembles', 'VBZ'),
#   ('a', 'DT'),
#   ('real', 'JJ'),
#   ('kid', 'NN'),
#   ('.', '.')],
#  [('guaranteed', 'VBN'),
#   ('to', 'TO'),
#   ('move', 'VB'),
#   ('anyone', 'NN'),
#   ('who', 'WP'),
#   ('ever', 'RB'),
#   ('shook', 'VBP'),
#   (',', ','),
#   ('rattled', 'VBN'),
#   (',', ','),
#   ('or', 'CC'),
#   ('rolled', 'VBN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('masterful', 'JJ'),
#   ('film', 'NN'),
#   ('from', 'IN'),
#   ('a', 'DT'),
#   ('master', 'NN'),
#   ('filmmaker', 'NN'),
#   (',', ','),
#   ('unique', 'NN'),
#   ('in', 'IN'),
#   ('its', 'PRP$'),
#   ('deceptive', 'JJ'),
#   ('grimness', 'NN'),
#   (',', ','),
#   ('compelling', 'VBG'),
#   ('in', 'IN'),
#   ('its', 'PRP$'),
#   ('fatalist', 'NN'),
#   ('worldview', 'NN'),
#   ('.', '.')],
#  [('light', 'NN'),
#   (',', ','),
#   ('cute', 'NN'),
#   ('and', 'CC'),
#   ('forgettable', 'JJ'),
#   ('.', '.')],
#  [('if', 'IN'),
#   ('there', 'EX'),
#   ('s', 'VBP'),
#   ('a', 'DT'),
#   ('way', 'NN'),
#   ('to', 'TO'),
#   ('effectively', 'RB'),
#   ('teach', 'VB'),
#   ('kids', 'NNS'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('dangers', 'NNS'),
#   ('of', 'IN'),
#   ('drugs', 'NNS'),
#   (',', ','),
#   ('i', 'NN'),
#   ('think', 'VBP'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('in', 'IN'),
#   ('projects', 'NNS'),
#   ('like', 'IN'),
#   ('the', 'DT'),
#   ('(', '('),
#   ('unfortunately', 'JJ'),
#   ('r', 'NN'),
#   ('rated', 'VBN'),
#   (')', ')'),
#   ('paid', 'VBN'),
#   ('.', '.')],
#  [('while', 'IN'),
#   ('it', 'PRP'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('give', 'VB'),
#   ('crush', 'VB'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('title', 'NN'),
#   ('of', 'IN'),
#   ('two', 'CD'),
#   ('weddings', 'NNS'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('funeral', 'JJ'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('s', 'VBD'),
#   ('a', 'DT'),
#   ('far', 'RB'),
#   ('more', 'RBR'),
#   ('thoughtful', 'JJ'),
#   ('film', 'NN'),
#   ('than', 'IN'),
#   ('any', 'DT'),
#   ('slice', 'NN'),
#   ('of', 'IN'),
#   ('hugh', 'JJ'),
#   ('grant', 'NN'),
#   ('whimsy', 'NN'),
#   ('.', '.')],
#  [('though', 'IN'),
#   ('everything', 'NN'),
#   ('might', 'MD'),
#   ('be', 'VB'),
#   ('literate', 'JJ'),
#   ('and', 'CC'),
#   ('smart', 'JJ'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('never', 'RB'),
#   ('took', 'VBD'),
#   ('off', 'RP'),
#   ('and', 'CC'),
#   ('always', 'RB'),
#   ('seemed', 'VBD'),
#   ('static', 'JJ'),
#   ('.', '.')],
#  [('cantet', 'NN'),
#   ('perfectly', 'RB'),
#   ('captures', 'VBZ'),
#   ('the', 'DT'),
#   ('hotel', 'NN'),
#   ('lobbies', 'NNS'),
#   (',', ','),
#   ('two', 'CD'),
#   ('lane', 'NN'),
#   ('highways', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('roadside', 'VB'),
#   ('cafes', 'NN'),
#   ('that', 'WDT'),
#   ('permeate', 'VBP'),
#   ('vincent', 'JJ'),
#   ('s', 'NN'),
#   ('days', 'NNS')],
#  [('ms', 'NN'),
#   ('.', '.'),
#   ('fulford', 'NN'),
#   ('wierzbicki', 'NN'),
#   ('is', 'VBZ'),
#   ('almost', 'RB'),
#   ('spooky', 'JJ'),
#   ('in', 'IN'),
#   ('her', 'PRP$'),
#   ('sulky', 'NN'),
#   (',', ','),
#   ('calculating', 'VBG'),
#   ('lolita', 'JJ'),
#   ('turn', 'NN'),
#   ('.', '.')],
#  [('though', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('by', 'IN'),
#   ('no', 'DT'),
#   ('means', 'NNS'),
#   ('his', 'PRP$'),
#   ('best', 'JJS'),
#   ('work', 'NN'),
#   (',', ','),
#   ('laissez', 'FW'),
#   ('passer', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('distinguished', 'JJ'),
#   ('and', 'CC'),
#   ('distinctive', 'JJ'),
#   ('effort', 'NN'),
#   ('by', 'IN'),
#   ('a', 'DT'),
#   ('bona', 'JJ'),
#   ('fide', 'NN'),
#   ('master', 'NN'),
#   (',', ','),
#   ('a', 'DT'),
#   ('fascinating', 'JJ'),
#   ('film', 'NN'),
#   ('replete', 'NN'),
#   ('with', 'IN'),
#   ('rewards', 'NNS'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('had', 'VBN'),
#   ('by', 'IN'),
#   ('all', 'DT'),
#   ('willing', 'JJ'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('the', 'DT'),
#   ('effort', 'NN'),
#   ('to', 'TO'),
#   ('reap', 'VB'),
#   ('them', 'PRP'),
#   ('.', '.')],
#  [('like', 'IN'),
#   ('most', 'JJS'),
#   ('bond', 'NN'),
#   ('outings', 'NNS'),
#   ('in', 'IN'),
#   ('recent', 'JJ'),
#   ('years', 'NNS'),
#   (',', ','),
#   ('some', 'DT'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('stunts', 'NNS'),
#   ('are', 'VBP'),
#   ('so', 'RB'),
#   ('outlandish', 'JJ'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('border', 'VBP'),
#   ('on', 'IN'),
#   ('being', 'VBG'),
#   ('cartoonlike', 'NN'),
#   ('.', '.'),
#   ('a', 'DT'),
#   ('heavy', 'JJ'),
#   ('reliance', 'NN'),
#   ('on', 'IN'),
#   ('cgi', 'NN'),
#   ('technology', 'NN'),
#   ('is', 'VBZ'),
#   ('beginning', 'VBG'),
#   ('to', 'TO'),
#   ('creep', 'VB'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('series', 'NN'),
#   ('.', '.')],
#  [('newton', 'RB'),
#   ('draws', 'VBZ'),
#   ('our', 'PRP$'),
#   ('attention', 'NN'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('magnet', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('acts', 'VBZ'),
#   ('circles', 'NNS'),
#   ('around', 'IN'),
#   ('her', 'PRP$'),
#   ('better', 'JJR'),
#   ('known', 'VBN'),
#   ('co', 'JJ'),
#   ('star', 'NN'),
#   (',', ','),
#   ('mark', 'NN'),
#   ('wahlberg', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('story', 'NN'),
#   ('loses', 'VBZ'),
#   ('its', 'PRP$'),
#   ('bite', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('last', 'JJ'),
#   ('minute', 'NN'),
#   ('happy', 'JJ'),
#   ('ending', 'VBG'),
#   ('that', 'IN'),
#   ('s', 'VBD'),
#   ('even', 'RB'),
#   ('less', 'RBR'),
#   ('plausible', 'JJ'),
#   ('than', 'IN'),
#   ('the', 'DT'),
#   ('rest', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('picture', 'NN'),
#   ('.', '.'),
#   ('much', 'RB'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   (',', ','),
#   ('though', 'RB'),
#   (',', ','),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('refreshingly', 'RB'),
#   ('novel', 'JJ'),
#   ('ride', 'NN'),
#   ('.', '.')],
#  [('fuller', 'NN'),
#   ('would', 'MD'),
#   ('surely', 'RB'),
#   ('have', 'VB'),
#   ('called', 'VBN'),
#   ('this', 'DT'),
#   ('gutsy', 'NN'),
#   ('and', 'CC'),
#   ('at', 'IN'),
#   ('times', 'NNS'),
#   ('exhilarating', 'VBG'),
#   ('movie', 'NN'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('yarn', 'NN'),
#   ('.', '.')],
#  [('compleja', 'NN'),
#   ('e', 'NN'),
#   ('intelectualmente', 'NN'),
#   ('retadora', 'NN'),
#   (',', ','),
#   ('el', 'JJ'),
#   ('ladrón', 'FW'),
#   ('de', 'FW'),
#   ('orquídeas', 'FW'),
#   ('es', 'FW'),
#   ('uno', 'FW'),
#   ('de', 'FW'),
#   ('esos', 'FW'),
#   ('filmes', 'NNS'),
#   ('que', 'VBP'),
#   ('vale', 'JJ'),
#   ('la', 'FW'),
#   ('pena', 'FW'),
#   ('ver', 'FW'),
#   ('precisamente', 'FW'),
#   ('por', 'FW'),
#   ('su', 'NN'),
#   ('originalidad', 'NN'),
#   ('.', '.'),
#   ('', 'NN')],
#  [('the', 'DT'),
#   ('film', 'NN'),
#   ('makes', 'VBZ'),
#   ('a', 'DT'),
#   ('strong', 'JJ'),
#   ('case', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('importance', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('musicians', 'NNS'),
#   ('in', 'IN'),
#   ('creating', 'VBG'),
#   ('the', 'DT'),
#   ('motown', 'JJ'),
#   ('sound', 'NN'),
#   ('.', '.')],
#  [('karmen', 'NNS'),
#   ('moves', 'NNS'),
#   ('like', 'IN'),
#   ('rhythm', 'NN'),
#   ('itself', 'PRP'),
#   (',', ','),
#   ('her', 'PRP'),
#   ('lips', 'VBZ'),
#   ('chanting', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('beat', 'NN'),
#   (',', ','),
#   ('her', 'PRP'),
#   ('long', 'RB'),
#   (',', ','),
#   ('braided', 'VBD'),
#   ('hair', 'NN'),
#   ('doing', 'VBG'),
#   ('little', 'JJ'),
#   ('to', 'TO'),
#   ('wipe', 'VB'),
#   ('away', 'RP'),
#   ('the', 'DT'),
#   ('jeweled', 'JJ'),
#   ('beads', 'NNS'),
#   ('of', 'IN'),
#   ('sweat', 'NN'),
#   ('.', '.')],
#  [('gosling', 'VBG'),
#   ('provides', 'VBZ'),
#   ('an', 'DT'),
#   ('amazing', 'JJ'),
#   ('performance', 'NN'),
#   ('that', 'IN'),
#   ('dwarfs', 'VBZ'),
#   ('everything', 'NN'),
#   ('else', 'RB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('real', 'JJ'),
#   ('movie', 'NN'),
#   (',', ','),
#   ('about', 'RB'),
#   ('real', 'JJ'),
#   ('people', 'NNS'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('gives', 'VBZ'),
#   ('us', 'PRP'),
#   ('a', 'DT'),
#   ('rare', 'JJ'),
#   ('glimpse', 'NN'),
#   ('into', 'IN'),
#   ('a', 'DT'),
#   ('culture', 'NN'),
#   ('most', 'JJS'),
#   ('of', 'IN'),
#   ('us', 'PRP'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('.', '.')],
#  [('tender', 'NN'),
#   ('yet', 'RB'),
#   ('lacerating', 'VBG'),
#   ('and', 'CC'),
#   ('darkly', 'JJ'),
#   ('funny', 'NN'),
#   ('fable', 'NN'),
#   ('.', '.')],
#  [('may', 'MD'),
#   ('be', 'VB'),
#   ('spoofing', 'VBG'),
#   ('an', 'DT'),
#   ('easy', 'JJ'),
#   ('target', 'NN'),
#   ('those', 'DT'),
#   ('old', 'JJ'),
#   ('50', 'CD'),
#   ('s', 'NN'),
#   ('giant', 'JJ'),
#   ('creature', 'NN'),
#   ('features', 'NNS'),
#   ('but', 'CC'),
#   ('.', '.'),
#   ('.', '.'),
#   ('.', '.'),
#   ('it', 'PRP'),
#   ('acknowledges', 'VBZ'),
#   ('and', 'CC'),
#   ('celebrates', 'VBZ'),
#   ('their', 'PRP$'),
#   ('cheesiness', 'NN'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('reason', 'NN'),
#   ('why', 'WRB'),
#   ('people', 'NNS'),
#   ('get', 'VBP'),
#   ('a', 'DT'),
#   ('kick', 'NN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('watching', 'VBG'),
#   ('them', 'PRP'),
#   ('today', 'NN'),
#   ('.', '.')],
#  [('an', 'DT'),
#   ('engaging', 'VBG'),
#   ('overview', 'NN'),
#   ('of', 'IN'),
#   ('johnson', 'NN'),
#   ('s', 'NN'),
#   ('eccentric', 'JJ'),
#   ('career', 'NN'),
#   ('.', '.')],
#  [('in', 'IN'),
#   ('its', 'PRP$'),
#   ('ragged', 'NN'),
#   (',', ','),
#   ('cheap', 'JJ'),
#   ('and', 'CC'),
#   ('unassuming', 'JJ'),
#   ('way', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('works', 'VBZ'),
#   ('.', '.')],
#  [('some', 'DT'),
#   ('actors', 'NNS'),
#   ('have', 'VBP'),
#   ('so', 'RB'),
#   ('much', 'JJ'),
#   ('charisma', 'NN'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('d', 'VBP'),
#   ('be', 'VB'),
#   ('happy', 'JJ'),
#   ('to', 'TO'),
#   ('listen', 'VB'),
#   ('to', 'TO'),
#   ('them', 'PRP'),
#   ('reading', 'VBG'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('book', 'NN'),
#   ('.', '.'),
#   ('hugh', 'JJ'),
#   ('grant', 'NN'),
#   ('and', 'CC'),
#   ('sandra', 'NN'),
#   ('bullock', 'NN'),
#   ('are', 'VBP'),
#   ('two', 'CD'),
#   ('such', 'JJ'),
#   ('likeable', 'JJ'),
#   ('actors', 'NNS'),
#   ('.', '.')],
#  [('sandra', 'NN'),
#   ('nettelbeck', 'NN'),
#   ('beautifully', 'RB'),
#   ('orchestrates', 'VBZ'),
#   ('the', 'DT'),
#   ('transformation', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('chilly', 'NN'),
#   (',', ','),
#   ('neurotic', 'JJ'),
#   (',', ','),
#   ('and', 'CC'),
#   ('self', 'PRP'),
#   ('absorbed', 'RB'),
#   ('martha', 'VBD'),
#   ('as', 'IN'),
#   ('her', 'PRP$'),
#   ('heart', 'NN'),
#   ('begins', 'VBZ'),
#   ('to', 'TO'),
#   ('open', 'VB'),
#   ('.', '.')],
#  [('behind', 'IN'),
#   ('the', 'DT'),
#   ('snow', 'JJ'),
#   ('games', 'NNS'),
#   ('and', 'CC'),
#   ('lovable', 'JJ'),
#   ('siberian', 'JJ'),
#   ('huskies', 'NNS'),
#   ('(', '('),
#   ('plus', 'CC'),
#   ('one', 'CD'),
#   ('sheep', 'NN'),
#   ('dog', 'NN'),
#   (')', ')'),
#   (',', ','),
#   ('the', 'DT'),
#   ('picture', 'NN'),
#   ('hosts', 'VBZ'),
#   ('a', 'DT'),
#   ('parka', 'NN'),
#   ('wrapped', 'VBD'),
#   ('dose', 'NN'),
#   ('of', 'IN'),
#   ('heart', 'NN'),
#   ('.', '.')],
#  [('everytime', 'RB'),
#   ('you', 'PRP'),
#   ('think', 'VBP'),
#   ('undercover', 'JJ'),
#   ('brother', 'NN'),
#   ('has', 'VBZ'),
#   ('run', 'VBN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('steam', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('finds', 'VBZ'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('way', 'NN'),
#   ('to', 'TO'),
#   ('surprise', 'VB'),
#   ('and', 'CC'),
#   ('amuse', 'VB'),
#   ('.', '.')],
#  [('manages', 'NNS'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('original', 'JJ'),
#   (',', ','),
#   ('even', 'RB'),
#   ('though', 'IN'),
#   ('it', 'PRP'),
#   ('rips', 'VBZ'),
#   ('off', 'IN'),
#   ('many', 'JJ'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('ideas', 'NNS'),
#   ('.', '.')],
#  [('singer', 'NN'),
#   ('composer', 'NN'),
#   ('bryan', 'JJ'),
#   ('adams', 'NN'),
#   ('contributes', 'VBZ'),
#   ('a', 'DT'),
#   ('slew', 'NN'),
#   ('of', 'IN'),
#   ('songs', 'NNS'),
#   ('\x97', 'VBP'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('potential', 'JJ'),
#   ('hits', 'NNS'),
#   (',', ','),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('more', 'JJR'),
#   ('simply', 'RB'),
#   ('intrusive', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('\x97', 'NN'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('package', 'NN'),
#   ('certainly', 'RB'),
#   ('captures', 'VBZ'),
#   ('the', 'DT'),
#   ('intended', 'JJ'),
#   (',', ','),
#   ('er', 'NN'),
#   (',', ','),
#   ('spirit', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('piece', 'NN'),
#   ('.', '.')],
#  [('you', 'PRP'),
#   ('d', 'VBP'),
#   ('think', 'VB'),
#   ('by', 'IN'),
#   ('now', 'RB'),
#   ('america', 'RB'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('had', 'VBN'),
#   ('enough', 'NN'),
#   ('of', 'IN'),
#   ('plucky', 'JJ'),
#   ('british', 'JJ'),
#   ('eccentrics', 'NNS'),
#   ('with', 'IN'),
#   ('hearts', 'NNS'),
#   ('of', 'IN'),
#   ('gold', 'NN'),
#   ('.', '.'),
#   ('yet', 'CC'),
#   ('the', 'DT'),
#   ('act', 'NN'),
#   ('is', 'VBZ'),
#   ('still', 'RB'),
#   ('charming', 'VBG'),
#   ('here', 'RB'),
#   ('.', '.')],
#  [('whether', 'IN'),
#   ('or', 'CC'),
#   ('not', 'RB'),
#   ('you', 'PRP'),
#   ('re', 'VBP'),
#   ('enlightened', 'VBN'),
#   ('by', 'IN'),
#   ('any', 'DT'),
#   ('of', 'IN'),
#   ('derrida', 'NN'),
#   ('s', 'NN'),
#   ('lectures', 'VBZ'),
#   ('on', 'IN'),
#   ('``', '``'),
#   ('the', 'DT'),
#   ('other', 'JJ'),
#   ('``', '``'),
#   ('and', 'CC'),
#   ('``', '``'),
#   ('the', 'DT'),
#   ('self', 'NN'),
#   (',', ','),
#   ('``', '``'),
#   ('derrida', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('undeniably', 'JJ'),
#   ('fascinating', 'NN'),
#   ('and', 'CC'),
#   ('playful', 'JJ'),
#   ('fellow', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('pleasant', 'JJ'),
#   ('enough', 'JJ'),
#   ('movie', 'NN'),
#   (',', ','),
#   ('held', 'VBD'),
#   ('together', 'RB'),
#   ('by', 'IN'),
#   ('skilled', 'VBN'),
#   ('ensemble', 'JJ'),
#   ('actors', 'NNS'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('american', 'JJ'),
#   ('movie', 'NN'),
#   ('about', 'IN'),
#   ('troubled', 'VBN'),
#   ('teens', 'NNS'),
#   ('since', 'IN'),
#   ('1998', 'CD'),
#   ('s', 'NN'),
#   ('whatever', 'WDT'),
#   ('.', '.')],
#  [('disney', 'NN'),
#   ('has', 'VBZ'),
#   ('always', 'RB'),
#   ('been', 'VBN'),
#   ('hit', 'VBN'),
#   ('or', 'CC'),
#   ('miss', 'VB'),
#   ('when', 'WRB'),
#   ('bringing', 'VBG'),
#   ('beloved', 'VBD'),
#   ('kids', 'NNS'),
#   ('', 'VBP'),
#   ('books', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('screen', 'NN'),
#   ('.', '.'),
#   ('.', '.'),
#   ('.', '.'),
#   ('tuck', 'JJ'),
#   ('everlasting', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('of', 'IN'),
#   ('both', 'DT'),
#   ('.', '.')],
#  [('just', 'RB'),
#   ('the', 'DT'),
#   ('labour', 'NN'),
#   ('involved', 'VBN'),
#   ('in', 'IN'),
#   ('creating', 'VBG'),
#   ('the', 'DT'),
#   ('layered', 'JJ'),
#   ('richness', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('imagery', 'NN'),
#   ('in', 'IN'),
#   ('this', 'DT'),
#   ('chiaroscuro', 'NN'),
#   ('of', 'IN'),
#   ('madness', 'NN'),
#   ('and', 'CC'),
#   ('light', 'NN'),
#   ('is', 'VBZ'),
#   ('astonishing', 'VBG'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('animated', 'JJ'),
#   ('subplot', 'NN'),
#   ('keenly', 'RB'),
#   ('depicts', 'VBZ'),
#   ('the', 'DT'),
#   ('inner', 'JJ'),
#   ('struggles', 'NNS'),
#   ('of', 'IN'),
#   ('our', 'PRP$'),
#   ('adolescent', 'NN'),
#   ('heroes', 'NNS'),
#   ('insecure', 'NN'),
#   (',', ','),
#   ('uncontrolled', 'JJ'),
#   (',', ','),
#   ('and', 'CC'),
#   ('intense', 'JJ'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('invincible', 'JJ'),
#   ('werner', 'NN'),
#   ('herzog', 'NN'),
#   ('is', 'VBZ'),
#   ('alive', 'JJ'),
#   ('and', 'CC'),
#   ('well', 'RB'),
#   ('and', 'CC'),
#   ('living', 'VBG'),
#   ('in', 'IN'),
#   ('la', 'NN')],
#  [('morton', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('actress', 'NN'),
#   ('portraying', 'VBG'),
#   ('a', 'DT'),
#   ('complex', 'JJ'),
#   ('character', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('morvern', 'JJ'),
#   ('callar', 'JJ'),
#   ('grows', 'NNS'),
#   ('less', 'RBR'),
#   ('compelling', 'VBG'),
#   ('the', 'DT'),
#   ('farther', 'NN'),
#   ('it', 'PRP'),
#   ('meanders', 'VBZ'),
#   ('from', 'IN'),
#   ('its', 'PRP$'),
#   ('shocking', 'VBG'),
#   ('start', 'NN'),
#   ('.', '.')],
#  [('part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('charm', 'NN'),
#   ('of', 'IN'),
#   ('satin', 'NN'),
#   ('rouge', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('avoids', 'VBZ'),
#   ('the', 'DT'),
#   ('obvious', 'JJ'),
#   ('with', 'IN'),
#   ('humour', 'NN'),
#   ('and', 'CC'),
#   ('lightness', 'NN'),
#   ('.', '.')],
#  [('son', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('bride', 'NN'),
#   ('may', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('half', 'NN'),
#   ('hour', 'NN'),
#   ('too', 'RB'),
#   ('long', 'RB'),
#   ('but', 'CC'),
#   ('comes', 'VBZ'),
#   ('replete', 'JJ'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('flattering', 'VBG'),
#   ('sense', 'NN'),
#   ('of', 'IN'),
#   ('mystery', 'NN'),
#   ('and', 'CC'),
#   ('quietness', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('simmering', 'VBG'),
#   ('psychological', 'JJ'),
#   ('drama', 'NN'),
#   ('in', 'IN'),
#   ('which', 'WDT'),
#   ('the', 'DT'),
#   ('bursts', 'NNS'),
#   ('of', 'IN'),
#   ('sudden', 'JJ'),
#   ('violence', 'NN'),
#   ('are', 'VBP'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('more', 'RBR'),
#   ('startling', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('slow', 'JJ'),
#   ('buildup', 'NN'),
#   ('that', 'WDT'),
#   ('has', 'VBZ'),
#   ('preceded', 'VBN'),
#   ('them', 'PRP'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('taut', 'NN'),
#   (',', ','),
#   ('intelligent', 'JJ'),
#   ('psychological', 'JJ'),
#   ('drama', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('compelling', 'JJ'),
#   ('coming', 'NN'),
#   ('of', 'IN'),
#   ('age', 'NN'),
#   ('drama', 'NN'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('arduous', 'JJ'),
#   ('journey', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('sensitive', 'JJ'),
#   ('young', 'JJ'),
#   ('girl', 'NN'),
#   ('through', 'IN'),
#   ('a', 'DT'),
#   ('series', 'NN'),
#   ('of', 'IN'),
#   ('foster', 'JJ'),
#   ('homes', 'NNS'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('fierce', 'JJ'),
#   ('struggle', 'NN'),
#   ('to', 'TO'),
#   ('pull', 'VB'),
#   ('free', 'JJ'),
#   ('from', 'IN'),
#   ('her', 'PRP$'),
#   ('dangerous', 'JJ'),
#   ('and', 'CC'),
#   ('domineering', 'VBG'),
#   ('mother', 'NN'),
#   ('s', 'NN'),
#   ('hold', 'NN'),
#   ('over', 'IN'),
#   ('her', 'PRP'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('truly', 'JJ'),
#   ('moving', 'VBG'),
#   ('experience', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('perfect', 'JJ'),
#   ('example', 'NN'),
#   ('of', 'IN'),
#   ('how', 'WRB'),
#   ('art', 'NN'),
#   ('when', 'WRB'),
#   ('done', 'VBN'),
#   ('right', 'RB'),
#   ('can', 'MD'),
#   ('help', 'VB'),
#   ('heal', 'VB'),
#   (',', ','),
#   ('clarify', 'VB'),
#   (',', ','),
#   ('and', 'CC'),
#   ('comfort', 'NN'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('delicately', 'RB'),
#   ('observed', 'JJ'),
#   ('story', 'NN'),
#   (',', ','),
#   ('deeply', 'RB'),
#   ('felt', 'VBD'),
#   ('and', 'CC'),
#   ('masterfully', 'RB'),
#   ('stylized', 'VBN'),
#   (',', ','),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('triumph', 'NN'),
#   ('for', 'IN'),
#   ('its', 'PRP$'),
#   ('maverick', 'JJ'),
#   ('director', 'NN'),
#   ('.', '.')],
#  [('at', 'IN'),
#   ('heart', 'NN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('deftly', 'RB'),
#   ('wrought', 'JJ'),
#   ('suspense', 'NN'),
#   ('yarn', 'NN'),
#   ('whose', 'WP$'),
#   ('richer', 'JJR'),
#   ('shadings', 'NNS'),
#   ('work', 'VBP'),
#   ('as', 'IN'),
#   ('coloring', 'VBG'),
#   ('rather', 'RB'),
#   ('than', 'IN'),
#   ('substance', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('appearance', 'NN'),
#   ('of', 'IN'),
#   ('treebeard', 'NN'),
#   ('and', 'CC'),
#   ('gollum', 'NN'),
#   ('s', 'NN'),
#   ('expanded', 'VBD'),
#   ('role', 'NN'),
#   ('will', 'MD'),
#   ('either', 'RB'),
#   ('have', 'VB'),
#   ('you', 'PRP'),
#   ('loving', 'VBG'),
#   ('what', 'WP'),
#   ('you', 'PRP'),
#   ('re', 'VBP'),
#   ('seeing', 'VBG'),
#   (',', ','),
#   ('or', 'CC'),
#   ('rolling', 'VBG'),
#   ('your', 'PRP$'),
#   ('eyes', 'NNS'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('loved', 'VBD'),
#   ('it', 'PRP'),
#   ('!', '.'),
#   ('gollum', 'JJ'),
#   ('s', 'JJ'),
#   ('performance', 'NN'),
#   ('', 'NN'),
#   ('is', 'VBZ'),
#   ('incredible', 'JJ'),
#   ('!', '.')],
#  [('a', 'DT'),
#   ('screenplay', 'NN'),
#   ('more', 'RBR'),
#   ('ingeniously', 'RB'),
#   ('constructed', 'VBN'),
#   ('than', 'IN'),
#   ('``', '``'),
#   ('memento', 'IN'),
#   ('``', '``')],
#  [('if', 'IN'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('were', 'VBD'),
#   ('a', 'DT'),
#   ('book', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('page', 'NN'),
#   ('turner', 'NN'),
#   (',', ','),
#   ('you', 'PRP'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('wait', 'VB'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('what', 'WP'),
#   ('happens', 'VBZ'),
#   ('next', 'JJ'),
#   ('.', '.')],
#  [('haneke', 'NN'),
#   ('challenges', 'VBZ'),
#   ('us', 'PRP'),
#   ('to', 'TO'),
#   ('confront', 'VB'),
#   ('the', 'DT'),
#   ('reality', 'NN'),
#   ('of', 'IN'),
#   ('sexual', 'JJ'),
#   ('aberration', 'NN'),
#   ('.', '.')],
#  [('absorbing', 'VBG'),
#   ('and', 'CC'),
#   ('disturbing', 'VBG'),
#   ('perhaps', 'RB'),
#   ('more', 'RBR'),
#   ('disturbing', 'JJ'),
#   ('than', 'IN'),
#   ('originally', 'RB'),
#   ('intended', 'VBN'),
#   ('but', 'CC'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('clarity', 'NN'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('gone', 'VBN'),
#   ('a', 'DT'),
#   ('long', 'JJ'),
#   ('way', 'NN'),
#   ('.', '.')],
#  [('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('film', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('year', 'NN'),
#   ('so', 'RB'),
#   ('far', 'RB'),
#   (',', ','),
#   ('the', 'DT'),
#   ('benchmark', 'NN'),
#   ('against', 'IN'),
#   ('which', 'WDT'),
#   ('all', 'DT'),
#   ('other', 'JJ'),
#   ('best', 'JJS'),
#   ('picture', 'NN'),
#   ('contenders', 'NNS'),
#   ('should', 'MD'),
#   ('be', 'VB'),
#   ('measured', 'VBN'),
#   ('.', '.')],
#  [('painful', 'JJ'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('viewers', 'NNS'),
#   ('willing', 'JJ'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('a', 'DT'),
#   ('chance', 'NN'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('rewarded', 'VBN'),
#   ('with', 'IN'),
#   ('two', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('year', 'NN'),
#   ('s', 'VBZ'),
#   ('most', 'RBS'),
#   ('accomplished', 'JJ'),
#   ('and', 'CC'),
#   ('riveting', 'JJ'),
#   ('film', 'NN'),
#   ('performances', 'NNS'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('startling', 'JJ'),
#   ('film', 'NN'),
#   ('that', 'WDT'),
#   ('gives', 'VBZ'),
#   ('you', 'PRP'),
#   ('a', 'DT'),
#   ('fascinating', 'JJ'),
#   (',', ','),
#   ('albeit', 'IN'),
#   ('depressing', 'VBG'),
#   ('view', 'NN'),
#   ('of', 'IN'),
#   ('iranian', 'JJ'),
#   ('rural', 'JJ'),
#   ('life', 'NN'),
#   ('close', 'RB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('iraqi', 'NN'),
#   ('border', 'NN'),
#   ('.', '.')],
#  [('an', 'DT'),
#   ('imaginative', 'JJ'),
#   ('comedy', 'NN'),
#   ('thriller', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('few', 'JJ'),
#   ('artsy', 'NN'),
#   ('flourishes', 'NNS'),
#   ('aside', 'RB'),
#   (',', ','),
#   ('narc', 'NN'),
#   ('is', 'VBZ'),
#   ('as', 'RB'),
#   ('gritty', 'JJ'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('movie', 'NN'),
#   ('gets', 'VBZ'),
#   ('these', 'DT'),
#   ('days', 'NNS'),
#   ('.', '.')],
#  [('while', 'IN'),
#   ('the', 'DT'),
#   ('isle', 'NN'),
#   ('is', 'VBZ'),
#   ('both', 'DT'),
#   ('preposterous', 'JJ'),
#   ('and', 'CC'),
#   ('thoroughly', 'JJ'),
#   ('misogynistic', 'JJ'),
#   (',', ','),
#   ('its', 'PRP$'),
#   ('vistas', 'NNS'),
#   ('are', 'VBP'),
#   ('incredibly', 'RB'),
#   ('beautiful', 'JJ'),
#   ('to', 'TO'),
#   ('look', 'VB'),
#   ('at', 'IN'),
#   ('.', '.')],
#  [('together', 'RB'),
#   (',', ','),
#   ('tok', 'NN'),
#   ('and', 'CC'),
#   ('o', 'JJ'),
#   ('orchestrate', 'NN'),
#   ('a', 'DT'),
#   ('buoyant', 'NN'),
#   (',', ','),
#   ('darkly', 'RB'),
#   ('funny', 'JJ'),
#   ('dance', 'NN'),
#   ('of', 'IN'),
#   ('death', 'NN'),
#   ('.', '.'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('process', 'NN'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('demonstrate', 'VBP'),
#   ('that', 'IN'),
#   ('there', 'EX'),
#   ('s', 'VB'),
#   ('still', 'RB'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('life', 'NN'),
#   ('in', 'IN'),
#   ('hong', 'JJ'),
#   ('kong', 'NN'),
#   ('cinema', 'NN'),
#   ('.', '.')],
#  [('director', 'NN'),
#   ('kapur', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('filmmaker', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('real', 'JJ'),
#   ('flair', 'NN'),
#   ('for', 'IN'),
#   ('epic', 'NN'),
#   ('landscapes', 'NNS'),
#   ('and', 'CC'),
#   ('adventure', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('better', 'JJR'),
#   ('film', 'NN'),
#   ('than', 'IN'),
#   ('his', 'PRP$'),
#   ('earlier', 'JJR'),
#   ('english', 'JJ'),
#   ('language', 'NN'),
#   ('movie', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('overpraised', 'JJ'),
#   ('elizabeth', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('blast', 'NN'),
#   ('of', 'IN'),
#   ('educational', 'JJ'),
#   ('energy', 'NN'),
#   (',', ','),
#   ('as', 'IN'),
#   ('bouncy', 'NN'),
#   ('animation', 'NN'),
#   ('and', 'CC'),
#   ('catchy', 'JJ'),
#   ('songs', 'NNS'),
#   ('escort', 'NN'),
#   ('you', 'PRP'),
#   ('through', 'IN'),
#   ('the', 'DT'),
#   ('entire', 'JJ'),
#   ('85', 'CD'),
#   ('minutes', 'NNS'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('sports', 'NNS'),
#   ('movie', 'NN'),
#   ('with', 'IN'),
#   ('action', 'NN'),
#   ('that', 'IN'),
#   ('s', 'VBZ'),
#   ('exciting', 'VBG'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('field', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('story', 'NN'),
#   ('you', 'PRP'),
#   ('care', 'VBP'),
#   ('about', 'IN'),
#   ('off', 'IN'),
#   ('it', 'PRP'),
#   ('.', '.')],
#  [('doug', 'NN'),
#   ('liman', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('director', 'NN'),
#   ('of', 'IN'),
#   ('bourne', 'NN'),
#   (',', ','),
#   ('directs', 'VBZ'),
#   ('the', 'DT'),
#   ('traffic', 'NN'),
#   ('well', 'RB'),
#   (',', ','),
#   ('gets', 'VBZ'),
#   ('a', 'DT'),
#   ('nice', 'JJ'),
#   ('wintry', 'NN'),
#   ('look', 'NN'),
#   ('from', 'IN'),
#   ('his', 'PRP$'),
#   ('locations', 'NNS'),
#   (',', ','),
#   ('absorbs', 'VBP'),
#   ('us', 'PRP'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('s', 'NN'),
#   ('spycraft', 'NN'),
#   ('and', 'CC'),
#   ('uses', 'VBZ'),
#   ('damon', 'JJ'),
#   ('s', 'JJ'),
#   ('ability', 'NN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('focused', 'VBN'),
#   ('and', 'CC'),
#   ('sincere', 'RB'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('tenderness', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('piece', 'NN'),
#   ('is', 'VBZ'),
#   ('still', 'RB'),
#   ('intact', 'JJ'),
#   ('.', '.')],
#  [('katz', 'NN'),
#   ('uses', 'VBZ'),
#   ('archival', 'JJ'),
#   ('footage', 'NN'),
#   (',', ','),
#   ('horrifying', 'VBG'),
#   ('documents', 'NNS'),
#   ('of', 'IN'),
#   ('lynchings', 'NNS'),
#   (',', ','),
#   ('still', 'RB'),
#   ('photographs', 'JJ'),
#   ('and', 'CC'),
#   ('charming', 'VBG'),
#   ('old', 'JJ'),
#   ('reel', 'NN'),
#   ('to', 'TO'),
#   ('reel', 'VB'),
#   ('recordings', 'NNS'),
#   ('of', 'IN'),
#   ('meeropol', 'NN'),
#   ('entertaining', 'VBG'),
#   ('his', 'PRP$'),
#   ('children', 'NNS'),
#   ('to', 'TO'),
#   ('create', 'VB'),
#   ('his', 'PRP$'),
#   ('song', 'JJ'),
#   ('history', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('most', 'JJS'),
#   ('powerful', 'JJ'),
#   ('of', 'IN'),
#   ('all', 'DT'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('song', 'NN'),
#   ('itself', 'PRP')],
#  [('like', 'IN'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('s', 'VBZ'),
#   ('almost', 'RB'),
#   ('anthropologically', 'RB'),
#   ('detailed', 'JJ'),
#   ('realization', 'NN'),
#   ('of', 'IN'),
#   ('early', 'JJ'),
#   ('80s', 'CD'),
#   ('suburbia', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('s', 'VBD'),
#   ('significant', 'JJ'),
#   ('without', 'IN'),
#   ('being', 'VBG'),
#   ('overstated', 'VBN'),
#   ('.', '.')],
#  [('while', 'IN'),
#   ('mcfarlane', 'JJ'),
#   ('s', 'JJ'),
#   ('animation', 'NN'),
#   ('lifts', 'VBZ'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('firmly', 'RB'),
#   ('above', 'IN'),
#   ('the', 'DT'),
#   ('level', 'NN'),
#   ('of', 'IN'),
#   ('other', 'JJ'),
#   ('coming', 'VBG'),
#   ('of', 'IN'),
#   ('age', 'NN'),
#   ('films', 'NNS'),
#   ('.', '.'),
#   ('.', '.'),
#   ('.', '.'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('also', 'RB'),
#   ('so', 'RB'),
#   ('jarring', 'VBG'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('hard', 'JJ'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('back', 'RB'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('boys', 'NNS'),
#   ('', 'NNP'),
#   ('story', 'NN'),
#   ('.', '.')],
#  [('if', 'IN'),
#   ('nothing', 'NN'),
#   ('else', 'RB'),
#   (',', ','),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('introduces', 'VBZ'),
#   ('a', 'DT'),
#   ('promising', 'NN'),
#   (',', ','),
#   ('unusual', 'JJ'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('psychological', 'JJ'),
#   ('horror', 'NN'),
#   ('.', '.')],
#  [('in', 'IN'),
#   ('a', 'DT'),
#   ('normal', 'JJ'),
#   ('screen', 'NN'),
#   ('process', 'NN'),
#   (',', ','),
#   ('these', 'DT'),
#   ('bromides', 'NNS'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('barely', 'RB'),
#   ('enough', 'JJ'),
#   ('to', 'TO'),
#   ('sustain', 'VB'),
#   ('an', 'DT'),
#   ('interstitial', 'JJ'),
#   ('program', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('discovery', 'NN'),
#   ('channel', 'NN'),
#   ('.', '.'),
#   ('but', 'CC'),
#   ('in', 'IN'),
#   ('imax', 'JJ'),
#   ('3', 'CD'),
#   ('d', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('clichés', 'NN'),
#   ('disappear', 'VBP'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('vertiginous', 'JJ'),
#   ('perspectives', 'NNS'),
#   ('opened', 'VBD'),
#   ('up', 'RP'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('photography', 'NN'),
#   ('.', '.')],
#  [('writer', 'NN'),
#   ('director', 'NN'),
#   ('burger', 'NN'),
#   ('imaginatively', 'RB'),
#   ('fans', 'VBZ'),
#   ('the', 'DT'),
#   ('embers', 'NNS'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('dormant', 'JJ'),
#   ('national', 'JJ'),
#   ('grief', 'NN'),
#   ('and', 'CC'),
#   ('curiosity', 'NN'),
#   ('that', 'WDT'),
#   ('has', 'VBZ'),
#   ('calcified', 'VBN'),
#   ('into', 'IN'),
#   ('chronic', 'JJ'),
#   ('cynicism', 'NN'),
#   ('and', 'CC'),
#   ('fear', 'NN'),
#   ('.', '.')],
#  [('.', '.'),
#   ('.', '.'),
#   ('.', '.'),
#   ('a', 'DT'),
#   ('roller', 'NN'),
#   ('coaster', 'NN'),
#   ('ride', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('movie', 'NN')],
#  [('i', 'VB'),
#   ('enjoyed', 'JJ'),
#   ('time', 'NN'),
#   ('of', 'IN'),
#   ('favor', 'NN'),
#   ('while', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('watching', 'VBG'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('surprised', 'VBN'),
#   ('at', 'IN'),
#   ('how', 'WRB'),
#   ('quickly', 'RB'),
#   ('it', 'PRP'),
#   ('faded', 'VBD'),
#   ('from', 'IN'),
#   ('my', 'PRP$'),
#   ('memory', 'NN'),
#   ('.', '.')],
#  [('chicago', 'NN'),
#   ('is', 'VBZ'),
#   ('sophisticated', 'JJ'),
#   (',', ','),
#   ('brash', 'JJ'),
#   (',', ','),
#   ('sardonic', 'JJ'),
#   (',', ','),
#   ('completely', 'RB'),
#   ('joyful', 'JJ'),
#   ('in', 'IN'),
#   ('its', 'PRP$'),
#   ('execution', 'NN'),
#   ('.', '.')],
#  [('steve', 'NN'),
#   ('irwin', 'NN'),
#   ('s', 'NN'),
#   ('method', 'NN'),
#   ('is', 'VBZ'),
#   ('ernest', 'JJS'),
#   ('hemmingway', 'NN'),
#   ('at', 'IN'),
#   ('accelerated', 'VBN'),
#   ('speed', 'NN'),
#   ('and', 'CC'),
#   ('volume', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('refreshing', 'JJ'),
#   ('korean', 'JJ'),
#   ('film', 'NN'),
#   ('about', 'IN'),
#   ('five', 'CD'),
#   ('female', 'JJ'),
#   ('high', 'JJ'),
#   ('school', 'NN'),
#   ('friends', 'NNS'),
#   ('who', 'WP'),
#   ('face', 'VBP'),
#   ('an', 'DT'),
#   ('uphill', 'JJ'),
#   ('battle', 'NN'),
#   ('when', 'WRB'),
#   ('they', 'PRP'),
#   ('try', 'VBP'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('their', 'PRP$'),
#   ('relationships', 'NNS'),
#   ('into', 'IN'),
#   ('deeper', 'JJ'),
#   ('waters', 'NNS'),
#   ('.', '.')],
#  [('on', 'IN'),
#   ('the', 'DT'),
#   ('surface', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('s', 'VBD'),
#   ('a', 'DT'),
#   ('lovers', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('run', 'NN'),
#   ('crime', 'NN'),
#   ('flick', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('in', 'IN'),
#   ('common', 'JJ'),
#   ('with', 'IN'),
#   ('piesiewicz', 'JJ'),
#   ('s', 'NN'),
#   ('and', 'CC'),
#   ('kieslowski', 'VB'),
#   ('s', 'NN'),
#   ('earlier', 'RBR'),
#   ('work', 'NN'),
#   (',', ','),
#   ('films', 'NNS'),
#   ('like', 'IN'),
#   ('the', 'DT'),
#   ('double', 'JJ'),
#   ('life', 'NN'),
#   ('of', 'IN'),
#   ('veronique', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('values', 'NNS'),
#   ('that', 'WDT'),
#   ('have', 'VBP'),
#   ('held', 'VBN'),
#   ('the', 'DT'),
#   ('enterprise', 'NN'),
#   ('crew', 'NN'),
#   ('together', 'RB'),
#   ('through', 'IN'),
#   ('previous', 'JJ'),
#   ('adventures', 'NNS'),
#   ('and', 'CC'),
#   ('perils', 'NNS'),
#   ('do', 'VBP'),
#   ('so', 'RB'),
#   ('again', 'RB'),
#   ('courage', 'NN'),
#   (',', ','),
#   ('self', 'JJ'),
#   ('sacrifice', 'NN'),
#   ('and', 'CC'),
#   ('patience', 'NN'),
#   ('under', 'IN'),
#   ('pressure', 'NN'),
#   ('.', '.')],
#  [('if', 'IN'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('possible', 'JJ'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('sequel', 'NN'),
#   ('to', 'TO'),
#   ('outshine', 'VB'),
#   ('the', 'DT'),
#   ('original', 'JJ'),
#   (',', ','),
#   ('then', 'RB'),
#   ('sl2', 'NN'),
#   ('does', 'VBZ'),
#   ('just', 'RB'),
#   ('that', 'DT'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('romantic', 'JJ'),
#   ('comedy', 'NN'),
#   ('that', 'IN'),
#   ('operates', 'VBZ'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('rules', 'NNS'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('own', 'JJ'),
#   ('self', 'NN'),
#   ('contained', 'VBN'),
#   ('universe', 'NN'),
#   ('.', '.')],
#  [('4', 'CD'),
#   ('friends', 'NNS'),
#   (',', ','),
#   ('2', 'CD'),
#   ('couples', 'NNS'),
#   (',', ','),
#   ('2000', 'CD'),
#   ('miles', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('pabst', 'NN'),
#   ('blue', 'JJ'),
#   ('ribbon', 'NN'),
#   ('beer', 'NN'),
#   ('they', 'PRP'),
#   ('can', 'MD'),
#   ('drink', 'VB'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('the', 'DT'),
#   ('ultimate', 'JJ'),
#   ('redneck', 'NN'),
#   ('road', 'NN'),
#   ('trip', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('film', 'NN'),
#   ('is', 'VBZ'),
#   ('often', 'RB'),
#   ('filled', 'VBN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('sense', 'NN'),
#   ('of', 'IN'),
#   ('pure', 'JJ'),
#   ('wonderment', 'NN'),
#   ('and', 'CC'),
#   ('excitement', 'NN'),
#   ('not', 'RB'),
#   ('often', 'RB'),
#   ('seen', 'VBN'),
#   ('in', 'IN'),
#   ('today', 'NN'),
#   ('s', 'VBP'),
#   ('cinema', 'NN'),
#   ('du', 'NN'),
#   ('sarcasm', 'NN')],
#  [('it', 'PRP'),
#   ('might', 'MD'),
#   ('be', 'VB'),
#   ('tempting', 'VBG'),
#   ('to', 'TO'),
#   ('regard', 'VB'),
#   ('mr', 'NN'),
#   ('.', '.'),
#   ('andrew', 'NN'),
#   ('and', 'CC'),
#   ('his', 'PRP$'),
#   ('collaborators', 'NNS'),
#   ('as', 'IN'),
#   ('oddballs', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('mr', 'NN'),
#   ('.', '.'),
#   ('earnhart', 'VB'),
#   ('s', 'JJ'),
#   ('quizzical', 'JJ'),
#   (',', ','),
#   ('charming', 'VBG'),
#   ('movie', 'NN'),
#   ('allows', 'VBZ'),
#   ('us', 'PRP'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('them', 'PRP'),
#   (',', ','),
#   ('finally', 'RB'),
#   (',', ','),
#   ('as', 'IN'),
#   ('artists', 'NNS'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('sense', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('term', 'NN'),
#   ('.', '.')],
#  [('edited', 'VBN'),
#   ('and', 'CC'),
#   ('shot', 'VBN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('syncopated', 'JJ'),
#   ('style', 'NN'),
#   ('mimicking', 'VBG'),
#   ('the', 'DT'),
#   ('work', 'NN'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('subjects', 'NNS'),
#   (',', ','),
#   ('pray', 'NN'),
#   ('turns', 'VBZ'),
#   ('the', 'DT'),
#   ('idea', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('documentary', 'NN'),
#   ('on', 'IN'),
#   ('its', 'PRP$'),
#   ('head', 'NN'),
#   (',', ','),
#   ('making', 'VBG'),
#   ('it', 'PRP'),
#   ('rousing', 'VBG'),
#   (',', ','),
#   ('invigorating', 'VBG'),
#   ('fun', 'NN'),
#   ('lacking', 'VBG'),
#   ('any', 'DT'),
#   ('mtv', 'JJ'),
#   ('puffery', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('mostly', 'RB'),
#   ('intelligent', 'JJ'),
#   (',', ','),
#   ('engrossing', 'VBG'),
#   ('and', 'CC'),
#   ('psychologically', 'RB'),
#   ('resonant', 'JJ'),
#   ('suspenser', 'NN'),
#   ('.', '.')],
#  [('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('this', 'DT'),
#   ('memory', 'NN'),
#   ('as', 'IN'),
#   ('identity', 'NN'),
#   ('obviation', 'NN'),
#   ('that', 'WDT'),
#   ('gives', 'VBZ'),
#   ('secret', 'JJ'),
#   ('life', 'NN'),
#   ('its', 'PRP$'),
#   ('intermittent', 'JJ'),
#   ('unease', 'NN'),
#   (',', ','),
#   ('reaffirming', 'VBG'),
#   ('that', 'IN'),
#   ('long', 'RB'),
#   ('held', 'VBN'),
#   ('illusions', 'NNS'),
#   ('are', 'VBP'),
#   ('indeed', 'RB'),
#   ('reality', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('that', 'IN'),
#   ('erasing', 'VBG'),
#   ('them', 'PRP'),
#   ('recasts', 'VBZ'),
#   ('the', 'DT'),
#   ('self', 'NN'),
#   ('.', '.')],
#  [('hip', 'NN'),
#   ('hop', 'NN'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('history', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('it', 'PRP'),
#   ('s', 'VBD'),
#   ('a', 'DT'),
#   ('metaphor', 'NN'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ('love', 'NN'),
#   ('story', 'NN'),
#   ('.', '.')],
#  [('in', 'IN'),
#   ('scope', 'NN'),
#   (',', ','),
#   ('ambition', 'NN'),
#   ('and', 'CC'),
#   ('accomplishment', 'NN'),
#   (',', ','),
#   ('children', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('century', 'NN'),
#   ('.', '.'),
#   ('.', '.'),
#   ('.', '.'),
#   ('takes', 'VBZ'),
#   ('kurys', 'JJ'),
#   ('', 'NNP'),
#   ('career', 'NN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('whole', 'JJ'),
#   ('new', 'JJ'),
#   ('level', 'NN'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('may', 'MD'),
#   ('not', 'RB'),
#   ('have', 'VB'),
#   ('the', 'DT'),
#   ('dramatic', 'JJ'),
#   ('gut', 'NN'),
#   ('wrenching', 'VBG'),
#   ('impact', 'NN'),
#   ('of', 'IN'),
#   ('other', 'JJ'),
#   ('holocaust', 'JJ'),
#   ('films', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('a', 'DT'),
#   ('compelling', 'JJ'),
#   ('story', 'NN'),
#   (',', ','),
#   ('mainly', 'RB'),
#   ('because', 'IN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('it', 'PRP'),
#   ('s', 'VBD'),
#   ('told', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('who', 'WP'),
#   ('were', 'VBD'),
#   ('there', 'RB'),
#   ('.', '.')],
#  [('between', 'IN'),
#   ('the', 'DT'),
#   ('drama', 'NN'),
#   ('of', 'IN'),
#   ('cube', 'NN'),
#   ('?', '.'),
#   ('s', 'JJ'),
#   ('personal', 'JJ'),
#   ('revelations', 'NNS'),
#   ('regarding', 'VBG'),
#   ('what', 'WP'),
#   ('the', 'DT'),
#   ('shop', 'NN'),
#   ('means', 'VBZ'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('big', 'JJ'),
#   ('picture', 'NN'),
#   (',', ','),
#   ('iconic', 'JJ'),
#   ('characters', 'NNS'),
#   ('gambol', 'VBP'),
#   ('fluidly', 'RB'),
#   ('through', 'IN'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   (',', ','),
#   ('with', 'IN'),
#   ('charming', 'JJ'),
#   ('results', 'NNS'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('gentle', 'NN'),
#   (',', ','),
#   ('compassionate', 'JJ'),
#   ('drama', 'NN'),
#   ('about', 'IN'),
#   ('grief', 'NN'),
#   ('and', 'CC'),
#   ('healing', 'NN'),
#   ('.', '.')],
#  [('somewhere', 'RB'),
#   ('short', 'JJ'),
#   ('of', 'IN'),
# ...
#   ('comes', 'VBZ'),
#   ('alive', 'JJ'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('attention', 'NN'),
#   ('from', 'IN'),
#   ('two', 'CD'),
#   ('strangers', 'NNS'),
#   ('in', 'IN'),
#   ('town', 'NN'),
#   ('with', 'IN'),
#   ('honest', 'JJ'),
#   ('performances', 'NNS'),
#   ('and', 'CC'),
#   ('realistic', 'JJ'),
#   ('interaction', 'NN'),
#   ('between', 'IN'),
#   ('the', 'DT'),
#   ('characters', 'NNS'),
#   (',', ','),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('coming', 'VBG'),
#   ('of', 'IN'),
#   ('age', 'NN'),
#   ('story', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('twist', 'NN'),
#   ('.', '.')],
#  [('there', 'EX'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('much', 'JJ'),
#   ('puzzlement', 'NN'),
#   ('among', 'IN'),
#   ('critics', 'NNS'),
#   ('about', 'IN'),
#   ('what', 'WP'),
#   ('the', 'DT'),
#   ('election', 'NN'),
#   ('symbolizes', 'VBZ'),
#   ('.', '.'),
#   ('i', 'VB'),
#   ('believe', 'VBP'),
#   ('the', 'DT'),
#   ('message', 'NN'),
#   ('is', 'VBZ'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('messenger', 'NN'),
#   (':', ':'),
#   ('the', 'DT'),
#   ('agent', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('woman', 'NN'),
#   ('.', '.')],
#  [('an', 'DT'),
#   ('enjoyable', 'JJ'),
#   ('film', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('family', 'NN'),
#   (',', ','),
#   ('amusing', 'VBG'),
#   ('and', 'CC'),
#   ('cute', 'NN'),
#   ('for', 'IN'),
#   ('both', 'DT'),
#   ('adults', 'NNS'),
#   ('and', 'CC'),
#   ('kids', 'NNS'),
#   ('.', '.')],
#  [('``', '``'),
#   ('the', 'DT'),
#   ('mothman', 'NN'),
#   ('prophecies', 'VBZ'),
#   ('``', '``'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('difficult', 'JJ'),
#   ('film', 'NN'),
#   ('to', 'TO'),
#   ('shake', 'VB'),
#   ('from', 'IN'),
#   ('your', 'PRP$'),
#   ('conscience', 'NN'),
#   ('when', 'WRB'),
#   ('night', 'NN'),
#   ('falls', 'VBZ'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('second', 'JJ'),
#   ('chapter', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('harry', 'NN'),
#   ('potter', 'NN'),
#   ('series', 'NN'),
#   ('is', 'VBZ'),
#   ('even', 'RB'),
#   ('more', 'RBR'),
#   ('magical', 'JJ'),
#   ('than', 'IN'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('and', 'CC'),
#   ('simply', 'RB'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('family', 'NN'),
#   ('film', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('more', 'RBR'),
#   ('honest', 'JJS'),
#   ('about', 'IN'),
#   ('alzheimer', 'NN'),
#   ('s', 'NN'),
#   ('disease', 'NN'),
#   (',', ','),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   (',', ','),
#   ('than', 'IN'),
#   ('iris', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('acting', 'VBG'),
#   ('alone', 'NN'),
#   ('is', 'VBZ'),
#   ('worth', 'IN'),
#   ('the', 'DT'),
#   ('price', 'NN'),
#   ('of', 'IN'),
#   ('admission', 'NN'),
#   ('.', '.')],
#  [('an', 'DT'),
#   ('excellent', 'JJ'),
#   ('romp', 'NN'),
#   ('that', 'WDT'),
#   ('boasts', 'VBZ'),
#   ('both', 'DT'),
#   ('a', 'DT'),
#   ('heart', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('mind', 'NN'),
#   ('.', '.')],
#  [('interacting', 'VBG'),
#   ('eyeball', 'DT'),
#   ('to', 'TO'),
#   ('eyeball', 'VB'),
#   ('and', 'CC'),
#   ('toe', 'VB'),
#   ('to', 'TO'),
#   ('toe', 'VB'),
#   (',', ','),
#   ('hopkins', 'NNS'),
#   ('and', 'CC'),
#   ('norton', 'NN'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('winning', 'JJ'),
#   ('combination', 'NN'),
#   ('but', 'CC'),
#   ('fiennes', 'NNS'),
#   ('steals', 'NNS'),
#   ('red', 'VBD'),
#   ('dragon', 'NN'),
#   ('', 'RB'),
#   ('right', 'RB'),
#   ('from', 'IN'),
#   ('under', 'IN'),
#   ('their', 'PRP$'),
#   ('noses', 'NNS'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('terrific', 'JJ'),
#   ('character', 'NN'),
#   ('study', 'NN'),
#   (',', ','),
#   ('a', 'DT'),
#   ('probe', 'NN'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('life', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('complex', 'JJ'),
#   ('man', 'NN'),
#   ('.', '.')],
#  [('impresses', 'NNS'),
#   ('you', 'PRP'),
#   ('with', 'IN'),
#   ('its', 'PRP$'),
#   ('open', 'JJ'),
#   ('endedness', 'NN'),
#   ('and', 'CC'),
#   ('surprises', 'NNS'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ("n't", 'RB'),
#   ('a', 'DT'),
#   ('narrative', 'JJ'),
#   ('film', 'NN'),
#   ('i', 'NNS'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('possible', 'JJ'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('a', 'DT'),
#   ('narrative', 'JJ'),
#   ('film', 'NN'),
#   ('about', 'IN'),
#   ('september', 'NN'),
#   ('11th', 'CD'),
#   (',', ','),
#   ('though', 'IN'),
#   ('i', 'JJ'),
#   ('m', 'VBP'),
#   ('sure', 'JJ'),
#   ('some', 'DT'),
#   ('will', 'MD'),
#   ('try', 'VB'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('as', 'RB'),
#   ('close', 'JJ'),
#   ('as', 'IN'),
#   ('anyone', 'NN'),
#   ('has', 'VBZ'),
#   ('dared', 'VBN'),
#   ('to', 'TO'),
#   ('come', 'VB'),
#   ('.', '.')],
#  [('my', 'PRP$'),
#   ('oh', 'JJ'),
#   ('my', 'PRP$'),
#   (',', ','),
#   ('is', 'VBZ'),
#   ('this', 'DT'),
#   ('an', 'DT'),
#   ('invigorating', 'NN'),
#   (',', ','),
#   ('electric', 'JJ'),
#   ('movie', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('two', 'CD'),
#   ('leads', 'NNS'),
#   ('chomp', 'VBP'),
#   ('considerably', 'RB'),
#   ('more', 'RBR'),
#   ('scenery', 'JJ'),
#   ('with', 'IN'),
#   ('their', 'PRP$'),
#   ('acting', 'NN'),
#   ('than', 'IN'),
#   ('fire', 'NN'),
#   ('breathing', 'NN'),
#   ('monsters', 'NNS'),
#   ('barbecue', 'VBP'),
#   ('with', 'IN'),
#   ('their', 'PRP$'),
#   ('breath', 'NN'),
#   ('.', '.'),
#   ('.', '.'),
#   ('.', '.')],
#  [('cedar', 'NN'),
#   ('takes', 'VBZ'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('open', 'JJ'),
#   ('minded', 'VBD'),
#   ('approach', 'NN'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('sensitive', 'JJ'),
#   ('material', 'NN'),
#   (',', ','),
#   ('showing', 'VBG'),
#   ('impressive', 'JJ'),
#   ('control', 'NN'),
#   (',', ','),
#   ('both', 'DT'),
#   ('visually', 'RB'),
#   ('and', 'CC'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('writing', 'NN'),
#   ('.', '.')],
#  [('never', 'RB'), ('once', 'RB'), ('predictable', 'JJ'), ('.', '.')],
#  [('biggie', 'NN'),
#   ('and', 'CC'),
#   ('tupac', 'NN'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('single', 'JJ'),
#   ('mindedly', 'RB'),
#   ('daring', 'VBG'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('puts', 'VBZ'),
#   ('far', 'RB'),
#   ('more', 'RBR'),
#   ('polished', 'JJ'),
#   ('documentaries', 'NNS'),
#   ('to', 'TO'),
#   ('shame', 'VB'),
#   ('.', '.')],
#  [('so', 'RB'),
#   ('many', 'JJ'),
#   ('documentaries', 'NNS'),
#   ('like', 'IN'),
#   ('this', 'DT'),
#   ('presuppose', 'JJ'),
#   ('religious', 'JJ'),
#   ('bigotry', 'NN'),
#   ('or', 'CC'),
#   ('zealous', 'JJ'),
#   ('nuttiness', 'NN'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('antagonists', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('family', 'NN'),
#   ('fundamentals', 'NNS'),
#   ('displays', 'VBZ'),
#   ('a', 'DT'),
#   ('rare', 'JJ'),
#   ('gift', 'NN'),
#   ('for', 'IN'),
#   ('unflinching', 'JJ'),
#   ('impartiality', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('cast', 'NN'),
#   ('is', 'VBZ'),
#   ('uniformly', 'JJ'),
#   ('excellent', 'JJ'),
#   ('and', 'CC'),
#   ('relaxed', 'JJ'),
#   ('.', '.')],
#  [('after', 'IN'),
#   ('making', 'VBG'),
#   ('several', 'JJ'),
#   ('adaptations', 'NNS'),
#   ('of', 'IN'),
#   ('other', 'JJ'),
#   ('writers', 'NNS'),
#   ('', 'VBP'),
#   ('work', 'NN'),
#   (',', ','),
#   ('armenian', 'JJ'),
#   ('canadian', 'JJ'),
#   ('director', 'NN'),
#   ('atom', 'NN'),
#   ('egoyan', 'NN'),
#   ('broached', 'VBD'),
#   ('an', 'DT'),
#   ('original', 'JJ'),
#   ('treatment', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('deeply', 'JJ'),
#   ('personal', 'JJ'),
#   ('subject', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('film', 'NN'),
#   ('is', 'VBZ'),
#   ('painfully', 'RB'),
#   ('authentic', 'JJ'),
#   (',', ','),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('performances', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('young', 'JJ'),
#   ('players', 'NNS'),
#   ('are', 'VBP'),
#   ('utterly', 'JJ'),
#   ('convincing', 'NN'),
#   ('.', '.')],
#  [('if', 'IN'),
#   ('it', 'PRP'),
#   ('seems', 'VBZ'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('minor', 'JJ'),
#   ('miracle', 'NN'),
#   ('that', 'IN'),
#   ('its', 'PRP$'),
#   ('septuagenarian', 'JJ'),
#   ('star', 'NN'),
#   ('is', 'VBZ'),
#   ('young', 'JJ'),
#   ('enough', 'RB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('the', 'DT'),
#   ('nonagenarian', 'JJ'),
#   ('filmmaker', 'NN'),
#   ('s', 'NN'),
#   ('son', 'NN'),
#   (',', ','),
#   ('more', 'RBR'),
#   ('incredible', 'JJ'),
#   ('still', 'RB'),
#   ('are', 'VBP'),
#   ('the', 'DT'),
#   ('clear', 'JJ'),
#   ('eyed', 'JJ'),
#   ('boldness', 'NN'),
#   ('and', 'CC'),
#   ('quiet', 'JJ'),
#   ('irony', 'NN'),
#   ('with', 'IN'),
#   ('which', 'WDT'),
#   ('actor', 'NN'),
#   ('and', 'CC'),
#   ('director', 'NN'),
#   ('take', 'VB'),
#   ('on', 'IN'),
#   ('life', 'NN'),
#   ('s', 'JJ'),
#   ('urgent', 'JJ'),
#   ('questions', 'NNS'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('candid', 'NN'),
#   ('and', 'CC'),
#   ('often', 'RB'),
#   ('fascinating', 'JJ'),
#   ('documentary', 'JJ'),
#   ('about', 'IN'),
#   ('a', 'DT'),
#   ('pentecostal', 'JJ'),
#   ('church', 'NN'),
#   ('in', 'IN'),
#   ('dallas', 'NN'),
#   ('that', 'IN'),
#   ('assembles', 'VBZ'),
#   ('an', 'DT'),
#   ('elaborate', 'JJ'),
#   ('haunted', 'VBN'),
#   ('house', 'NN'),
#   ('each', 'DT'),
#   ('year', 'NN'),
#   ('to', 'TO'),
#   ('scare', 'VB'),
#   ('teenagers', 'NNS'),
#   ('into', 'IN'),
#   ('attending', 'VBG'),
#   ('services', 'NNS'),
#   ('.', '.')],
#  [('fans', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('animated', 'JJ'),
#   ('wildlife', 'NN'),
#   ('adventure', 'NN'),
#   ('show', 'NN'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('in', 'IN'),
#   ('warthog', 'JJ'),
#   ('heaven', 'NN'),
#   (';', ':'),
#   ('others', 'NNS'),
#   ('need', 'VBP'),
#   ('not', 'RB'),
#   ('necessarily', 'RB'),
#   ('apply', 'VB'),
#   ('.', '.')],
#  [('without', 'IN'),
#   ('resorting', 'VBG'),
#   ('to', 'TO'),
#   ('hyperbole', 'VB'),
#   (',', ','),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('state', 'NN'),
#   ('that', 'IN'),
#   ('kissing', 'VBG'),
#   ('jessica', 'NN'),
#   ('stein', 'NN'),
#   ('may', 'MD'),
#   ('be', 'VB'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('same', 'JJ'),
#   ('sex', 'NN'),
#   ('romance', 'NN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('.', '.')],
#  [('nolan', 'NN'),
#   ('bravely', 'RB'),
#   ('treads', 'VBZ'),
#   ('where', 'WRB'),
#   ('few', 'JJ'),
#   ('american', 'JJ'),
#   ('films', 'NNS'),
#   ('dare', 'VBP'),
#   ('to', 'TO'),
#   ('delve', 'VB'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('of', 'IN'),
#   ('ambivalence', 'NN'),
#   ('and', 'CC'),
#   ('ambiguity', 'NN'),
#   ('.', '.'),
#   ('.', '.'),
#   ('.', '.')],
#  [('unlike', 'IN'),
#   ('the', 'DT'),
#   ('nauseating', 'JJ'),
#   ('fictions', 'NNS'),
#   ('peddled', 'VBN'),
#   ('by', 'IN'),
#   ('such', 'JJ'),
#   ('have', 'VBP'),
#   ('yourself', 'PRP'),
#   ('a', 'DT'),
#   ('happy', 'JJ'),
#   ('little', 'JJ'),
#   ('holocaust', 'JJ'),
#   ('', 'NN'),
#   ('movies', 'NNS'),
#   ('as', 'IN'),
#   ('life', 'NN'),
#   ('is', 'VBZ'),
#   ('beautiful', 'JJ'),
#   ('and', 'CC'),
#   ('jakob', 'VBZ'),
#   ('the', 'DT'),
#   ('liar', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('grey', 'NN'),
#   ('zone', 'NN'),
#   ('is', 'VBZ'),
#   ('honest', 'RB'),
#   ('enough', 'RB'),
#   ('to', 'TO'),
#   ('deny', 'VB'),
#   ('the', 'DT'),
#   ('possibility', 'NN'),
#   ('of', 'IN'),
#   ('hope', 'NN'),
#   ('in', 'IN'),
#   ('auschwitz', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('potent', 'JJ'),
#   ('allegorical', 'JJ'),
#   ('love', 'NN'),
#   ('story', 'NN'),
#   ('.', '.')],
#  [('even', 'RB'),
#   ('those', 'DT'),
#   ('who', 'WP'),
#   ('would', 'MD'),
#   ('like', 'VB'),
#   ('to', 'TO'),
#   ('dismiss', 'VB'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('outright', 'NN'),
#   ('should', 'MD'),
#   ('find', 'VB'),
#   ('much', 'JJ'),
#   ('to', 'TO'),
#   ('mull', 'VB'),
#   ('and', 'CC'),
#   ('debate', 'VB'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('cool', 'JJ'),
#   (',', ','),
#   ('slick', 'JJ'),
#   ('stuff', 'NN'),
#   (',', ','),
#   ('ready', 'JJ'),
#   ('to', 'TO'),
#   ('quench', 'VB'),
#   ('the', 'DT'),
#   ('thirst', 'NN'),
#   ('of', 'IN'),
#   ('an', 'DT'),
#   ('audience', 'NN'),
#   ('that', 'WDT'),
#   ('misses', 'VBZ'),
#   ('the', 'DT'),
#   ('summer', 'NN'),
#   ('blockbusters', 'NNS'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('full', 'JJ'),
#   ('of', 'IN'),
#   ('fine', 'JJ'),
#   ('performances', 'NNS'),
#   (',', ','),
#   ('led', 'VBN'),
#   ('by', 'IN'),
#   ('josef', 'NN'),
#   ('bierbichler', 'NN'),
#   ('as', 'IN'),
#   ('brecht', 'NN'),
#   ('and', 'CC'),
#   ('monica', 'NN'),
#   ('bleibtreu', 'NN'),
#   ('as', 'IN'),
#   ('helene', 'NN'),
#   ('weigel', 'NN'),
#   (',', ','),
#   ('his', 'PRP$'),
#   ('wife', 'NN'),
#   ('.', '.')],
#  [('a', 'DT'),
#   ('captivating', 'NN'),
#   ('cross', 'NN'),
#   ('cultural', 'JJ'),
#   ('comedy', 'NN'),
#   ('of', 'IN'),
#   ('manners', 'NNS'),
#   ('.', '.')],
#  [('andy', 'JJ'),
#   ('garcia', 'NN'),
#   ('enjoys', 'VBZ'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('richest', 'JJS'),
#   ('roles', 'NNS'),
#   ('in', 'IN'),
#   ('years', 'NNS'),
#   ('and', 'CC'),
#   ('mick', 'JJ'),
#   ('jagger', 'NN'),
#   ('gives', 'VBZ'),
#   ('his', 'PRP$'),
#   ('best', 'JJS'),
#   ('movie', 'NN'),
#   ('performance', 'NN'),
#   ('since', 'IN'),
#   (',', ','),
#   ('well', 'UH'),
#   (',', ','),
#   ('performance', 'NN'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ("n't", 'RB'),
#   ('always', 'RB'),
#   ('easy', 'VB'),
#   ('to', 'TO'),
#   ('look', 'VB'),
#   ('at', 'IN'),
#   ('.', '.'),
#   ('but', 'CC'),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('indeed', 'RB'),
#   ('a', 'DT'),
#   ('duty', 'NN'),
#   ('of', 'IN'),
#   ('art', 'NN'),
#   ('to', 'TO'),
#   ('reflect', 'VB'),
#   ('life', 'NN'),
#   (',', ','),
#   ('than', 'IN'),
#   ('leigh', 'NN'),
#   ('has', 'VBZ'),
#   ('created', 'VBN'),
#   ('a', 'DT'),
#   ('masterful', 'JJ'),
#   ('piece', 'NN'),
#   ('of', 'IN'),
#   ('artistry', 'NN'),
#   ('right', 'NN'),
#   ('here', 'RB'),
#   ('.', '.')],
#  [('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('[', 'JJ'),
#   ('ricci', 'NN'),
#   ('s', 'NN'),
#   (']', 'NNP'),
#   ('best', 'JJS'),
#   ('work', 'NN'),
#   ('yet', 'RB'),
#   (',', ','),
#   ('this', 'DT'),
#   ('girl', 'JJ'),
#   ('woman', 'NN'),
#   ('who', 'WP'),
#   ('sincerely', 'RB'),
#   ('believes', 'VBZ'),
#   ('she', 'PRP'),
#   ('can', 'MD'),
#   ('thwart', 'VB'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('s', 'NN'),
#   ('misery', 'NN'),
#   ('with', 'IN'),
#   ('blind', 'NN'),
#   ('good', 'JJ'),
#   ('will', 'MD'),
#   ('.', '.')],
#  [('highlights', 'NNS'),
#   ('are', 'VBP'),
#   ('the', 'DT'),
#   ('terrific', 'JJ'),
#   ('performances', 'NNS'),
#   ('by', 'IN'),
#   ('christopher', 'JJR'),
#   ('plummer', 'NN'),
#   (',', ','),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('prime', 'JJ'),
#   ('villain', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('nathan', 'RB'),
#   ('lane', 'NN'),
#   ('as', 'IN'),
#   ('vincent', 'NN'),
#   ('crummles', 'NNS'),
#   (',', ','),
#   ('the', 'DT'),
#   ('eccentric', 'JJ'),
#   ('theater', 'NN'),
#   ('company', 'NN'),
#   ('manager', 'NN'),
#   ('.', '.')],
#  [('[', 'RB'),
#   ('howard', 'JJ'),
#   (']', 'NNP'),
#   ('so', 'RB'),
#   ('good', 'JJ'),
#   ('as', 'IN'),
#   ('leon', 'NN'),
#   ('barlow', 'NN'),
#   ('.', '.'),
#   ('.', '.'),
#   ('.', '.'),
#   ('that', 'IN'),
#   ('he', 'PRP'),
#   ('hardly', 'RB'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('acting', 'VBG'),
#   ('.', '.')],
#  [('an', 'DT'),
#   ('uplifting', 'NN'),
#   (',', ','),
#   ('near', 'IN'),
#   ('masterpiece', 'NN'),
#   ('.', '.')],
#  [('superior', 'JJ'),
#   ('genre', 'NN'),
#   ('storytelling', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('gets', 'VBZ'),
#   ('under', 'IN'),
#   ('our', 'PRP$'),
#   ('skin', 'NN'),
#   ('simply', 'RB'),
#   ('by', 'IN'),
#   ('crossing', 'VBG'),
#   ('the', 'DT'),
#   ('nuclear', 'JJ'),
#   ('line', 'NN'),
#   ('.', '.')],
#  [('by', 'IN'),
#   ('taking', 'VBG'),
#   ('entertainment', 'NN'),
#   ('tonight', 'NN'),
#   ('subject', 'JJ'),
#   ('matter', 'NN'),
#   ('and', 'CC'),
#   ('giving', 'VBG'),
#   ('it', 'PRP'),
#   ('humor', 'NN'),
#   ('and', 'CC'),
#   ('poignancy', 'NN'),
#   (',', ','),
#   ('auto', 'NN'),
#   ('focus', 'NN'),
#   ('becomes', 'VBZ'),
#   ('both', 'DT'),
#   ('gut', 'JJ'),
#   ('bustingly', 'RB'),
#   ('funny', 'JJ'),
#   ('and', 'CC'),
#   ('crushingly', 'RB'),
#   ('depressing', 'JJ'),
#   ('.', '.')],
#  [('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('a', 'DT'),
#   ('bittersweet', 'NN'),
#   ('and', 'CC'),
#   ('lyrical', 'JJ'),
#   ('mix', 'NN'),
#   ('of', 'IN'),
#   ('elements', 'NNS'),
#   ('.', '.')],
#  [('subversive', 'JJ'),
#   (',', ','),
#   ('meditative', 'JJ'),
#   (',', ','),
#   ('clinical', 'JJ'),
#   ('and', 'CC'),
#   ('poetic', 'JJ'),
#   (',', ','),
#   ('the', 'DT'),
#   ('piano', 'NN'),
#   ('teacher', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('daring', 'VBG'),
#   ('work', 'NN'),
#   ('of', 'IN'),
#   ('genius', 'NN'),
#   ('.', '.')],
#  ...]

# %%
# Find POS tags for OOV words
oov_words_pos = {}
for oov_word in oov_words:
    # Find all possible POS for OOV word
    pos_tags = []
    for sentence_pos in train_dataset_pos:
        for word, pos in sentence_pos:
            if word == oov_word:
                pos_tags.append(pos)
    # # Assign
    oov_words_pos[oov_word] = pos_tags

# %%
oov_words_pos
# Out:
# {'1899.': ['CD'],
#  '1952.': ['CD'],
#  '1975.': ['CD'],
#  '1995.': ['CD'],
#  '2002.': ['CD', 'CD'],
#  '28k': ['CD', 'CD'],
#  '5ths': ['CD', 'CD'],
#  '8217': ['CD', 'CD'],
#  'abandone': ['NN'],
#  'aborbing': ['VBG'],
#  'absolutamente': ['NN'],
#  'aburrido': ['NN'],
#  'acabamos': ['NN'],
#  'accomodates': ['VBZ'],
#  'aceitou': ['NN'],
#  'achival': ['JJ'],
#  'achronological': ['NN', 'JJ'],
#  'acidically': ['RB'],
#  'acontecimentos': ['NNS'],
#  'actorious': ['JJ'],
#  'actorish': ['JJ'],
#  'actory': ['JJ'],
#  'actuación': ['FW'],
#  'actuada': ['NN', 'JJ'],
#  'addessi': ['NN', 'RB'],
#  'adorability': ['NN', 'NN'],
#  'adventues': ['NNS'],
#  'affirmational': ['JJ'],
#  "ain't": ['IN'],
#  'alientation': ['NN', 'NN'],
#  'allodi': ['JJ', 'RB'],
#  'amoses': ['NNS', 'NNS'],
#  'amusedly': ['RB'],
#  'andamento': ['NN'],
#  'animé': ['JJ', 'NN'],
#  'anteing': ['VBG'],
#  'apallingly': ['RB'],
#  'apesar': ['NN'],
#  'aproveitar': ['NN'],
#  'aqueles': ['NNS'],
#  "aren't": ['JJ'],
#  'arriesgado': ['FW'],
#  'artnering': ['VBG'],
#  'artsploitation': ['NN'],
#  'artístico': ['JJ'],
#  'assistir': ['IN'],
#  'atacar': ['NN'],
#  'atacarse': ['JJ'],
#  'atreve': ['VBP'],
#  'auteil': ['NN', 'JJ', 'NN', 'NN'],
#  'autocritique': ['NN'],
#  'awakener': ['NN'],
#  'b+': ['NN'],
#  'bazadona': ['NN', 'NN'],
#  'bergmanesque': ['JJ'],
#  'beseechingly': ['RB'],
#  'bibbidy': ['NN'],
#  'bierbichler': ['NN'],
#  'birot': ['NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN'],
#  'bizzarre': ['JJ'],
#  'bjorkness': ['NN'],
#  'blighter': ['NN'],
#  'blutarsky': ['NN'],
#  'bobbidi': ['NN'],
#  'bondish': ['JJ'],
#  'bornin': ['NN'],
#  'bottomlessly': ['RB'],
#  'bruckheimeresque': ['JJ'],
#  'brûlée': ['NN', 'NN'],
#  "bull's": ['NN'],
#  'burningly': ['RB'],
#  'bustingly': ['RB'],
#  'butterfingered': ['VBN', 'VBN'],
#  'cadness': ['NN'],
#  "cam'ron": ['NN'],
#  'camareras': ['NNS'],
#  'cannier': ['JJR'],
#  'captivatingly': ['RB'],
#  'capturou': ['NN'],
#  'carefreeness': ['NN', 'NN'],
#  'carente': ['NN'],
#  'caricatural': ['JJ'],
#  'cativante': ['NN'],
#  'certamente': ['NN'],
#  'chabrolian': ['JJ'],
#  'chopsocky': ['JJ'],
#  'choquart': ['NN', 'NN'],
#  'cineasts': ['NNS'],
#  'cinemantic': ['JJ'],
#  'ciphered': ['JJ'],
#  'cipherlike': ['NN'],
#  'cirulnick': ['NN'],
#  'claptraps': ['NNS'],
#  'claustrophic': ['JJ'],
#  'clericks': ['NNS'],
#  'cletis': ['NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN'],
#  'clichês': ['NN'],
#  'clutchy': ['NN'],
#  'collinswood': ['NN'],
#  'collosum': ['NN'],
#  'colocar': ['NN'],
#  'colonics': ['NNS'],
#  'colosal': ['NN'],
#  'começamos': ['VB'],
#  'compleja': ['NN'],
#  'complejos': ['NN'],
#  'complementares': ['NNS'],
#  'condensada': ['NN'],
#  'confusedred': ['VBN'],
#  'conmovedora': ['NN'],
#  'consegue': ['NN', 'NN'],
#  'constatação': ['NN'],
#  'contando': ['NN'],
#  'contemplarse': ['FW'],
#  'continuação': ['NN'],
#  'contructed': ['JJ'],
#  'contrária': ['NNS'],
#  'convencional': ['NN'],
#  'copmovieland': ['NN', 'NN'],
#  'coriat': ['NN', 'NN'],
#  'corniest': ['JJS'],
#  'corpse—stays': ['VBZ'],
#  'corruscating': ['VBG'],
#  'costumey': ['NN'],
#  'covardia': ['NN'],
#  'crappola': ['NN'],
#  'creepyness': ['NN'],
#  'criar': ['NN'],
#  'crowdpleaser': ['NN'],
#  'crummles': ['NNS', 'NNS'],
#  'csoka': ['NN'],
#  'culminando': ['NN'],
#  'daneses': ['NNS'],
#  'datedness': ['NN'],
#  'dateflick': ['NN'],
#  'deadeningly': ['RB'],
#  'debuter': ['NN'],
#  'decasia': ['NN', 'NN'],
#  'decidiram': ['JJ'],
#  'decirles': ['VBZ'],
#  'defeatingly': ['RB'],
#  'delibrately': ['RB'],
#  'delicia': ['NN'],
#  'demencial': ['JJ'],
#  'democracie': ['NN'],
#  'denlopp': ['VBP', 'NN'],
#  'derivativeness': ['NN'],
#  'desaponta': ['NN'],
#  'desarrollarse': ['NN'],
#  'desee': ['NN'],
#  'deseos': ['NN'],
#  'desfecho': ['NN'],
#  'desnudo': ['NN'],
#  'destinees': ['NNS'],
#  'deutchland': ['VB', 'VB'],
#  'diciness': ['NN'],
#  'diferença': ['NN'],
#  'digno': ['NN'],
#  'direto': ['NN'],
#  'diretor': ['NN'],
#  'direção': ['VB', 'NN'],
#  'disfrutable': ['JJ'],
#  'disposible': ['JJ'],
#  'divertida': ['NN', 'NN', 'VBP', 'NN'],
#  'divertingly': ['RB'],
#  'djeinaba': ['JJ', 'NN'],
#  'document—its': ['NNS'],
#  'does—but': ['IN'],
#  'dogwalker': ['NN'],
#  'dominatrixes': ['NNS', 'NNS'],
#  "don't": ['RB'],
#  'dooper': ['NN'],
#  'dramatisms': ['NNS'],
#  'dreadfulness': ['NN'],
#  'drecks': ['NNS'],
#  'drek': ['NN'],
#  'dridi': ['NN'],
#  'drippiness': ['NN'],
#  'dudds': ['NN'],
#  'dudsville': ['JJ'],
#  'dullingly': ['RB'],
#  'dumbfoundingly': ['RB'],
#  'duración': ['NN'],
#  'dysfunctionally': ['RB'],
#  'dès': ['NN'],
#  'efteriades': ['NNS'],
#  'elegiacally': ['RB'],
#  'elemento': ['FW', 'IN'],
#  'emocionalmente': ['FW'],
#  'emocionante': ['NN'],
#  'emotiva': ['FW'],
#  'emptily': ['RB'],
#  'enamoring': ['VBG'],
#  'enfrentados': ['FW'],
#  'enfrentará': ['NN'],
#  'engaña': ['NN'],
#  'enrapturing': ['VBG'],
#  'enternecedora': ['NN'],
#  'entretenida': ['NN'],
#  'entreter': ['NN'],
#  'entretiene': ['FW'],
#  'então': ['JJ'],
#  'enviará': ['NN'],
#  'episódio': ['NN'],
#  'equlibrium': ['NN', 'NN'],
#  'eroti': ['NN'],
#  'escapa': ['NN'],
#  'esfera': ['JJ'],
#  'esforço': ['NN'],
#  'espectáculo': ['JJ'],
#  'espetáculo': ['VBP'],
#  'espite': ['VBZ'],
#  'esquerdo': ['NN'],
#  'estafeta': ['VBZ'],
#  'estava': ['NN'],
#  'esteticamente': ['NN'],
#  'estranhos': ['NN'],
#  'estudo': ['NN'],
#  'estupendamente': ['NN'],
#  'everlyn': ['NN'],
#  'evolução': ['VBP'],
#  'excrescence': ['NN'],
#  'exhilarate': ['NN'],
#  'exibi': ['FW'],
#  'existência': ['NN'],
#  'explicados': ['NN'],
#  'exporing': ['VBG'],
#  'expresar': ['NN'],
#  'fabulosity': ['NN'],
#  'fantasti': ['JJ'],
#  'fascinantes': ['NNS'],
#  'fashionedness': ['NN'],
#  'fato': ['NN', 'NN'],
#  'feardotcom': ['NN', 'NN', 'NN', 'NN', 'NN', 'NN'],
#  'felinni': ['VB', 'NNS'],
#  'fillm': ['NN'],
#  'film—i': ['NN'],
#  'fizzability': ['NN'],
#  'flakeball': ['NN'],
#  'flatula': ['NN', 'NN'],
#  'flck': ['VBP'],
#  'fluxing': ['VBG'],
#  'forgettably': ['RB'],
#  'francamente': ['NN'],
#  'frissons': ['NNS', 'NNS'],
#  'frustrado': ['NN'],
#  'fuddled': ['VBN'],
#  'fuhgeddaboutit': ['JJ'],
#  "fun's": ['JJ'],
#  'funcionar': ['NN'],
#  'fustily': ['RB'],
#  'fílmica': ['NN'],
#  'gabbiest': ['NN'],
#  'ganha': ['NN'],
#  'gantzes': ['JJ'],
#  'gasm': ['NN', 'NN'],
#  'gaï': ['NN', 'NN'],
#  'gerbosi': ['NN', 'NN'],
#  'glizty': ['NN'],
#  'gooeyness': ['VB'],
#  'goombah': ['NN', 'FW'],
#  'gorefests': ['NNS'],
#  'gosto': ['NN'],
#  'grandiosa': ['VBP'],
#  'grato': ['NN'],
#  'graças': ['NN'],
#  'greaseballs': ['NNS'],
#  'greasiest': ['JJS'],
#  'guessable': ['JJ', 'JJ'],
#  'guión': ['NN'],
#  'gutterball': ['NN'],
#  'gymkata': ['NNS', 'NN'],
#  'halfwit': ['NN'],
#  'hamfisted': ['JJ'],
#  'hammily': ['RB'],
#  'hanewe': ['NN'],
#  'haphazardness': ['NN'],
#  'hastier': ['JJR'],
#  'havia': ['NN'],
#  'headbangingly': ['RB'],
#  'heartwarmingly': ['RB'],
#  'hellfires': ['NNS'],
#  'hellstenius': ['NN', 'NN'],
#  'heremakono': ['NN', 'NN'],
#  'higuchinsky': ['NN', 'JJ'],
#  'him.': ['NN'],
#  'hirosue': ['NN'],
#  'histo': ['NN', 'NN'],
#  'hitchcockianism': ['NN'],
#  'hjelje': ['NN', 'NN'],
#  'hobnail': ['JJ'],
#  'hotdogging': ['VBG', 'VBG'],
#  'hotsies': ['NNS', 'NNS'],
#  'hubac': ['NN', 'NN'],
#  'humbuggery': ['NN'],
#  'idemoto': ['NN', 'NN', 'NN'],
#  'idoosyncratic': ['JJ', 'JJ'],
#  'igualmente': ['NN'],
#  'ihops': ['NNS'],
#  'illogicality': ['NN'],
#  'imaginación': ['NN'],
#  'imponderably': ['RB'],
#  'impotentes': ['NNS'],
#  'incoloro': ['NN'],
#  'incompetência': ['NN'],
#  'incomplacency': ['NN'],
#  'inconsequentiality': ['NN'],
#  'indieflick': ['NN', 'NN'],
#  'inducingly': ['RB'],
#  'ineptitudes': ['NNS'],
#  'infidèle': ['NN'],
#  'inhospitability': ['NN'],
#  'inhospitality': ['NN'],
#  'inquestionável': ['NN'],
#  'insipidity': ['NN', 'NN', 'NN'],
#  'instante': ['VB'],
#  'intacto': ['JJ'],
#  'intelectualmente': ['NN'],
#  'intentando': ['NN'],
#  'interações': ['NN'],
#  'interspliced': ['VBN'],
#  'involvingly': ['RB'],
#  'início': ['VBZ'],
#  'irretrievability': ['NN'],
#  "it's": ['NN', 'JJ', 'NN'],
#  'italianas': ['VBP'],
#  'italicizes': ['VBZ', 'VBZ'],
#  'jaglomized': ['VBN'],
#  'janklowicz': ['NN', 'NN', 'NN'],
#  'japanimator': ['NN'],
#  'jirí': ['NN', 'NN'],
#  'jovovith': ['NN'],
#  'joylessly': ['RB'],
#  'juiceless': ['JJ'],
#  'kahlories': ['NNS'],
#  'kalesniko': ['NNP', 'NNP'],
#  'kalvert': ['NN', 'NN'],
#  'kaputschnik': ['NN', 'NN'],
#  'kazmierski': ['NNP'],
#  'kibbitzes': ['NNS'],
#  'kickass': ['NN'],
#  'kidlets': ['NNS', 'NNS'],
#  'komediant': ['NN'],
#  'kosashvili': ['VB', 'JJ', 'NNP', 'VB', 'VB', 'NNP'],
#  'koshashvili': ['NN'],
#  'laboriousness': ['NN'],
#  'landbound': ['NN'],
#  'lapdance': ['NN'],
#  'lappy': ['JJ'],
#  'leatherbound': ['NN'],
#  'leplouff': ['NN', 'NN'],
#  'lhe': ['NN'],
#  'likableness': ['NN'],
#  'logra': ['JJ'],
#  'luvvies': ['NNS', 'NNS'],
#  'lynchable': ['JJ'],
#  'lástima': ['JJ'],
#  'líquido': ['NN', 'NN'],
#  'maelström': ['NN'],
#  'makmalbaf': ['NN', 'NN'],
#  'manipulador': ['NN'],
#  'manqué': ['NN'],
#  'marcken': ['FW', 'FW'],
#  'margolo': ['NN', 'NN'],
#  'marveilleux': ['VBN'],
#  'masterpeice': ['NN'],
#  'materalism': ['NN'],
#  'mcklusky': ['JJ', 'JJ'],
#  'meaningness': ['NN'],
#  'meanspirited': ['VBD'],
#  'mediocridade': ['NN'],
#  'melodramáticos': ['NN'],
#  'memória': ['NN'],
#  'mergulha': ['NN'],
#  'mesmos': ['NN'],
#  'mibii': ['FW', 'FW'],
#  'miedos': ['FW'],
#  'minac': ['NN', 'NN'],
#  'misacted': ['VBN'],
#  'miscasts': ['NNS'],
#  'moinoise': ['NN'],
#  'mollà': ['VBP'],
#  'monkeyfun': ['NN'],
#  'montaje': ['JJ'],
#  'montias': ['NN', 'NN', 'NN', 'CC'],
#  'montied': ['VBN'],
#  'mouglalis': ['NN'],
#  'movie\x97if': ['NN'],
#  'movilizador': ['NN'],
#  'mullinski': ['NN', 'NN'],
#  'murdery': ['NN'],
#  'musclefest': ['JJS', 'JJS'],
#  'musicais': ['NN'],
#  'narcotized': ['JJ'],
#  'narcotizing': ['NN'],
#  'narrativa': ['FW'],
#  'naturedness': ['NN'],
#  'nebrida': ['NN', 'NN'],
#  'necessidade': ['FW'],
#  'nerfs': ['RB'],
#  'ninguém': ['JJ'],
#  'ningún': ['NN'],
#  'nohe': ['JJ', 'NN', 'FW', 'JJ', 'FW'],
#  'nolden': ['JJ', 'JJ'],
#  'nonchallenging': ['NN'],
#  'nonethnic': ['JJ'],
#  'nrelentingly': ['RB'],
#  'nutjob': ['NN'],
#  'nuttgens': ['NNS', 'RB'],
#  'næs': ['JJ', 'JJ'],
#  'obligada': ['NN'],
#  'obviation': ['NN', 'NN'],
#  'oedederk': ['JJ', 'NN'],
#  'oedekark': ['JJ'],
#  'ooky': ['JJ'],
#  'originalidad': ['NN'],
#  'orquídeas': ['FW'],
#  'ourside': ['IN'],
#  'outgag': ['VB'],
#  'outing—the': ['NN'],
#  'outré': ['JJ'],
#  'overemphatic': ['JJ'],
#  'overmanipulative': ['JJ', 'JJ'],
#  'overplotted': ['VBN'],
#  'overstylized': ['JJ'],
#  'ozpetek': ['NN', 'JJ', 'NN', 'JJ', 'NN', 'NN', 'JJ', 'RB', 'JJ', 'NN'],
#  'oídos': ['NN'],
#  'papai': ['FW'],
#  'paródia': ['FW'],
#  'patriotero': ['NN'],
#  'penotti': ['NN', 'NN'],
#  'pentacal': ['JJ'],
#  'perde': ['FW'],
#  'perdona': ['VBP'],
#  'perfervid': ['JJ'],
#  'peroxidized': ['JJ'],
#  'perseguição': ['NN'],
#  'personagens': ['NNS', 'NNS'],
#  'petin': ['NN', 'NN'],
#  'phonce': ['NN'],
#  'pianista': ['VBP'],
#  'pincel': ['NN'],
#  'pisiewicz': ['NN'],
#  'pistoled': ['VBN'],
#  'plaintiveness': ['NN'],
#  'playdough': ['NN'],
#  'plushies': ['NNS', 'NNS'],
#  'pokepie': ['NN'],
#  'policiales': ['NNS'],
#  'pollyana': ['NN', 'NN'],
#  'possui': ['NN'],
#  'pouquíssimos': ['JJ'],
#  'powaqqatsi': ['NN', 'NN'],
#  'prechewed': ['VBN'],
#  'preciosista': ['JJ'],
#  'precisa': ['NN'],
#  'precollegiate': ['NN'],
#  'predecesora': ['NN'],
#  'predecible': ['JJ'],
#  'prefeminist': ['NN'],
#  'prejuicios': ['NNS'],
#  'premisa': ['NN'],
#  'premissa': ['NN'],
#  'preocupar': ['NN'],
#  'preocupe': ['NN'],
#  'prescinde': ['NN'],
#  'pretenciosas': ['FW'],
#  'pretention': ['NN'],
#  'prewarned': ['VBN'],
#  'profundamente': ['NN', 'NN'],
#  'projeção': ['NN'],
#  'provocatuers': ['NNS'],
#  'próprio': ['NN'],
#  'psychodramatics': ['NNS'],
#  'pulpiness': ['NN'],
#  'puportedly': ['RB'],
#  'puréed': ['JJ'],
#  'putain': ['NN'],
#  'puttingly': ['RB'],
#  'pérdida': ['NN'],
#  'péssima': ['NN'],
#  'qatsi': ['NN', 'JJ'],
#  'quizá': ['FW'],
#  'qutting': ['NN'],
#  'realidade': ['NN'],
#  'real\x97she': ['JJ'],
#  'recoing': ['VBG'],
#  'reconceptualize': ['VB', 'VB'],
#  'recurre': ['VBZ'],
#  'reeboir': ['NN', 'NN'],
#  'reeses': ['NNS'],
#  'repartees': ['NNS'],
#  'repellantly': ['RB'],
#  'rephrases': ['VBZ'],
#  'representando': ['FW'],
#  'repulsively': ['RB', 'RB'],
#  'responsável': ['NN'],
#  'resultan': ['NN'],
#  'retadora': ['NN'],
#  'retrata': ['NN'],
#  'revigorates': ['VBZ'],
#  'ricture': ['NN'],
#  'rintarô': ['NN'],
#  'roisterous': ['JJ'],
#  'romething': ['VBG'],
#  'románticas': ['JJ'],
#  'roteirista': ['NN', 'JJ'],
#  'roteiro': ['NN'],
#  'runteldat': ['NN', 'NN', 'NN'],
#  'russos': ['NN', 'NN', 'NN'],
#  'ryanovich': ['NN', 'NN'],
#  'rápidamente': ['JJ'],
#  's1m0ne': ['NN', 'NN'],
#  'sailboaters': ['NNS'],
#  'salaciously': ['RB'],
#  'sandlerian': ['JJ'],
#  'sapes': ['NNS'],
#  'sapid': ['JJ'],
#  'sappier': ['JJR'],
#  'sarcástica': ['NN'],
#  'satirizado': ['NN'],
#  'saído': ['NN'],
#  'saímos': ['NNS'],
#  'scandalousness': ['NN'],
#  'schneidermeister': ['NN'],
#  'schweigh': ['JJ'],
#  'scuzbag': ['NN', 'NN'],
#  'seldahl': ['NN', 'NN', 'NNS', 'VBP', 'NN', 'NN', 'NNS', 'NN'],
#  'sequer': ['NN'],
#  'sermonize': ['VB'],
#  'shagster': ['NN', 'NN'],
#  'shakesperean': ['JJ'],
#  'shapable': ['JJ'],
#  'shapelessly': ['RB'],
#  'shayamalan': ['VBN', 'VBN'],
#  'sheerly': ['RB', 'JJ'],
#  'shimmeringly': ['RB'],
#  'shlockmeister': ['NN'],
#  'shmear': ['NN', 'NN'],
#  'shoplifts': ['VBP'],
#  'shrieky': ['JJ'],
#  'silbersteins': ['NNS'],
#  'sillified': ['VBN'],
#  'sillyly': ['NN'],
#  'silléified': ['VBN'],
#  'simbolizando': ['VBP'],
#  'sinais': ['NN'],
#  'sincera': ['NN'],
#  'sitcomishly': ['JJ'],
#  'siuation': ['NN'],
#  'skeeved': ['VBN'],
#  'skippable': ['JJ'],
#  'slappingly': ['RB'],
#  'slowtime': ['VB'],
#  'slummy': ['JJ'],
#  'smashups': ['NNS'],
#  'snazziness': ['NN'],
#  'snoots': ['NNS', 'NNS'],
#  'soaringly': ['RB'],
#  'soberbio': ['NN'],
#  'sogginess': ['NN'],
#  'solondzian': ['JJ'],
#  'sophomer': ['NN'],
#  'sophomoronic': ['JJ', 'JJ'],
#  'sorprenderá': ['NN'],
#  "soul's": ['NN'],
#  'sparklingly': ['RB'],
#  'splatterfests': ['NNS', 'NNS'],
#  'splittingly': ['RB'],
#  'spookies': ['NNS'],
#  'squaddie': ['JJ'],
#  'stagecrafts': ['NNS'],
#  "stalk'n'slash": ['NN'],
#  'steinis': ['NN'],
#  'stoppingly': ['RB'],
#  'stortelling': ['NN', 'NN'],
#  'strafings': ['NNS'],
#  'strainingly': ['RB'],
#  'stuffiest': ['JJS'],
#  'stultifyingly': ['RB', 'RB', 'RB'],
#  'stumblings': ['NNS'],
#  'stuporously': ['RB'],
#  'substitutable': ['JJ', 'JJ'],
#  'sumamente': ['JJ'],
#  'superada': ['NN'],
#  'superficiale': ['NN'],
#  'superlarge': ['NN'],
#  'surehanded': ['JJ'],
#  'surfacey': ['JJ'],
#  'suspeito': ['NN'],
#  'suspenser': ['NN'],
#  'swashbuck': ['NN'],
#  'swordfights': ['NNS'],
#  'sychowski': ['JJ', 'JJ'],
#  'sytle': ['NN'],
#  'sánchezes': ['VBZ'],
#  'talancón': ['NN'],
#  'também': ['NN', 'NN', 'NN'],
#  'tardier': ['JJR'],
#  'tearfulness': ['NN'],
#  'thekids': ['NNS'],
#  'theorization': ['NN'],
#  'thesps': ['NN'],
#  'thons': ['NNS'],
#  'time.': ['NN'],
#  'timewaster': ['NN'],
#  'toolbags': ['NNS'],
#  'transfigures': ['NNS', 'VBZ'],
#  'transforma': ['NN'],
#  'travestite': ['JJ'],
#  'travil': ['NN'],
#  'truncheoning': ['VBG'],
#  'try—but': ['VB'],
#  'término': ['VB'],
#  'têm': ['NN'],
#  'uberviolence': ['NN'],
#  'unamusing': ['JJ'],
#  'uncharismatically': ['RB'],
#  'uncinematic': ['JJ'],
#  'unclassifiably': ['RB'],
#  'unconned': ['VBN'],
#  'underdramatized': ['JJ'],
#  'underinspired': ['JJ'],
#  'unembarrassing': ['NN'],
#  'unemotive': ['JJ'],
#  'unencouraging': ['JJ'],
#  'unentertaining': ['JJ', 'JJ'],
#  'unfakable': ['JJ'],
#  'unforgivingly': ['RB'],
#  'unhibited': ['JJ'],
#  'unimpressively': ['RB'],
#  'universos': ['NN'],
#  'unlaughable': ['JJ'],
#  'unplundered': ['VBD', 'VBD'],
#  'unrecommendable': ['JJ'],
#  'unreligious': ['JJ'],
#  'unsalvageability': ['NN'],
#  'unslick': ['JJ'],
#  'unspeakables': ['NNS'],
#  'unstyled': ['JJ'],
#  'unsuspenseful': ['JJ'],
#  'untugged': ['JJ'],
#  'updatings': ['NNS'],
#  'uplifter': ['NN'],
#  'utilizar': ['JJ'],
#  'ventually': ['RB'],
#  'verete': ['JJ', 'NNS'],
#  'versión': ['NN'],
#  'vidgame': ['NN'],
#  'villians': ['NNS'],
#  'visualmente': ['FW'],
#  'volletta': ['NN'],
#  'vulakoro': ['NN'],
#  'wankery': ['NN'],
#  'wanking': ['JJ'],
#  'watstein': ['NNS', 'NN', 'NN', 'NN'],
#  'waydowntown': ['NN', 'JJ', 'NN', 'JJ', 'NN', 'NN', 'JJ', 'NN'],
#  'wewannour': ['VB'],
#  'whimsicality': ['NN'],
#  'whippers': ['NNS'],
#  'wifty': ['JJ'],
#  'wisegirls': ['NN'],
#  'witlessness': ['NN'],
#  'wizy': ['JJ'],
#  'wollter': ['NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN'],
#  'wrackingly': ['RB'],
#  'zillionth': ['JJ'],
#  'zzzzzzzzz': ['NN'],
#  '\x9170s': ['NNP'],
#  '\x91direct': ['JJ'],
#  '\x91what': ['WP'],
#  '\x96': ['VBG',
#   'NNP',
#   'NN',
#   'NNP',
#   'VBP',
#   'NNP',
#   'NN',
#   'NNS',
#   'NN',
#   'VBN',
#   'VBZ',
#   'NNP',
#   'VBP',
#   'NNP',
#   'RP',
#   'RB',
#   'VBP',
#   'NNP',
#   'NN',
#   'VBZ',
#   'NNS',
#   'NN',
#   'NNP',
#   'NN',
#   'NNP',
#   'VBP'],
#  '\x97': ['VBP',
#   'NN',
#   'VBP',
#   'CC',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'VB',
#   'NN',
#   'VBP',
#   'NN',
#   'NN',
#   'NN'],
#  'às': ['NNP'],
#  'ápice': ['NNP'],
#  'ótimo': ['NNP'],
#  'últimos': ['JJ'],
#  'única': ['JJ']}

# %% [markdown]
# ## (c) The existence of the OOV words is one of the well-known limitations of Word2vec (or Glove). Without using any transformer-based language models (e.g., BERT, GPT, T5), what do you think is the best strategy to mitigate such limitation? Implement your solution in your source code. Show the corresponding code snippet.

# %% [markdown]
# ## Pass 1: Use Stemming to match OOV words of different forms to the same word in GloVe

# %% [markdown]
# - Use snowball stemmer, as it is more aggressive than porter stemmer. Handles -ly words better

# %%
# from nltk.stem import PorterStemmer
# ps = PorterStemmer()

# from nltk.stem import SnowballStemmer
# ss = SnowballStemmer('english')

from nltk.stem import LancasterStemmer
ls = LancasterStemmer()

# Stem vocab
stemmed_glove_vocab = {ls.stem(word): word for word in glove_embeddings.keys()}

# Stem vocab and OOV words, find same word
def find_substitute_word_stem(oov_word, stemmed_glove_vocab):
    stemmed_oov_word = ls.stem(oov_word)
    if stemmed_oov_word in stemmed_glove_vocab.keys():
        return stemmed_glove_vocab[stemmed_oov_word]
    
    return None

# %%
# Copy substitute word embedding to OOV word
for oov_word in oov_words:
    best_substitute_word = find_substitute_word_stem(oov_word, stemmed_glove_vocab)
    if best_substitute_word:
        print(f'OOV word: {oov_word}, substitute word: {best_substitute_word}')
        embedding_matrix[vocab_word_to_index[oov_word]] = glove_embeddings[best_substitute_word]
# Out:
# OOV word: abandone, substitute word: abandonar
# OOV word: accomodates, substitute word: accomodative
# OOV word: achival, substitute word: acher
# OOV word: acidically, substitute word: acidulated
# OOV word: actorious, substitute word: actionism
# OOV word: actorish, substitute word: actionism
# OOV word: actory, substitute word: actionism
# OOV word: adorability, substitute word: adag
# OOV word: affirmational, substitute word: affirmance
# OOV word: alientation, substitute word: aliis
# OOV word: allodi, substitute word: allodial
# OOV word: amusedly, substitute word: amusa
# OOV word: anteing, substitute word: antiseizure
# OOV word: apallingly, substitute word: apala
# OOV word: aqueles, substitute word: aquel
# OOV word: atacar, substitute word: atac
# OOV word: awakener, substitute word: awaking
# OOV word: beseechingly, substitute word: beseeches
# OOV word: birot, substitute word: birote
# OOV word: bjorkness, substitute word: bjorke
# OOV word: blighter, substitute word: blighting
# OOV word: bondish, substitute word: bondian
# OOV word: bottomlessly, substitute word: bottomless
# OOV word: burningly, substitute word: burnable
# OOV word: bustingly, substitute word: busti
# OOV word: butterfingered, substitute word: butterflyer
# OOV word: cadness, substitute word: cadent
# OOV word: cannier, substitute word: canniness
# OOV word: captivatingly, substitute word: captal
# OOV word: carefreeness, substitute word: carefree
# OOV word: carente, substitute word: carral
# OOV word: caricatural, substitute word: carral
# OOV word: cativante, substitute word: catagory
# OOV word: chabrolian, substitute word: chabrol
# OOV word: cineasts, substitute word: cineaste
# OOV word: cinemantic, substitute word: cinemagic
# OOV word: ciphered, substitute word: ciphering
# OOV word: claptraps, substitute word: claptrap
# OOV word: cletis, substitute word: cleta
# OOV word: colocar, substitute word: colocated
# OOV word: colonics, substitute word: colonizations
# OOV word: complejos, substitute word: complejo
# OOV word: complementares, substitute word: complementarities
# OOV word: contructed, substitute word: contruction
# OOV word: convencional, substitute word: convencer
# OOV word: coriat, substitute word: coryat
# OOV word: creepyness, substitute word: creepier
# OOV word: criar, substitute word: criers
# OOV word: daneses, substitute word: danesi
# OOV word: datedness, substitute word: datis
# OOV word: deadeningly, substitute word: deadness
# OOV word: debuter, substitute word: debutantes
# OOV word: defeatingly, substitute word: defeis
# OOV word: delicia, substitute word: delica
# OOV word: demencial, substitute word: demoratic
# OOV word: democracie, substitute word: democratised
# OOV word: derivativeness, substitute word: derating
# OOV word: desee, substitute word: desus
# OOV word: deseos, substitute word: deseo
# OOV word: destinees, substitute word: destinee
# OOV word: diciness, substitute word: dicier
# OOV word: disposible, substitute word: disposers
# OOV word: divertingly, substitute word: diverters
# OOV word: dominatrixes, substitute word: dominatrix
# OOV word: dooper, substitute word: doop
# OOV word: dramatisms, substitute word: dramatical
# OOV word: dreadfulness, substitute word: dreadfuls
# OOV word: drecks, substitute word: dreck
# OOV word: dridi, substitute word: drider
# OOV word: drippiness, substitute word: drippy
# OOV word: dudds, substitute word: dudding
# OOV word: dullingly, substitute word: dulness
# OOV word: dumbfoundingly, substitute word: dumbfounding
# OOV word: dysfunctionally, substitute word: dysfunctionality
# OOV word: elegiacally, substitute word: elegiac
# OOV word: elemento, substitute word: elementos
# OOV word: emptily, substitute word: emptier
# OOV word: enamoring, substitute word: enami
# OOV word: enrapturing, substitute word: enraptured
# OOV word: entretiene, substitute word: enten
# OOV word: eroti, substitute word: erotics
# OOV word: escapa, substitute word: escapists
# OOV word: estudo, substitute word: estudos
# OOV word: exhilarate, substitute word: exhilaratingly
# OOV word: exporing, substitute word: expat
# OOV word: expresar, substitute word: expresa
# OOV word: fantasti, substitute word: fantastics
# OOV word: fascinantes, substitute word: fascinations
# OOV word: fashionedness, substitute word: fashionability
# OOV word: fato, substitute word: fatos
# OOV word: fillm, substitute word: fillmore
# OOV word: fizzability, substitute word: fizzes
# OOV word: fluxing, substitute word: fluxes
# OOV word: forgettably, substitute word: forgetfulness
# OOV word: francamente, substitute word: francas
# OOV word: frissons, substitute word: frisson
# OOV word: funcionar, substitute word: funciona
# OOV word: fustily, substitute word: fusty
# OOV word: gantzes, substitute word: gantz
# OOV word: gasm, substitute word: gasman
# OOV word: gooeyness, substitute word: gooey
# OOV word: gorefests, substitute word: gorefest
# OOV word: grandiosa, substitute word: grandiosely
# OOV word: greaseballs, substitute word: greaseball
# OOV word: guessable, substitute word: guesser
# OOV word: hammily, substitute word: hamminess
# OOV word: haphazardness, substitute word: haphazardly
# OOV word: hastier, substitute word: hastiness
# OOV word: havia, substitute word: havis
# OOV word: headbangingly, substitute word: headbanging
# OOV word: heartwarmingly, substitute word: heartwarming
# OOV word: hellfires, substitute word: hellfire
# OOV word: hitchcockianism, substitute word: hitchcockian
# OOV word: hotdogging, substitute word: hotdog
# OOV word: hotsies, substitute word: hotsy
# OOV word: igualmente, substitute word: igoris
# OOV word: ihops, substitute word: ihop
# OOV word: illogicality, substitute word: illogically
# OOV word: imponderably, substitute word: imponderables
# OOV word: impotentes, substitute word: impotently
# OOV word: inconsequentiality, substitute word: inconsequence
# OOV word: inducingly, substitute word: inductances
# OOV word: ineptitudes, substitute word: ineptitude
# OOV word: inhospitability, substitute word: inhospitable
# OOV word: inhospitality, substitute word: inhospitable
# OOV word: insipidity, substitute word: insipidus
# OOV word: instante, substitute word: instating
# OOV word: intelectualmente, substitute word: intelect
# OOV word: involvingly, substitute word: involutive
# OOV word: irretrievability, substitute word: irretrievable
# OOV word: italicizes, substitute word: itte
# OOV word: jaglomized, substitute word: jaglom
# OOV word: joylessly, substitute word: joyless
# OOV word: kahlories, substitute word: kahlan
# OOV word: laboriousness, substitute word: laborie
# OOV word: lapdance, substitute word: lapd
# OOV word: likableness, substitute word: liker
# OOV word: logra, substitute word: lograr
# OOV word: lynchable, substitute word: lynchers
# OOV word: marcken, substitute word: marcks
# OOV word: materalism, substitute word: matory
# OOV word: meaningness, substitute word: meana
# OOV word: miedos, substitute word: miedo
# OOV word: miscasts, substitute word: miscasting
# OOV word: montied, substitute word: montie
# OOV word: musicais, substitute word: musicae
# OOV word: narcotized, substitute word: narcotic
# OOV word: narcotizing, substitute word: narcotic
# OOV word: naturedness, substitute word: naters
# OOV word: nerfs, substitute word: nerf
# OOV word: nohe, substitute word: nohar
# OOV word: nolden, substitute word: nold
# OOV word: nrelentingly, substitute word: nrel
# OOV word: obviation, substitute word: obviative
# OOV word: papai, substitute word: papae
# OOV word: pentacal, substitute word: pentacle
# OOV word: perde, substitute word: perdus
# OOV word: peroxidized, substitute word: peroxidation
# OOV word: personagens, substitute word: personalistic
# OOV word: phonce, substitute word: phonte
# OOV word: pistoled, substitute word: pistola
# OOV word: plaintiveness, substitute word: plaints
# OOV word: policiales, substitute word: pollees
# OOV word: preocupar, substitute word: preocupa
# OOV word: preocupe, substitute word: preocupa
# OOV word: pretention, substitute word: preterist
# OOV word: psychodramatics, substitute word: psychodrama
# OOV word: pulpiness, substitute word: pulpy
# OOV word: puréed, substitute word: purée
# OOV word: puttingly, substitute word: puttees
# OOV word: quizá, substitute word: quizás
# OOV word: qutting, substitute word: quta
# OOV word: realidade, substitute word: realidad
# OOV word: recoing, substitute word: reco
# OOV word: reconceptualize, substitute word: reconceived
# OOV word: recurre, substitute word: recurrently
# OOV word: reeses, substitute word: reesor
# OOV word: repartees, substitute word: repartee
# OOV word: repellantly, substitute word: repellants
# OOV word: rephrases, substitute word: rephrasing
# OOV word: repulsively, substitute word: repulsor
# OOV word: resultan, substitute word: resultative
# OOV word: ricture, substitute word: rictus
# OOV word: roisterous, substitute word: roistering
# OOV word: russos, substitute word: russo
# OOV word: sailboaters, substitute word: sailboats
# OOV word: salaciously, substitute word: salee
# OOV word: sandlerian, substitute word: sandling
# OOV word: sapes, substitute word: sapag
# OOV word: sapid, substitute word: sapidus
# OOV word: sappier, substitute word: sappiness
# OOV word: scandalousness, substitute word: scandalizes
# OOV word: sequer, substitute word: sequa
# OOV word: sermonize, substitute word: sermonized
# OOV word: shapable, substitute word: shapps
# OOV word: shapelessly, substitute word: shapeless
# OOV word: sheerly, substitute word: sheane
# OOV word: shimmeringly, substitute word: shimi
# OOV word: shoplifts, substitute word: shoplifted
# OOV word: silbersteins, substitute word: silberstein
# OOV word: sillified, substitute word: sillars
# OOV word: sillyly, substitute word: silic
# OOV word: sinais, substitute word: sinas
# OOV word: sitcomishly, substitute word: sitcoms
# OOV word: siuation, substitute word: siuan
# OOV word: skippable, substitute word: skipp
# OOV word: slappingly, substitute word: slape
# OOV word: smashups, substitute word: smashup
# OOV word: snazziness, substitute word: snazzier
# OOV word: snoots, substitute word: snoot
# OOV word: soaringly, substitute word: soarer
# OOV word: sogginess, substitute word: soggy
# OOV word: solondzian, substitute word: solondz
# OOV word: sophomer, substitute word: sophomoric
# OOV word: sparklingly, substitute word: sparkler
# OOV word: spookies, substitute word: spookier
# OOV word: stagecrafts, substitute word: stagecraft
# OOV word: steinis, substitute word: steininger
# OOV word: stoppingly, substitute word: stoped
# OOV word: stultifyingly, substitute word: stultified
# OOV word: stumblings, substitute word: stumbles
# OOV word: stuporously, substitute word: stupar
# OOV word: substitutable, substitute word: substitutional
# OOV word: sumamente, substitute word: sumas
# OOV word: superficiale, substitute word: superfans
# OOV word: suspenser, substitute word: suspensory
# OOV word: swordfights, substitute word: swordfighting
# OOV word: tardier, substitute word: tardily
# OOV word: tearfulness, substitute word: teare
# OOV word: theorization, substitute word: theatened
# OOV word: thesps, substitute word: thespis
# OOV word: thons, substitute word: thone
# OOV word: toolbags, substitute word: toolbars
# OOV word: transfigures, substitute word: transfigured
# OOV word: transforma, substitute word: transformable
# OOV word: truncheoning, substitute word: truncheon
# OOV word: unamusing, substitute word: unamused
# OOV word: uncharismatically, substitute word: unchs
# OOV word: unclassifiably, substitute word: unclassifiable
# OOV word: unembarrassing, substitute word: unembarrassed
# OOV word: unemotive, substitute word: unemotionally
# OOV word: unforgivingly, substitute word: unforgiveable
# OOV word: unimpressively, substitute word: unimpressive
# OOV word: universos, substitute word: universo
# OOV word: unsalvageability, substitute word: unsalvageable
# OOV word: unspeakables, substitute word: unspeakably
# OOV word: unstyled, substitute word: unstylish
# OOV word: updatings, substitute word: updater
# OOV word: uplifter, substitute word: uplifts
# OOV word: ventually, substitute word: vencie
# OOV word: verete, substitute word: verettes
# OOV word: villians, substitute word: vilane
# OOV word: visualmente, substitute word: visar
# OOV word: wanking, substitute word: wanka
# OOV word: whimsicality, substitute word: whimsically
# OOV word: whippers, substitute word: whipps
# OOV word: witlessness, substitute word: witless
# OOV word: wrackingly, substitute word: wracks

# %%
# Print remaining OOV words
oov_words = get_oov_words(embedding_matrix, vocab_word_to_index)

print(f"Number of OOV words left: {len(oov_words)}")
# Out:
# Number of OOV words left: 420

# %% [markdown]
# ## Pass 2: Use Wordnet synonyms bank based on sentence POS tagging

# %%
oov_words_pos
# Out:
# {'1899.': ['CD'],
#  '1952.': ['CD'],
#  '1975.': ['CD'],
#  '1995.': ['CD'],
#  '2002.': ['CD', 'CD'],
#  '28k': ['CD', 'CD'],
#  '5ths': ['CD', 'CD'],
#  '8217': ['CD', 'CD'],
#  'abandone': ['NN'],
#  'aborbing': ['VBG'],
#  'absolutamente': ['NN'],
#  'aburrido': ['NN'],
#  'acabamos': ['NN'],
#  'accomodates': ['VBZ'],
#  'aceitou': ['NN'],
#  'achival': ['JJ'],
#  'achronological': ['NN', 'JJ'],
#  'acidically': ['RB'],
#  'acontecimentos': ['NNS'],
#  'actorious': ['JJ'],
#  'actorish': ['JJ'],
#  'actory': ['JJ'],
#  'actuación': ['FW'],
#  'actuada': ['NN', 'JJ'],
#  'addessi': ['NN', 'RB'],
#  'adorability': ['NN', 'NN'],
#  'adventues': ['NNS'],
#  'affirmational': ['JJ'],
#  "ain't": ['IN'],
#  'alientation': ['NN', 'NN'],
#  'allodi': ['JJ', 'RB'],
#  'amoses': ['NNS', 'NNS'],
#  'amusedly': ['RB'],
#  'andamento': ['NN'],
#  'animé': ['JJ', 'NN'],
#  'anteing': ['VBG'],
#  'apallingly': ['RB'],
#  'apesar': ['NN'],
#  'aproveitar': ['NN'],
#  'aqueles': ['NNS'],
#  "aren't": ['JJ'],
#  'arriesgado': ['FW'],
#  'artnering': ['VBG'],
#  'artsploitation': ['NN'],
#  'artístico': ['JJ'],
#  'assistir': ['IN'],
#  'atacar': ['NN'],
#  'atacarse': ['JJ'],
#  'atreve': ['VBP'],
#  'auteil': ['NN', 'JJ', 'NN', 'NN'],
#  'autocritique': ['NN'],
#  'awakener': ['NN'],
#  'b+': ['NN'],
#  'bazadona': ['NN', 'NN'],
#  'bergmanesque': ['JJ'],
#  'beseechingly': ['RB'],
#  'bibbidy': ['NN'],
#  'bierbichler': ['NN'],
#  'birot': ['NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN'],
#  'bizzarre': ['JJ'],
#  'bjorkness': ['NN'],
#  'blighter': ['NN'],
#  'blutarsky': ['NN'],
#  'bobbidi': ['NN'],
#  'bondish': ['JJ'],
#  'bornin': ['NN'],
#  'bottomlessly': ['RB'],
#  'bruckheimeresque': ['JJ'],
#  'brûlée': ['NN', 'NN'],
#  "bull's": ['NN'],
#  'burningly': ['RB'],
#  'bustingly': ['RB'],
#  'butterfingered': ['VBN', 'VBN'],
#  'cadness': ['NN'],
#  "cam'ron": ['NN'],
#  'camareras': ['NNS'],
#  'cannier': ['JJR'],
#  'captivatingly': ['RB'],
#  'capturou': ['NN'],
#  'carefreeness': ['NN', 'NN'],
#  'carente': ['NN'],
#  'caricatural': ['JJ'],
#  'cativante': ['NN'],
#  'certamente': ['NN'],
#  'chabrolian': ['JJ'],
#  'chopsocky': ['JJ'],
#  'choquart': ['NN', 'NN'],
#  'cineasts': ['NNS'],
#  'cinemantic': ['JJ'],
#  'ciphered': ['JJ'],
#  'cipherlike': ['NN'],
#  'cirulnick': ['NN'],
#  'claptraps': ['NNS'],
#  'claustrophic': ['JJ'],
#  'clericks': ['NNS'],
#  'cletis': ['NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN'],
#  'clichês': ['NN'],
#  'clutchy': ['NN'],
#  'collinswood': ['NN'],
#  'collosum': ['NN'],
#  'colocar': ['NN'],
#  'colonics': ['NNS'],
#  'colosal': ['NN'],
#  'começamos': ['VB'],
#  'compleja': ['NN'],
#  'complejos': ['NN'],
#  'complementares': ['NNS'],
#  'condensada': ['NN'],
#  'confusedred': ['VBN'],
#  'conmovedora': ['NN'],
#  'consegue': ['NN', 'NN'],
#  'constatação': ['NN'],
#  'contando': ['NN'],
#  'contemplarse': ['FW'],
#  'continuação': ['NN'],
#  'contructed': ['JJ'],
#  'contrária': ['NNS'],
#  'convencional': ['NN'],
#  'copmovieland': ['NN', 'NN'],
#  'coriat': ['NN', 'NN'],
#  'corniest': ['JJS'],
#  'corpse—stays': ['VBZ'],
#  'corruscating': ['VBG'],
#  'costumey': ['NN'],
#  'covardia': ['NN'],
#  'crappola': ['NN'],
#  'creepyness': ['NN'],
#  'criar': ['NN'],
#  'crowdpleaser': ['NN'],
#  'crummles': ['NNS', 'NNS'],
#  'csoka': ['NN'],
#  'culminando': ['NN'],
#  'daneses': ['NNS'],
#  'datedness': ['NN'],
#  'dateflick': ['NN'],
#  'deadeningly': ['RB'],
#  'debuter': ['NN'],
#  'decasia': ['NN', 'NN'],
#  'decidiram': ['JJ'],
#  'decirles': ['VBZ'],
#  'defeatingly': ['RB'],
#  'delibrately': ['RB'],
#  'delicia': ['NN'],
#  'demencial': ['JJ'],
#  'democracie': ['NN'],
#  'denlopp': ['VBP', 'NN'],
#  'derivativeness': ['NN'],
#  'desaponta': ['NN'],
#  'desarrollarse': ['NN'],
#  'desee': ['NN'],
#  'deseos': ['NN'],
#  'desfecho': ['NN'],
#  'desnudo': ['NN'],
#  'destinees': ['NNS'],
#  'deutchland': ['VB', 'VB'],
#  'diciness': ['NN'],
#  'diferença': ['NN'],
#  'digno': ['NN'],
#  'direto': ['NN'],
#  'diretor': ['NN'],
#  'direção': ['VB', 'NN'],
#  'disfrutable': ['JJ'],
#  'disposible': ['JJ'],
#  'divertida': ['NN', 'NN', 'VBP', 'NN'],
#  'divertingly': ['RB'],
#  'djeinaba': ['JJ', 'NN'],
#  'document—its': ['NNS'],
#  'does—but': ['IN'],
#  'dogwalker': ['NN'],
#  'dominatrixes': ['NNS', 'NNS'],
#  "don't": ['RB'],
#  'dooper': ['NN'],
#  'dramatisms': ['NNS'],
#  'dreadfulness': ['NN'],
#  'drecks': ['NNS'],
#  'drek': ['NN'],
#  'dridi': ['NN'],
#  'drippiness': ['NN'],
#  'dudds': ['NN'],
#  'dudsville': ['JJ'],
#  'dullingly': ['RB'],
#  'dumbfoundingly': ['RB'],
#  'duración': ['NN'],
#  'dysfunctionally': ['RB'],
#  'dès': ['NN'],
#  'efteriades': ['NNS'],
#  'elegiacally': ['RB'],
#  'elemento': ['FW', 'IN'],
#  'emocionalmente': ['FW'],
#  'emocionante': ['NN'],
#  'emotiva': ['FW'],
#  'emptily': ['RB'],
#  'enamoring': ['VBG'],
#  'enfrentados': ['FW'],
#  'enfrentará': ['NN'],
#  'engaña': ['NN'],
#  'enrapturing': ['VBG'],
#  'enternecedora': ['NN'],
#  'entretenida': ['NN'],
#  'entreter': ['NN'],
#  'entretiene': ['FW'],
#  'então': ['JJ'],
#  'enviará': ['NN'],
#  'episódio': ['NN'],
#  'equlibrium': ['NN', 'NN'],
#  'eroti': ['NN'],
#  'escapa': ['NN'],
#  'esfera': ['JJ'],
#  'esforço': ['NN'],
#  'espectáculo': ['JJ'],
#  'espetáculo': ['VBP'],
#  'espite': ['VBZ'],
#  'esquerdo': ['NN'],
#  'estafeta': ['VBZ'],
#  'estava': ['NN'],
#  'esteticamente': ['NN'],
#  'estranhos': ['NN'],
#  'estudo': ['NN'],
#  'estupendamente': ['NN'],
#  'everlyn': ['NN'],
#  'evolução': ['VBP'],
#  'excrescence': ['NN'],
#  'exhilarate': ['NN'],
#  'exibi': ['FW'],
#  'existência': ['NN'],
#  'explicados': ['NN'],
#  'exporing': ['VBG'],
#  'expresar': ['NN'],
#  'fabulosity': ['NN'],
#  'fantasti': ['JJ'],
#  'fascinantes': ['NNS'],
#  'fashionedness': ['NN'],
#  'fato': ['NN', 'NN'],
#  'feardotcom': ['NN', 'NN', 'NN', 'NN', 'NN', 'NN'],
#  'felinni': ['VB', 'NNS'],
#  'fillm': ['NN'],
#  'film—i': ['NN'],
#  'fizzability': ['NN'],
#  'flakeball': ['NN'],
#  'flatula': ['NN', 'NN'],
#  'flck': ['VBP'],
#  'fluxing': ['VBG'],
#  'forgettably': ['RB'],
#  'francamente': ['NN'],
#  'frissons': ['NNS', 'NNS'],
#  'frustrado': ['NN'],
#  'fuddled': ['VBN'],
#  'fuhgeddaboutit': ['JJ'],
#  "fun's": ['JJ'],
#  'funcionar': ['NN'],
#  'fustily': ['RB'],
#  'fílmica': ['NN'],
#  'gabbiest': ['NN'],
#  'ganha': ['NN'],
#  'gantzes': ['JJ'],
#  'gasm': ['NN', 'NN'],
#  'gaï': ['NN', 'NN'],
#  'gerbosi': ['NN', 'NN'],
#  'glizty': ['NN'],
#  'gooeyness': ['VB'],
#  'goombah': ['NN', 'FW'],
#  'gorefests': ['NNS'],
#  'gosto': ['NN'],
#  'grandiosa': ['VBP'],
#  'grato': ['NN'],
#  'graças': ['NN'],
#  'greaseballs': ['NNS'],
#  'greasiest': ['JJS'],
#  'guessable': ['JJ', 'JJ'],
#  'guión': ['NN'],
#  'gutterball': ['NN'],
#  'gymkata': ['NNS', 'NN'],
#  'halfwit': ['NN'],
#  'hamfisted': ['JJ'],
#  'hammily': ['RB'],
#  'hanewe': ['NN'],
#  'haphazardness': ['NN'],
#  'hastier': ['JJR'],
#  'havia': ['NN'],
#  'headbangingly': ['RB'],
#  'heartwarmingly': ['RB'],
#  'hellfires': ['NNS'],
#  'hellstenius': ['NN', 'NN'],
#  'heremakono': ['NN', 'NN'],
#  'higuchinsky': ['NN', 'JJ'],
#  'him.': ['NN'],
#  'hirosue': ['NN'],
#  'histo': ['NN', 'NN'],
#  'hitchcockianism': ['NN'],
#  'hjelje': ['NN', 'NN'],
#  'hobnail': ['JJ'],
#  'hotdogging': ['VBG', 'VBG'],
#  'hotsies': ['NNS', 'NNS'],
#  'hubac': ['NN', 'NN'],
#  'humbuggery': ['NN'],
#  'idemoto': ['NN', 'NN', 'NN'],
#  'idoosyncratic': ['JJ', 'JJ'],
#  'igualmente': ['NN'],
#  'ihops': ['NNS'],
#  'illogicality': ['NN'],
#  'imaginación': ['NN'],
#  'imponderably': ['RB'],
#  'impotentes': ['NNS'],
#  'incoloro': ['NN'],
#  'incompetência': ['NN'],
#  'incomplacency': ['NN'],
#  'inconsequentiality': ['NN'],
#  'indieflick': ['NN', 'NN'],
#  'inducingly': ['RB'],
#  'ineptitudes': ['NNS'],
#  'infidèle': ['NN'],
#  'inhospitability': ['NN'],
#  'inhospitality': ['NN'],
#  'inquestionável': ['NN'],
#  'insipidity': ['NN', 'NN', 'NN'],
#  'instante': ['VB'],
#  'intacto': ['JJ'],
#  'intelectualmente': ['NN'],
#  'intentando': ['NN'],
#  'interações': ['NN'],
#  'interspliced': ['VBN'],
#  'involvingly': ['RB'],
#  'início': ['VBZ'],
#  'irretrievability': ['NN'],
#  "it's": ['NN', 'JJ', 'NN'],
#  'italianas': ['VBP'],
#  'italicizes': ['VBZ', 'VBZ'],
#  'jaglomized': ['VBN'],
#  'janklowicz': ['NN', 'NN', 'NN'],
#  'japanimator': ['NN'],
#  'jirí': ['NN', 'NN'],
#  'jovovith': ['NN'],
#  'joylessly': ['RB'],
#  'juiceless': ['JJ'],
#  'kahlories': ['NNS'],
#  'kalesniko': ['NNP', 'NNP'],
#  'kalvert': ['NN', 'NN'],
#  'kaputschnik': ['NN', 'NN'],
#  'kazmierski': ['NNP'],
#  'kibbitzes': ['NNS'],
#  'kickass': ['NN'],
#  'kidlets': ['NNS', 'NNS'],
#  'komediant': ['NN'],
#  'kosashvili': ['VB', 'JJ', 'NNP', 'VB', 'VB', 'NNP'],
#  'koshashvili': ['NN'],
#  'laboriousness': ['NN'],
#  'landbound': ['NN'],
#  'lapdance': ['NN'],
#  'lappy': ['JJ'],
#  'leatherbound': ['NN'],
#  'leplouff': ['NN', 'NN'],
#  'lhe': ['NN'],
#  'likableness': ['NN'],
#  'logra': ['JJ'],
#  'luvvies': ['NNS', 'NNS'],
#  'lynchable': ['JJ'],
#  'lástima': ['JJ'],
#  'líquido': ['NN', 'NN'],
#  'maelström': ['NN'],
#  'makmalbaf': ['NN', 'NN'],
#  'manipulador': ['NN'],
#  'manqué': ['NN'],
#  'marcken': ['FW', 'FW'],
#  'margolo': ['NN', 'NN'],
#  'marveilleux': ['VBN'],
#  'masterpeice': ['NN'],
#  'materalism': ['NN'],
#  'mcklusky': ['JJ', 'JJ'],
#  'meaningness': ['NN'],
#  'meanspirited': ['VBD'],
#  'mediocridade': ['NN'],
#  'melodramáticos': ['NN'],
#  'memória': ['NN'],
#  'mergulha': ['NN'],
#  'mesmos': ['NN'],
#  'mibii': ['FW', 'FW'],
#  'miedos': ['FW'],
#  'minac': ['NN', 'NN'],
#  'misacted': ['VBN'],
#  'miscasts': ['NNS'],
#  'moinoise': ['NN'],
#  'mollà': ['VBP'],
#  'monkeyfun': ['NN'],
#  'montaje': ['JJ'],
#  'montias': ['NN', 'NN', 'NN', 'CC'],
#  'montied': ['VBN'],
#  'mouglalis': ['NN'],
#  'movie\x97if': ['NN'],
#  'movilizador': ['NN'],
#  'mullinski': ['NN', 'NN'],
#  'murdery': ['NN'],
#  'musclefest': ['JJS', 'JJS'],
#  'musicais': ['NN'],
#  'narcotized': ['JJ'],
#  'narcotizing': ['NN'],
#  'narrativa': ['FW'],
#  'naturedness': ['NN'],
#  'nebrida': ['NN', 'NN'],
#  'necessidade': ['FW'],
#  'nerfs': ['RB'],
#  'ninguém': ['JJ'],
#  'ningún': ['NN'],
#  'nohe': ['JJ', 'NN', 'FW', 'JJ', 'FW'],
#  'nolden': ['JJ', 'JJ'],
#  'nonchallenging': ['NN'],
#  'nonethnic': ['JJ'],
#  'nrelentingly': ['RB'],
#  'nutjob': ['NN'],
#  'nuttgens': ['NNS', 'RB'],
#  'næs': ['JJ', 'JJ'],
#  'obligada': ['NN'],
#  'obviation': ['NN', 'NN'],
#  'oedederk': ['JJ', 'NN'],
#  'oedekark': ['JJ'],
#  'ooky': ['JJ'],
#  'originalidad': ['NN'],
#  'orquídeas': ['FW'],
#  'ourside': ['IN'],
#  'outgag': ['VB'],
#  'outing—the': ['NN'],
#  'outré': ['JJ'],
#  'overemphatic': ['JJ'],
#  'overmanipulative': ['JJ', 'JJ'],
#  'overplotted': ['VBN'],
#  'overstylized': ['JJ'],
#  'ozpetek': ['NN', 'JJ', 'NN', 'JJ', 'NN', 'NN', 'JJ', 'RB', 'JJ', 'NN'],
#  'oídos': ['NN'],
#  'papai': ['FW'],
#  'paródia': ['FW'],
#  'patriotero': ['NN'],
#  'penotti': ['NN', 'NN'],
#  'pentacal': ['JJ'],
#  'perde': ['FW'],
#  'perdona': ['VBP'],
#  'perfervid': ['JJ'],
#  'peroxidized': ['JJ'],
#  'perseguição': ['NN'],
#  'personagens': ['NNS', 'NNS'],
#  'petin': ['NN', 'NN'],
#  'phonce': ['NN'],
#  'pianista': ['VBP'],
#  'pincel': ['NN'],
#  'pisiewicz': ['NN'],
#  'pistoled': ['VBN'],
#  'plaintiveness': ['NN'],
#  'playdough': ['NN'],
#  'plushies': ['NNS', 'NNS'],
#  'pokepie': ['NN'],
#  'policiales': ['NNS'],
#  'pollyana': ['NN', 'NN'],
#  'possui': ['NN'],
#  'pouquíssimos': ['JJ'],
#  'powaqqatsi': ['NN', 'NN'],
#  'prechewed': ['VBN'],
#  'preciosista': ['JJ'],
#  'precisa': ['NN'],
#  'precollegiate': ['NN'],
#  'predecesora': ['NN'],
#  'predecible': ['JJ'],
#  'prefeminist': ['NN'],
#  'prejuicios': ['NNS'],
#  'premisa': ['NN'],
#  'premissa': ['NN'],
#  'preocupar': ['NN'],
#  'preocupe': ['NN'],
#  'prescinde': ['NN'],
#  'pretenciosas': ['FW'],
#  'pretention': ['NN'],
#  'prewarned': ['VBN'],
#  'profundamente': ['NN', 'NN'],
#  'projeção': ['NN'],
#  'provocatuers': ['NNS'],
#  'próprio': ['NN'],
#  'psychodramatics': ['NNS'],
#  'pulpiness': ['NN'],
#  'puportedly': ['RB'],
#  'puréed': ['JJ'],
#  'putain': ['NN'],
#  'puttingly': ['RB'],
#  'pérdida': ['NN'],
#  'péssima': ['NN'],
#  'qatsi': ['NN', 'JJ'],
#  'quizá': ['FW'],
#  'qutting': ['NN'],
#  'realidade': ['NN'],
#  'real\x97she': ['JJ'],
#  'recoing': ['VBG'],
#  'reconceptualize': ['VB', 'VB'],
#  'recurre': ['VBZ'],
#  'reeboir': ['NN', 'NN'],
#  'reeses': ['NNS'],
#  'repartees': ['NNS'],
#  'repellantly': ['RB'],
#  'rephrases': ['VBZ'],
#  'representando': ['FW'],
#  'repulsively': ['RB', 'RB'],
#  'responsável': ['NN'],
#  'resultan': ['NN'],
#  'retadora': ['NN'],
#  'retrata': ['NN'],
#  'revigorates': ['VBZ'],
#  'ricture': ['NN'],
#  'rintarô': ['NN'],
#  'roisterous': ['JJ'],
#  'romething': ['VBG'],
#  'románticas': ['JJ'],
#  'roteirista': ['NN', 'JJ'],
#  'roteiro': ['NN'],
#  'runteldat': ['NN', 'NN', 'NN'],
#  'russos': ['NN', 'NN', 'NN'],
#  'ryanovich': ['NN', 'NN'],
#  'rápidamente': ['JJ'],
#  's1m0ne': ['NN', 'NN'],
#  'sailboaters': ['NNS'],
#  'salaciously': ['RB'],
#  'sandlerian': ['JJ'],
#  'sapes': ['NNS'],
#  'sapid': ['JJ'],
#  'sappier': ['JJR'],
#  'sarcástica': ['NN'],
#  'satirizado': ['NN'],
#  'saído': ['NN'],
#  'saímos': ['NNS'],
#  'scandalousness': ['NN'],
#  'schneidermeister': ['NN'],
#  'schweigh': ['JJ'],
#  'scuzbag': ['NN', 'NN'],
#  'seldahl': ['NN', 'NN', 'NNS', 'VBP', 'NN', 'NN', 'NNS', 'NN'],
#  'sequer': ['NN'],
#  'sermonize': ['VB'],
#  'shagster': ['NN', 'NN'],
#  'shakesperean': ['JJ'],
#  'shapable': ['JJ'],
#  'shapelessly': ['RB'],
#  'shayamalan': ['VBN', 'VBN'],
#  'sheerly': ['RB', 'JJ'],
#  'shimmeringly': ['RB'],
#  'shlockmeister': ['NN'],
#  'shmear': ['NN', 'NN'],
#  'shoplifts': ['VBP'],
#  'shrieky': ['JJ'],
#  'silbersteins': ['NNS'],
#  'sillified': ['VBN'],
#  'sillyly': ['NN'],
#  'silléified': ['VBN'],
#  'simbolizando': ['VBP'],
#  'sinais': ['NN'],
#  'sincera': ['NN'],
#  'sitcomishly': ['JJ'],
#  'siuation': ['NN'],
#  'skeeved': ['VBN'],
#  'skippable': ['JJ'],
#  'slappingly': ['RB'],
#  'slowtime': ['VB'],
#  'slummy': ['JJ'],
#  'smashups': ['NNS'],
#  'snazziness': ['NN'],
#  'snoots': ['NNS', 'NNS'],
#  'soaringly': ['RB'],
#  'soberbio': ['NN'],
#  'sogginess': ['NN'],
#  'solondzian': ['JJ'],
#  'sophomer': ['NN'],
#  'sophomoronic': ['JJ', 'JJ'],
#  'sorprenderá': ['NN'],
#  "soul's": ['NN'],
#  'sparklingly': ['RB'],
#  'splatterfests': ['NNS', 'NNS'],
#  'splittingly': ['RB'],
#  'spookies': ['NNS'],
#  'squaddie': ['JJ'],
#  'stagecrafts': ['NNS'],
#  "stalk'n'slash": ['NN'],
#  'steinis': ['NN'],
#  'stoppingly': ['RB'],
#  'stortelling': ['NN', 'NN'],
#  'strafings': ['NNS'],
#  'strainingly': ['RB'],
#  'stuffiest': ['JJS'],
#  'stultifyingly': ['RB', 'RB', 'RB'],
#  'stumblings': ['NNS'],
#  'stuporously': ['RB'],
#  'substitutable': ['JJ', 'JJ'],
#  'sumamente': ['JJ'],
#  'superada': ['NN'],
#  'superficiale': ['NN'],
#  'superlarge': ['NN'],
#  'surehanded': ['JJ'],
#  'surfacey': ['JJ'],
#  'suspeito': ['NN'],
#  'suspenser': ['NN'],
#  'swashbuck': ['NN'],
#  'swordfights': ['NNS'],
#  'sychowski': ['JJ', 'JJ'],
#  'sytle': ['NN'],
#  'sánchezes': ['VBZ'],
#  'talancón': ['NN'],
#  'também': ['NN', 'NN', 'NN'],
#  'tardier': ['JJR'],
#  'tearfulness': ['NN'],
#  'thekids': ['NNS'],
#  'theorization': ['NN'],
#  'thesps': ['NN'],
#  'thons': ['NNS'],
#  'time.': ['NN'],
#  'timewaster': ['NN'],
#  'toolbags': ['NNS'],
#  'transfigures': ['NNS', 'VBZ'],
#  'transforma': ['NN'],
#  'travestite': ['JJ'],
#  'travil': ['NN'],
#  'truncheoning': ['VBG'],
#  'try—but': ['VB'],
#  'término': ['VB'],
#  'têm': ['NN'],
#  'uberviolence': ['NN'],
#  'unamusing': ['JJ'],
#  'uncharismatically': ['RB'],
#  'uncinematic': ['JJ'],
#  'unclassifiably': ['RB'],
#  'unconned': ['VBN'],
#  'underdramatized': ['JJ'],
#  'underinspired': ['JJ'],
#  'unembarrassing': ['NN'],
#  'unemotive': ['JJ'],
#  'unencouraging': ['JJ'],
#  'unentertaining': ['JJ', 'JJ'],
#  'unfakable': ['JJ'],
#  'unforgivingly': ['RB'],
#  'unhibited': ['JJ'],
#  'unimpressively': ['RB'],
#  'universos': ['NN'],
#  'unlaughable': ['JJ'],
#  'unplundered': ['VBD', 'VBD'],
#  'unrecommendable': ['JJ'],
#  'unreligious': ['JJ'],
#  'unsalvageability': ['NN'],
#  'unslick': ['JJ'],
#  'unspeakables': ['NNS'],
#  'unstyled': ['JJ'],
#  'unsuspenseful': ['JJ'],
#  'untugged': ['JJ'],
#  'updatings': ['NNS'],
#  'uplifter': ['NN'],
#  'utilizar': ['JJ'],
#  'ventually': ['RB'],
#  'verete': ['JJ', 'NNS'],
#  'versión': ['NN'],
#  'vidgame': ['NN'],
#  'villians': ['NNS'],
#  'visualmente': ['FW'],
#  'volletta': ['NN'],
#  'vulakoro': ['NN'],
#  'wankery': ['NN'],
#  'wanking': ['JJ'],
#  'watstein': ['NNS', 'NN', 'NN', 'NN'],
#  'waydowntown': ['NN', 'JJ', 'NN', 'JJ', 'NN', 'NN', 'JJ', 'NN'],
#  'wewannour': ['VB'],
#  'whimsicality': ['NN'],
#  'whippers': ['NNS'],
#  'wifty': ['JJ'],
#  'wisegirls': ['NN'],
#  'witlessness': ['NN'],
#  'wizy': ['JJ'],
#  'wollter': ['NN', 'NN', 'NN', 'NN', 'NN', 'NN', 'NN'],
#  'wrackingly': ['RB'],
#  'zillionth': ['JJ'],
#  'zzzzzzzzz': ['NN'],
#  '\x9170s': ['NNP'],
#  '\x91direct': ['JJ'],
#  '\x91what': ['WP'],
#  '\x96': ['VBG',
#   'NNP',
#   'NN',
#   'NNP',
#   'VBP',
#   'NNP',
#   'NN',
#   'NNS',
#   'NN',
#   'VBN',
#   'VBZ',
#   'NNP',
#   'VBP',
#   'NNP',
#   'RP',
#   'RB',
#   'VBP',
#   'NNP',
#   'NN',
#   'VBZ',
#   'NNS',
#   'NN',
#   'NNP',
#   'NN',
#   'NNP',
#   'VBP'],
#  '\x97': ['VBP',
#   'NN',
#   'VBP',
#   'CC',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'VB',
#   'NN',
#   'VBP',
#   'NN',
#   'NN',
#   'NN'],
#  'às': ['NNP'],
#  'ápice': ['NNP'],
#  'ótimo': ['NNP'],
#  'últimos': ['JJ'],
#  'única': ['JJ']}

# %%
from nltk.corpus import wordnet as wn

pos_mapping_dict = {'NN':wn.NOUN,
              'JJ':wn.ADJ,
              'VB':wn.VERB,
              'RB':wn.ADV,
              # NLTK does not have wn.ADV_SAT
              }

# Convert oov_words_pos to wordnet POS
def map_pos_list(pos_list, mapping_dict):
    mapped_pos = []
    for pos in pos_list:
        # Find the first matching POS tag in mapping_dict by first letter comparison
        matched_pos = next((mapping_dict[key] for key in mapping_dict if key[0] == pos[0]), None)
        mapped_pos.append(matched_pos)
    return mapped_pos

# Creating the pos list
oov_words_pos_wordnet = {}
for key, pos_list in oov_words_pos.items():
    mapped_pos_list = map_pos_list(pos_list, pos_mapping_dict)
    
    # Remove None from list
    cleaned_list = [pos for pos in mapped_pos_list if pos is not None]
    
    # If all nones, remove whole entry
    if cleaned_list:
        oov_words_pos_wordnet[key] = cleaned_list
    

# Print the new dictionary
for key, value in oov_words_pos_wordnet.items():
    print(f"{key}: {value}")
# Out:
# abandone: ['n']
# aborbing: ['v']
# absolutamente: ['n']
# aburrido: ['n']
# acabamos: ['n']
# accomodates: ['v']
# aceitou: ['n']
# achival: ['a']
# achronological: ['n', 'a']
# acidically: ['r']
# acontecimentos: ['n']
# actorious: ['a']
# actorish: ['a']
# actory: ['a']
# actuada: ['n', 'a']
# addessi: ['n', 'r']
# adorability: ['n', 'n']
# adventues: ['n']
# affirmational: ['a']
# alientation: ['n', 'n']
# allodi: ['a', 'r']
# amoses: ['n', 'n']
# amusedly: ['r']
# andamento: ['n']
# animé: ['a', 'n']
# anteing: ['v']
# apallingly: ['r']
# apesar: ['n']
# aproveitar: ['n']
# aqueles: ['n']
# aren't: ['a']
# artnering: ['v']
# artsploitation: ['n']
# artístico: ['a']
# atacar: ['n']
# atacarse: ['a']
# atreve: ['v']
# auteil: ['n', 'a', 'n', 'n']
# autocritique: ['n']
# awakener: ['n']
# b+: ['n']
# bazadona: ['n', 'n']
# bergmanesque: ['a']
# beseechingly: ['r']
# bibbidy: ['n']
# bierbichler: ['n']
# birot: ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# bizzarre: ['a']
# bjorkness: ['n']
# blighter: ['n']
# blutarsky: ['n']
# bobbidi: ['n']
# bondish: ['a']
# bornin: ['n']
# bottomlessly: ['r']
# bruckheimeresque: ['a']
# brûlée: ['n', 'n']
# bull's: ['n']
# burningly: ['r']
# bustingly: ['r']
# butterfingered: ['v', 'v']
# cadness: ['n']
# cam'ron: ['n']
# camareras: ['n']
# cannier: ['a']
# captivatingly: ['r']
# capturou: ['n']
# carefreeness: ['n', 'n']
# carente: ['n']
# caricatural: ['a']
# cativante: ['n']
# certamente: ['n']
# chabrolian: ['a']
# chopsocky: ['a']
# choquart: ['n', 'n']
# cineasts: ['n']
# cinemantic: ['a']
# ciphered: ['a']
# cipherlike: ['n']
# cirulnick: ['n']
# claptraps: ['n']
# claustrophic: ['a']
# clericks: ['n']
# cletis: ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# clichês: ['n']
# clutchy: ['n']
# collinswood: ['n']
# collosum: ['n']
# colocar: ['n']
# colonics: ['n']
# colosal: ['n']
# começamos: ['v']
# compleja: ['n']
# complejos: ['n']
# complementares: ['n']
# condensada: ['n']
# confusedred: ['v']
# conmovedora: ['n']
# consegue: ['n', 'n']
# constatação: ['n']
# contando: ['n']
# continuação: ['n']
# contructed: ['a']
# contrária: ['n']
# convencional: ['n']
# copmovieland: ['n', 'n']
# coriat: ['n', 'n']
# corniest: ['a']
# corpse—stays: ['v']
# corruscating: ['v']
# costumey: ['n']
# covardia: ['n']
# crappola: ['n']
# creepyness: ['n']
# criar: ['n']
# crowdpleaser: ['n']
# crummles: ['n', 'n']
# csoka: ['n']
# culminando: ['n']
# daneses: ['n']
# datedness: ['n']
# dateflick: ['n']
# deadeningly: ['r']
# debuter: ['n']
# decasia: ['n', 'n']
# decidiram: ['a']
# decirles: ['v']
# defeatingly: ['r']
# delibrately: ['r']
# delicia: ['n']
# demencial: ['a']
# democracie: ['n']
# denlopp: ['v', 'n']
# derivativeness: ['n']
# desaponta: ['n']
# desarrollarse: ['n']
# desee: ['n']
# deseos: ['n']
# desfecho: ['n']
# desnudo: ['n']
# destinees: ['n']
# deutchland: ['v', 'v']
# diciness: ['n']
# diferença: ['n']
# digno: ['n']
# direto: ['n']
# diretor: ['n']
# direção: ['v', 'n']
# disfrutable: ['a']
# disposible: ['a']
# divertida: ['n', 'n', 'v', 'n']
# divertingly: ['r']
# djeinaba: ['a', 'n']
# document—its: ['n']
# dogwalker: ['n']
# dominatrixes: ['n', 'n']
# don't: ['r']
# dooper: ['n']
# dramatisms: ['n']
# dreadfulness: ['n']
# drecks: ['n']
# drek: ['n']
# dridi: ['n']
# drippiness: ['n']
# dudds: ['n']
# dudsville: ['a']
# dullingly: ['r']
# dumbfoundingly: ['r']
# duración: ['n']
# dysfunctionally: ['r']
# dès: ['n']
# efteriades: ['n']
# elegiacally: ['r']
# emocionante: ['n']
# emptily: ['r']
# enamoring: ['v']
# enfrentará: ['n']
# engaña: ['n']
# enrapturing: ['v']
# enternecedora: ['n']
# entretenida: ['n']
# entreter: ['n']
# então: ['a']
# enviará: ['n']
# episódio: ['n']
# equlibrium: ['n', 'n']
# eroti: ['n']
# escapa: ['n']
# esfera: ['a']
# esforço: ['n']
# espectáculo: ['a']
# espetáculo: ['v']
# espite: ['v']
# esquerdo: ['n']
# estafeta: ['v']
# estava: ['n']
# esteticamente: ['n']
# estranhos: ['n']
# estudo: ['n']
# estupendamente: ['n']
# everlyn: ['n']
# evolução: ['v']
# excrescence: ['n']
# exhilarate: ['n']
# existência: ['n']
# explicados: ['n']
# exporing: ['v']
# expresar: ['n']
# fabulosity: ['n']
# fantasti: ['a']
# fascinantes: ['n']
# fashionedness: ['n']
# fato: ['n', 'n']
# feardotcom: ['n', 'n', 'n', 'n', 'n', 'n']
# felinni: ['v', 'n']
# fillm: ['n']
# film—i: ['n']
# fizzability: ['n']
# flakeball: ['n']
# flatula: ['n', 'n']
# flck: ['v']
# fluxing: ['v']
# forgettably: ['r']
# francamente: ['n']
# frissons: ['n', 'n']
# frustrado: ['n']
# fuddled: ['v']
# fuhgeddaboutit: ['a']
# fun's: ['a']
# funcionar: ['n']
# fustily: ['r']
# fílmica: ['n']
# gabbiest: ['n']
# ganha: ['n']
# gantzes: ['a']
# gasm: ['n', 'n']
# gaï: ['n', 'n']
# gerbosi: ['n', 'n']
# glizty: ['n']
# gooeyness: ['v']
# goombah: ['n']
# gorefests: ['n']
# gosto: ['n']
# grandiosa: ['v']
# grato: ['n']
# graças: ['n']
# greaseballs: ['n']
# greasiest: ['a']
# guessable: ['a', 'a']
# guión: ['n']
# gutterball: ['n']
# gymkata: ['n', 'n']
# halfwit: ['n']
# hamfisted: ['a']
# hammily: ['r']
# hanewe: ['n']
# haphazardness: ['n']
# hastier: ['a']
# havia: ['n']
# headbangingly: ['r']
# heartwarmingly: ['r']
# hellfires: ['n']
# hellstenius: ['n', 'n']
# heremakono: ['n', 'n']
# higuchinsky: ['n', 'a']
# him.: ['n']
# hirosue: ['n']
# histo: ['n', 'n']
# hitchcockianism: ['n']
# hjelje: ['n', 'n']
# hobnail: ['a']
# hotdogging: ['v', 'v']
# hotsies: ['n', 'n']
# hubac: ['n', 'n']
# humbuggery: ['n']
# idemoto: ['n', 'n', 'n']
# idoosyncratic: ['a', 'a']
# igualmente: ['n']
# ihops: ['n']
# illogicality: ['n']
# imaginación: ['n']
# imponderably: ['r']
# impotentes: ['n']
# incoloro: ['n']
# incompetência: ['n']
# incomplacency: ['n']
# inconsequentiality: ['n']
# indieflick: ['n', 'n']
# inducingly: ['r']
# ineptitudes: ['n']
# infidèle: ['n']
# inhospitability: ['n']
# inhospitality: ['n']
# inquestionável: ['n']
# insipidity: ['n', 'n', 'n']
# instante: ['v']
# intacto: ['a']
# intelectualmente: ['n']
# intentando: ['n']
# interações: ['n']
# interspliced: ['v']
# involvingly: ['r']
# início: ['v']
# irretrievability: ['n']
# it's: ['n', 'a', 'n']
# italianas: ['v']
# italicizes: ['v', 'v']
# jaglomized: ['v']
# janklowicz: ['n', 'n', 'n']
# japanimator: ['n']
# jirí: ['n', 'n']
# jovovith: ['n']
# joylessly: ['r']
# juiceless: ['a']
# kahlories: ['n']
# kalesniko: ['n', 'n']
# kalvert: ['n', 'n']
# kaputschnik: ['n', 'n']
# kazmierski: ['n']
# kibbitzes: ['n']
# kickass: ['n']
# kidlets: ['n', 'n']
# komediant: ['n']
# kosashvili: ['v', 'a', 'n', 'v', 'v', 'n']
# koshashvili: ['n']
# laboriousness: ['n']
# landbound: ['n']
# lapdance: ['n']
# lappy: ['a']
# leatherbound: ['n']
# leplouff: ['n', 'n']
# lhe: ['n']
# likableness: ['n']
# logra: ['a']
# luvvies: ['n', 'n']
# lynchable: ['a']
# lástima: ['a']
# líquido: ['n', 'n']
# maelström: ['n']
# makmalbaf: ['n', 'n']
# manipulador: ['n']
# manqué: ['n']
# margolo: ['n', 'n']
# marveilleux: ['v']
# masterpeice: ['n']
# materalism: ['n']
# mcklusky: ['a', 'a']
# meaningness: ['n']
# meanspirited: ['v']
# mediocridade: ['n']
# melodramáticos: ['n']
# memória: ['n']
# mergulha: ['n']
# mesmos: ['n']
# minac: ['n', 'n']
# misacted: ['v']
# miscasts: ['n']
# moinoise: ['n']
# mollà: ['v']
# monkeyfun: ['n']
# montaje: ['a']
# montias: ['n', 'n', 'n']
# montied: ['v']
# mouglalis: ['n']
# movieif: ['n']
# movilizador: ['n']
# mullinski: ['n', 'n']
# murdery: ['n']
# musclefest: ['a', 'a']
# musicais: ['n']
# narcotized: ['a']
# narcotizing: ['n']
# naturedness: ['n']
# nebrida: ['n', 'n']
# nerfs: ['r']
# ninguém: ['a']
# ningún: ['n']
# nohe: ['a', 'n', 'a']
# nolden: ['a', 'a']
# nonchallenging: ['n']
# nonethnic: ['a']
# nrelentingly: ['r']
# nutjob: ['n']
# nuttgens: ['n', 'r']
# næs: ['a', 'a']
# obligada: ['n']
# obviation: ['n', 'n']
# oedederk: ['a', 'n']
# oedekark: ['a']
# ooky: ['a']
# originalidad: ['n']
# outgag: ['v']
# outing—the: ['n']
# outré: ['a']
# overemphatic: ['a']
# overmanipulative: ['a', 'a']
# overplotted: ['v']
# overstylized: ['a']
# ozpetek: ['n', 'a', 'n', 'a', 'n', 'n', 'a', 'r', 'a', 'n']
# oídos: ['n']
# patriotero: ['n']
# penotti: ['n', 'n']
# pentacal: ['a']
# perdona: ['v']
# perfervid: ['a']
# peroxidized: ['a']
# perseguição: ['n']
# personagens: ['n', 'n']
# petin: ['n', 'n']
# phonce: ['n']
# pianista: ['v']
# pincel: ['n']
# pisiewicz: ['n']
# pistoled: ['v']
# plaintiveness: ['n']
# playdough: ['n']
# plushies: ['n', 'n']
# pokepie: ['n']
# policiales: ['n']
# pollyana: ['n', 'n']
# possui: ['n']
# pouquíssimos: ['a']
# powaqqatsi: ['n', 'n']
# prechewed: ['v']
# preciosista: ['a']
# precisa: ['n']
# precollegiate: ['n']
# predecesora: ['n']
# predecible: ['a']
# prefeminist: ['n']
# prejuicios: ['n']
# premisa: ['n']
# premissa: ['n']
# preocupar: ['n']
# preocupe: ['n']
# prescinde: ['n']
# pretention: ['n']
# prewarned: ['v']
# profundamente: ['n', 'n']
# projeção: ['n']
# provocatuers: ['n']
# próprio: ['n']
# psychodramatics: ['n']
# pulpiness: ['n']
# puportedly: ['r']
# puréed: ['a']
# putain: ['n']
# puttingly: ['r']
# pérdida: ['n']
# péssima: ['n']
# qatsi: ['n', 'a']
# qutting: ['n']
# realidade: ['n']
# realshe: ['a']
# recoing: ['v']
# reconceptualize: ['v', 'v']
# recurre: ['v']
# reeboir: ['n', 'n']
# reeses: ['n']
# repartees: ['n']
# repellantly: ['r']
# rephrases: ['v']
# repulsively: ['r', 'r']
# responsável: ['n']
# resultan: ['n']
# retadora: ['n']
# retrata: ['n']
# revigorates: ['v']
# ricture: ['n']
# rintarô: ['n']
# roisterous: ['a']
# romething: ['v']
# románticas: ['a']
# roteirista: ['n', 'a']
# roteiro: ['n']
# runteldat: ['n', 'n', 'n']
# russos: ['n', 'n', 'n']
# ryanovich: ['n', 'n']
# rápidamente: ['a']
# s1m0ne: ['n', 'n']
# sailboaters: ['n']
# salaciously: ['r']
# sandlerian: ['a']
# sapes: ['n']
# sapid: ['a']
# sappier: ['a']
# sarcástica: ['n']
# satirizado: ['n']
# saído: ['n']
# saímos: ['n']
# scandalousness: ['n']
# schneidermeister: ['n']
# schweigh: ['a']
# scuzbag: ['n', 'n']
# seldahl: ['n', 'n', 'n', 'v', 'n', 'n', 'n', 'n']
# sequer: ['n']
# sermonize: ['v']
# shagster: ['n', 'n']
# shakesperean: ['a']
# shapable: ['a']
# shapelessly: ['r']
# shayamalan: ['v', 'v']
# sheerly: ['r', 'a']
# shimmeringly: ['r']
# shlockmeister: ['n']
# shmear: ['n', 'n']
# shoplifts: ['v']
# shrieky: ['a']
# silbersteins: ['n']
# sillified: ['v']
# sillyly: ['n']
# silléified: ['v']
# simbolizando: ['v']
# sinais: ['n']
# sincera: ['n']
# sitcomishly: ['a']
# siuation: ['n']
# skeeved: ['v']
# skippable: ['a']
# slappingly: ['r']
# slowtime: ['v']
# slummy: ['a']
# smashups: ['n']
# snazziness: ['n']
# snoots: ['n', 'n']
# soaringly: ['r']
# soberbio: ['n']
# sogginess: ['n']
# solondzian: ['a']
# sophomer: ['n']
# sophomoronic: ['a', 'a']
# sorprenderá: ['n']
# soul's: ['n']
# sparklingly: ['r']
# splatterfests: ['n', 'n']
# splittingly: ['r']
# spookies: ['n']
# squaddie: ['a']
# stagecrafts: ['n']
# stalk'n'slash: ['n']
# steinis: ['n']
# stoppingly: ['r']
# stortelling: ['n', 'n']
# strafings: ['n']
# strainingly: ['r']
# stuffiest: ['a']
# stultifyingly: ['r', 'r', 'r']
# stumblings: ['n']
# stuporously: ['r']
# substitutable: ['a', 'a']
# sumamente: ['a']
# superada: ['n']
# superficiale: ['n']
# superlarge: ['n']
# surehanded: ['a']
# surfacey: ['a']
# suspeito: ['n']
# suspenser: ['n']
# swashbuck: ['n']
# swordfights: ['n']
# sychowski: ['a', 'a']
# sytle: ['n']
# sánchezes: ['v']
# talancón: ['n']
# também: ['n', 'n', 'n']
# tardier: ['a']
# tearfulness: ['n']
# thekids: ['n']
# theorization: ['n']
# thesps: ['n']
# thons: ['n']
# time.: ['n']
# timewaster: ['n']
# toolbags: ['n']
# transfigures: ['n', 'v']
# transforma: ['n']
# travestite: ['a']
# travil: ['n']
# truncheoning: ['v']
# try—but: ['v']
# término: ['v']
# têm: ['n']
# uberviolence: ['n']
# unamusing: ['a']
# uncharismatically: ['r']
# uncinematic: ['a']
# unclassifiably: ['r']
# unconned: ['v']
# underdramatized: ['a']
# underinspired: ['a']
# unembarrassing: ['n']
# unemotive: ['a']
# unencouraging: ['a']
# unentertaining: ['a', 'a']
# unfakable: ['a']
# unforgivingly: ['r']
# unhibited: ['a']
# unimpressively: ['r']
# universos: ['n']
# unlaughable: ['a']
# unplundered: ['v', 'v']
# unrecommendable: ['a']
# unreligious: ['a']
# unsalvageability: ['n']
# unslick: ['a']
# unspeakables: ['n']
# unstyled: ['a']
# unsuspenseful: ['a']
# untugged: ['a']
# updatings: ['n']
# uplifter: ['n']
# utilizar: ['a']
# ventually: ['r']
# verete: ['a', 'n']
# versión: ['n']
# vidgame: ['n']
# villians: ['n']
# volletta: ['n']
# vulakoro: ['n']
# wankery: ['n']
# wanking: ['a']
# watstein: ['n', 'n', 'n', 'n']
# waydowntown: ['n', 'a', 'n', 'a', 'n', 'n', 'a', 'n']
# wewannour: ['v']
# whimsicality: ['n']
# whippers: ['n']
# wifty: ['a']
# wisegirls: ['n']
# witlessness: ['n']
# wizy: ['a']
# wollter: ['n', 'n', 'n', 'n', 'n', 'n', 'n']
# wrackingly: ['r']
# zillionth: ['a']
# zzzzzzzzz: ['n']
# 70s: ['n']
# direct: ['a']
# : ['v', 'n', 'n', 'n', 'v', 'n', 'n', 'n', 'n', 'v', 'v', 'n', 'v', 'n', 'r', 'r', 'v', 'n', 'n', 'v', 'n', 'n', 'n', 'n', 'n', 'v']
# : ['v', 'n', 'v', 'n', 'n', 'n', 'n', 'v', 'n', 'v', 'n', 'n', 'n']
# às: ['n']
# ápice: ['n']
# ótimo: ['n']
# últimos: ['a']
# única: ['a']

# %%
def find_substitute_wordnet_synonym(oov_word, oov_words_pos_wordnet):
    # Find synonyms for OOV words
    # Retrieve POS tags list
    try:
        pos_list = oov_words_pos_wordnet[oov_word]
    except KeyError:
        return None
    
    # Find number of unique pos, except None
    unique_pos = list(set(pos_list))
    # sort by count
    unique_pos.sort(key=lambda x: pos_list.count(x), reverse=True)
    
    # Loop thru each unique pos, try to find synonyms
    for possible_pos_tag in unique_pos:
        # Get synonyms
        for synset in wn.synsets(oov_word, pos=possible_pos_tag):
            for lemma in synset.lemmas():
                if lemma.name() in glove_embeddings:
                    print(f'OOV word: {oov_word}, synonym: {lemma.name()}')
                    return glove_embeddings[lemma.name()]

# %%
for oov_word in oov_words:
    synonym_glove_embedding = find_substitute_wordnet_synonym(oov_word, oov_words_pos_wordnet)
    if synonym_glove_embedding is not None:
        embedding_matrix[vocab_word_to_index[oov_word]] = synonym_glove_embedding
# Out:
# OOV word: juiceless, synonym: dry
# OOV word: shmear, synonym: schmear
# OOV word: perfervid, synonym: ardent
# OOV word: excrescence, synonym: bulge
# OOV word: stuffiest, synonym: airless
# OOV word: greasiest, synonym: greasy
# OOV word: fuddled, synonym: befuddle
# OOV word: corniest, synonym: corny

# %%
# Print remaining OOV words
oov_words = get_oov_words(embedding_matrix, vocab_word_to_index)

print(f"Number of OOV words left: {len(oov_words)}")
# Out:
# Number of OOV words left: 412

# %% [markdown]
# ## Pass 3: Use Edit Distance to solve misspelled OOV words

# %%
from Levenshtein import distance as lev

# Find most similar word for OOV word
def find_substitute_word_edit_dist(oov_word, glove_embeddings):
    # Set to infinity first
    min_dist = float('inf')
    closest_word = None
    
    # Loop thru all words in glove embeddings
    for word in glove_embeddings:
        # Calculate edit distance
        dist = lev(oov_word, word)
        
        # Update if new minimum distance found
        if dist < min_dist:
            min_dist = dist
            closest_word = word
            
    return closest_word, min_dist

# %%
min_dist_thresh = 1

for oov_word in oov_words:
    best_substitute_word, min_dist = find_substitute_word_edit_dist(oov_word, glove_embeddings)
    if min_dist <= min_dist_thresh:
        print(f'OOV word: {oov_word}, substitute word: {best_substitute_word}, Distance: {min_dist}')
        # Copy substitute word embedding to OOV word
        embedding_matrix[vocab_word_to_index[oov_word]] = glove_embeddings[best_substitute_word]
# Out:
# OOV word: shrieky, substitute word: shrieks, Distance: 1
# OOV word: fun's, substitute word: funds, Distance: 1
# OOV word: zillionth, substitute word: millionth, Distance: 1
# OOV word: mcklusky, substitute word: mcclusky, Distance: 1
# OOV word: bizzarre, substitute word: bizarre, Distance: 1
# OOV word: what, substitute word: what, Distance: 1
# OOV word: enviará, substitute word: enviar, Distance: 1
# OOV word: manipulador, substitute word: manipulator, Distance: 1
# OOV word: possui, substitute word: possum, Distance: 1
# OOV word: csoka, substitute word: cska, Distance: 1
# OOV word: pérdida, substitute word: perdida, Distance: 1
# OOV word: slowtime, substitute word: showtime, Distance: 1
# OOV word: adventues, substitute word: adventures, Distance: 1
# OOV word: retrata, substitute word: retrato, Distance: 1
# OOV word: delibrately, substitute word: deliberately, Distance: 1
# OOV word: time., substitute word: time, Distance: 1
# OOV word: espectáculo, substitute word: espectaculo, Distance: 1
# OOV word: skeeved, substitute word: sleeved, Distance: 1
# OOV word: sincera, substitute word: sincere, Distance: 1
# OOV word: wifty, substitute word: fifty, Distance: 1
# OOV word: corruscating, substitute word: coruscating, Distance: 1
# OOV word: 1975., substitute word: 1975, Distance: 1
# OOV word: artístico, substitute word: artística, Distance: 1
# OOV word: têm, substitute word: tom, Distance: 1
# OOV word: volletta, substitute word: valletta, Distance: 1
# OOV word: strafings, substitute word: strafing, Distance: 1
# OOV word: precisa, substitute word: precise, Distance: 1
# OOV word: narrativa, substitute word: narrative, Distance: 1
# OOV word: guión, substitute word: guinn, Distance: 1
# OOV word: kickass, substitute word: kick-ass, Distance: 1
# OOV word: hanewe, substitute word: haneke, Distance: 1
# OOV word: apesar, substitute word: pesar, Distance: 1
# OOV word: episódio, substitute word: episodio, Distance: 1
# OOV word: shakesperean, substitute word: shakespearean, Distance: 1
# OOV word: stortelling, substitute word: storytelling, Distance: 1
# OOV word: clericks, substitute word: clerics, Distance: 1
# OOV word: premisa, substitute word: premise, Distance: 1
# OOV word: montias, substitute word: montas, Distance: 1
# OOV word: cam'ron, substitute word: cameron, Distance: 1
# OOV word: mesmos, substitute word: memos, Distance: 1
# OOV word: emotiva, substitute word: emotive, Distance: 1
# OOV word: versión, substitute word: version, Distance: 1
# OOV word: 8217, substitute word: 217, Distance: 1
# OOV word: colosal, substitute word: colossal, Distance: 1
# OOV word: aren't, substitute word: arendt, Distance: 1
# OOV word: 5ths, substitute word: 5th, Distance: 1
# OOV word: leatherbound, substitute word: leather-bound, Distance: 1
# OOV word: gosto, substitute word: gusto, Distance: 1
# OOV word: aborbing, substitute word: absorbing, Distance: 1
# OOV word: oídos, substitute word: ordos, Distance: 1
# OOV word: næs, substitute word: nas, Distance: 1
# OOV word: schweigh, substitute word: schweich, Distance: 1
# OOV word: ourside, substitute word: outside, Distance: 1
# OOV word: ótimo, substitute word: timo, Distance: 1
# OOV word: nonethnic, substitute word: non-ethnic, Distance: 1
# OOV word: 1995., substitute word: 1995, Distance: 1
# OOV word: próprio, substitute word: proprio, Distance: 1
# OOV word: wollter, substitute word: wolter, Distance: 1
# OOV word: petin, substitute word: putin, Distance: 1
# OOV word: soul's, substitute word: souls, Distance: 1
# OOV word: maelström, substitute word: maelstrom, Distance: 1
# OOV word: shayamalan, substitute word: shyamalan, Distance: 1
# OOV word: às, substitute word: 's, Distance: 1
# OOV word: 1899., substitute word: 1899, Distance: 1
# OOV word: actuación, substitute word: actuacion, Distance: 1
# OOV word: auteil, substitute word: auteuil, Distance: 1
# OOV word: contando, substitute word: cantando, Distance: 1
# OOV word: bobbidi, substitute word: bobbili, Distance: 1
# OOV word: início, substitute word: inacio, Distance: 1
# OOV word: 1952., substitute word: 1952, Distance: 1
# OOV word: engaña, substitute word: engaño, Distance: 1
# OOV word: vidgame, substitute word: midgame, Distance: 1
# OOV word: murdery, substitute word: murder, Distance: 1
# OOV word: oedederk, substitute word: oedekerk, Distance: 1
# OOV word: graças, substitute word: graça, Distance: 1
# OOV word: 2002., substitute word: 2002, Distance: 1
# OOV word: cirulnick, substitute word: sirulnick, Distance: 1
# OOV word: , substitute word: ,, Distance: 1
# OOV word: espite, substitute word: despite, Distance: 1
# OOV word: minac, substitute word: minas, Distance: 1
# OOV word: memória, substitute word: memoria, Distance: 1
# OOV word: flck, substitute word: flock, Distance: 1
# OOV word: direto, substitute word: directo, Distance: 1
# OOV word: costumey, substitute word: costume, Distance: 1
# OOV word: animé, substitute word: anime, Distance: 1
# OOV word: perdona, substitute word: persona, Distance: 1
# OOV word: 28k, substitute word: 28, Distance: 1
# OOV word: putain, substitute word: putin, Distance: 1
# OOV word: unslick, substitute word: unstick, Distance: 1
# OOV word: collinswood, substitute word: collingwood, Distance: 1
# OOV word: crummles, substitute word: crumbles, Distance: 1
# OOV word: brûlée, substitute word: brûlé, Distance: 1
# OOV word: artnering, substitute word: partnering, Distance: 1
# OOV word: surfacey, substitute word: surface, Distance: 1
# OOV word: penotti, substitute word: menotti, Distance: 1
# OOV word: andamento, substitute word: mandamento, Distance: 1
# OOV word: italianas, substitute word: italians, Distance: 1
# OOV word: líquido, substitute word: liquido, Distance: 1
# OOV word: seldahl, substitute word: meldahl, Distance: 1
# OOV word: pianista, substitute word: pianist, Distance: 1
# OOV word: intacto, substitute word: intact, Distance: 1
# OOV word: bull's, substitute word: bulls, Distance: 1
# OOV word: equlibrium, substitute word: equilibrium, Distance: 1
# OOV word: pisiewicz, substitute word: misiewicz, Distance: 1
# OOV word: gutterball, substitute word: butterball, Distance: 1
# OOV word: drek, substitute word: drew, Distance: 1
# OOV word: travil, substitute word: travel, Distance: 1
# OOV word: collosum, substitute word: callosum, Distance: 1
# OOV word: gaï, substitute word: gas, Distance: 1
# OOV word: everlyn, substitute word: evelyn, Distance: 1
# OOV word: rápidamente, substitute word: rapidamente, Distance: 1
# OOV word: hubac, substitute word: huac, Distance: 1
# OOV word: oedekark, substitute word: oedekerk, Distance: 1
# OOV word: digno, substitute word: dino, Distance: 1
# OOV word: outré, substitute word: outro, Distance: 1
# OOV word: clichês, substitute word: cliches, Distance: 1
# OOV word: don't, substitute word: dont, Distance: 1
# OOV word: estava, substitute word: estaba, Distance: 1
# OOV word: dès, substitute word: des, Distance: 1
# OOV word: desnudo, substitute word: desnuda, Distance: 1
# OOV word: makmalbaf, substitute word: makhmalbaf, Distance: 1
# OOV word: ain't, substitute word: aint, Distance: 1
# OOV word: margolo, substitute word: margalo, Distance: 1
# OOV word: idemoto, substitute word: ikemoto, Distance: 1
# OOV word: diretor, substitute word: director, Distance: 1
# OOV word: hjelje, substitute word: hjelle, Distance: 1
# OOV word: histo, substitute word: hristo, Distance: 1
# OOV word: deutchland, substitute word: deutschland, Distance: 1
# OOV word: única, substitute word: unica, Distance: 1
# OOV word: término, substitute word: termino, Distance: 1
# OOV word: románticas, substitute word: romántica, Distance: 1
# OOV word: qatsi, substitute word: qaisi, Distance: 1
# OOV word: hirosue, substitute word: hirose, Distance: 1
# OOV word: saído, substitute word: sado, Distance: 1
# OOV word: film—i, substitute word: filmi, Distance: 1
# OOV word: b+, substitute word: by, Distance: 1
# OOV word: pollyana, substitute word: pollyanna, Distance: 1
# OOV word: rintarô, substitute word: rintaro, Distance: 1
# OOV word: divertida, substitute word: divertido, Distance: 1
# OOV word: meanspirited, substitute word: mean-spirited, Distance: 1
# OOV word: achronological, substitute word: chronological, Distance: 1
# OOV word: bornin, substitute word: bonin, Distance: 1
# OOV word: obligada, substitute word: obligado, Distance: 1
# OOV word: pincel, substitute word: pincer, Distance: 1
# OOV word: idoosyncratic, substitute word: idiosyncratic, Distance: 1
# OOV word: jirí, substitute word: jiri, Distance: 1
# OOV word: puportedly, substitute word: purportedly, Distance: 1
# OOV word: então, substitute word: antão, Distance: 1
# OOV word: direct, substitute word: direct, Distance: 1
# OOV word: lappy, substitute word: happy, Distance: 1
# OOV word: mollà, substitute word: molly, Distance: 1
# OOV word: romething, substitute word: something, Distance: 1
# OOV word: lhe, substitute word: the, Distance: 1
# OOV word: , substitute word: ,, Distance: 1
# OOV word: saímos, substitute word: samos, Distance: 1
# OOV word: unhibited, substitute word: inhibited, Distance: 1
# OOV word: amoses, substitute word: moses, Distance: 1
# OOV word: wizy, substitute word: wily, Distance: 1
# OOV word: nebrida, substitute word: nebria, Distance: 1
# OOV word: manqué, substitute word: manque, Distance: 1
# OOV word: ganha, substitute word: ganga, Distance: 1
# OOV word: jovovith, substitute word: jovovich, Distance: 1
# OOV word: scuzbag, substitute word: scumbag, Distance: 1
# OOV word: 70s, substitute word: '70s, Distance: 1
# OOV word: grato, substitute word: rato, Distance: 1
# OOV word: him., substitute word: him, Distance: 1
# OOV word: esfera, substitute word: espera, Distance: 1
# OOV word: it's, substitute word: its, Distance: 1
# OOV word: slummy, substitute word: plummy, Distance: 1
# OOV word: montaje, substitute word: montane, Distance: 1
# OOV word: existência, substitute word: existencia, Distance: 1
# OOV word: kalvert, substitute word: calvert, Distance: 1
# OOV word: ápice, substitute word: spice, Distance: 1
# OOV word: paródia, substitute word: parodia, Distance: 1
# OOV word: wankery, substitute word: wanker, Distance: 1
# OOV word: imaginación, substitute word: imaginacion, Distance: 1
# OOV word: ningún, substitute word: ningun, Distance: 1
# OOV word: ooky, substitute word: kooky, Distance: 1
# OOV word: sytle, substitute word: lytle, Distance: 1
# OOV word: clutchy, substitute word: clutch, Distance: 1
# OOV word: compleja, substitute word: complejo, Distance: 1
# OOV word: decirles, substitute word: deciles, Distance: 1
# OOV word: últimos, substitute word: último, Distance: 1

# %% [markdown]
# # Remaining OOV words

# %%
# Print remaining OOV words
oov_words = get_oov_words(embedding_matrix, vocab_word_to_index)

print(f"Number of OOV words left: {len(oov_words)}")
# Out:
# Number of OOV words left: 229

# %% [markdown]
# ## Pass 4: Split words into subwords and average their subword embeddings

# %%
# Move split point from left to right of the OOV word
def find_subword(oov_word, glove_embeddings):
    # Usually words dont go beyond 3 splits, but we only try 2 splits, 3 splits might lose too much meaning
    # Different meaning: slappingly -> slap ping ly
    for i in range(1, len(oov_word)):
        left = oov_word[:i]
        right = oov_word[i:]
        
        if left in glove_embeddings and right in glove_embeddings.keys() and wn.synsets(left) and wn.synsets(right):
            return left, right
        
    return None

# %%
for oov_word in oov_words:
    subwords_tup = find_subword(oov_word, glove_embeddings)
    if subwords_tup is not None:
        print(f'OOV word: {oov_word}, subwords: {subwords_tup}')
        embeddings = [glove_embeddings[subword] for subword in subwords_tup]
        avg_embeddings = np.mean(embeddings, axis=0)
        embedding_matrix[vocab_word_to_index[oov_word]] = avg_embeddings
# Out:
# OOV word: landbound, subwords: ('land', 'bound')
# OOV word: komediant, subwords: ('ko', 'mediant')
# OOV word: interspliced, subwords: ('inter', 'spliced')
# OOV word: wisegirls, subwords: ('wise', 'girls')
# OOV word: unencouraging, subwords: ('un', 'encouraging')
# OOV word: dogwalker, subwords: ('dog', 'walker')
# OOV word: overmanipulative, subwords: ('over', 'manipulative')
# OOV word: nutjob, subwords: ('nut', 'job')
# OOV word: waydowntown, subwords: ('way', 'downtown')
# OOV word: superada, subwords: ('super', 'ada')
# OOV word: decasia, subwords: ('dec', 'asia')
# OOV word: monkeyfun, subwords: ('monkey', 'fun')
# OOV word: incomplacency, subwords: ('in', 'complacency')
# OOV word: surehanded, subwords: ('sure', 'handed')
# OOV word: unconned, subwords: ('un', 'conned')
# OOV word: plushies, subwords: ('plush', 'ies')
# OOV word: swashbuck, subwords: ('swash', 'buck')
# OOV word: hobnail, subwords: ('hob', 'nail')
# OOV word: timewaster, subwords: ('time', 'waster')
# OOV word: pokepie, subwords: ('poke', 'pie')
# OOV word: mibii, subwords: ('mib', 'ii')
# OOV word: superlarge, subwords: ('super', 'large')
# OOV word: halfwit, subwords: ('half', 'wit')
# OOV word: assistir, subwords: ('assist', 'ir')
# OOV word: cipherlike, subwords: ('cipher', 'like')
# OOV word: humbuggery, subwords: ('hum', 'buggery')
# OOV word: overstylized, subwords: ('over', 'stylized')
# OOV word: underdramatized, subwords: ('under', 'dramatized')
# OOV word: confusedred, subwords: ('confused', 'red')
# OOV word: overemphatic, subwords: ('over', 'emphatic')
# OOV word: indieflick, subwords: ('indie', 'flick')
# OOV word: nonchallenging, subwords: ('non', 'challenging')
# OOV word: overplotted, subwords: ('over', 'plotted')
# OOV word: playdough, subwords: ('play', 'dough')
# OOV word: unreligious, subwords: ('un', 'religious')
# OOV word: japanimator, subwords: ('jap', 'animator')
# OOV word: unlaughable, subwords: ('un', 'laughable')
# OOV word: squaddie, subwords: ('squad', 'die')
# OOV word: flakeball, subwords: ('flake', 'ball')
# OOV word: crowdpleaser, subwords: ('crowd', 'pleaser')
# OOV word: autocritique, subwords: ('auto', 'critique')
# OOV word: unsuspenseful, subwords: ('un', 'suspenseful')
# OOV word: uncinematic, subwords: ('un', 'cinematic')
# OOV word: kidlets, subwords: ('kid', 'lets')
# OOV word: consegue, subwords: ('con', 'segue')
# OOV word: unplundered, subwords: ('un', 'plundered')
# OOV word: misacted, subwords: ('mis', 'acted')
# OOV word: unentertaining, subwords: ('un', 'entertaining')
# OOV word: outgag, subwords: ('out', 'gag')
# OOV word: untugged, subwords: ('un', 'tugged')
# OOV word: underinspired, subwords: ('under', 'inspired')
# OOV word: dateflick, subwords: ('date', 'flick')

# %% [markdown]
# # Remaining OOV words

# %%
# Print remaining OOV words
oov_words = get_oov_words(embedding_matrix, vocab_word_to_index)

print(f"Number of OOV words left: {len(oov_words)}")
# Out:
# Number of OOV words left: 177

# %%
oov_words
# Out:
# ['aburrido',
#  'evolução',
#  'heremakono',
#  'sophomoronic',
#  'bazadona',
#  'começamos',
#  'enfrentados',
#  'movilizador',
#  'addessi',
#  'contrária',
#  'janklowicz',
#  'direção',
#  'higuchinsky',
#  'dudsville',
#  'diferença',
#  'wewannour',
#  'bierbichler',
#  'pretenciosas',
#  'inquestionável',
#  'esteticamente',
#  'thekids',
#  'splatterfests',
#  'necessidade',
#  'preciosista',
#  'prechewed',
#  'orquídeas',
#  'strainingly',
#  'mediocridade',
#  'projeção',
#  'estafeta',
#  'schneidermeister',
#  'outing—the',
#  'koshashvili',
#  'artsploitation',
#  'splittingly',
#  'unrecommendable',
#  'entretenida',
#  'feardotcom',
#  'revigorates',
#  'desaponta',
#  'nuttgens',
#  'lástima',
#  'esforço',
#  'ryanovich',
#  'emocionante',
#  'silléified',
#  "stalk'n'slash",
#  'sorprenderá',
#  'blutarsky',
#  'moinoise',
#  'responsável',
#  'prejuicios',
#  'sychowski',
#  'unfakable',
#  'retadora',
#  'conmovedora',
#  'kaputschnik',
#  'talancón',
#  'profundamente',
#  'runteldat',
#  'prewarned',
#  'choquart',
#  'gabbiest',
#  'espetáculo',
#  'entreter',
#  'provocatuers',
#  'try—but',
#  'fabulosity',
#  'disfrutable',
#  'gerbosi',
#  'kosashvili',
#  'leplouff',
#  'pouquíssimos',
#  'frustrado',
#  'ninguém',
#  'incoloro',
#  'decidiram',
#  'aproveitar',
#  'explicados',
#  'shagster',
#  'glizty',
#  'suspeito',
#  'mergulha',
#  'camareras',
#  'melodramáticos',
#  'zzzzzzzzz',
#  'sarcástica',
#  'felinni',
#  'emocionalmente',
#  'copmovieland',
#  'mouglalis',
#  'prefeminist',
#  'kibbitzes',
#  'uberviolence',
#  'infidèle',
#  'desarrollarse',
#  'reeboir',
#  'precollegiate',
#  'masterpeice',
#  'watstein',
#  'kalesniko',
#  'fílmica',
#  'simbolizando',
#  'contemplarse',
#  'desfecho',
#  'movie\x97if',
#  'enfrentará',
#  'esquerdo',
#  'crappola',
#  'bergmanesque',
#  'capturou',
#  'gymkata',
#  'exibi',
#  'powaqqatsi',
#  'premissa',
#  'predecesora',
#  'marveilleux',
#  'aceitou',
#  'vulakoro',
#  'incompetência',
#  'atreve',
#  'mullinski',
#  'atacarse',
#  'certamente',
#  'constatação',
#  'roteiro',
#  'prescinde',
#  'satirizado',
#  'soberbio',
#  'kazmierski',
#  'utilizar',
#  'intentando',
#  'bruckheimeresque',
#  'originalidad',
#  'péssima',
#  'arriesgado',
#  'estranhos',
#  'sánchezes',
#  'acontecimentos',
#  'hellstenius',
#  'interações',
#  'claustrophic',
#  'denlopp',
#  'culminando',
#  'document—its',
#  'absolutamente',
#  'travestite',
#  'patriotero',
#  'fuhgeddaboutit',
#  'actuada',
#  'does—but',
#  'roteirista',
#  'predecible',
#  'bibbidy',
#  'real\x97she',
#  'representando',
#  'corpse—stays',
#  'efteriades',
#  'estupendamente',
#  'acabamos',
#  'djeinaba',
#  'enternecedora',
#  'duración',
#  'também',
#  'luvvies',
#  'perseguição',
#  'ozpetek',
#  'continuação',
#  's1m0ne',
#  'goombah',
#  'musclefest',
#  'shlockmeister',
#  'covardia',
#  'hamfisted',
#  'flatula',
#  'condensada',
#  'chopsocky']

# %% [markdown]
# ## Last pass: Replace OOV words with <UNK> token

# %%
# Get min max range of glove embeddings
all_embeddings = np.stack(list(glove_embeddings.values()))
min_val = np.min(all_embeddings)
max_val = np.max(all_embeddings)

print(f"min: {min_val}")
print(f"max: {max_val}")

mean_embedding = np.mean(all_embeddings)
std_embedding = np.std(all_embeddings)

print(f"Mean: {mean_embedding}, Standard Deviation: {std_embedding}")
# Out:
# min: -4.1831
# max: 4.2165
# Mean: -0.008671859820026773, Standard Deviation: 0.3818620572721229

# %%
unk_token = '<UNK>'
# Random embedding for <UNK> token
embedding_dim = 200
unk_embedding = np.random.uniform(-0.25, 0.25, embedding_dim)

# Assign <UNK> token embedding to OOV words
oov_words = get_oov_words(embedding_matrix, vocab_word_to_index)
for oov_word in oov_words:
    ## Use a single random embedding for all OOV words
    embedding_matrix[vocab_word_to_index[oov_word]] = unk_embedding
    ## Zero embedding
    # embedding_matrix[vocab_word_to_index[oov_word]] = np.zeros(embedding_dim)
    
# Add <UNK> token to vocab and embedding matrix
vocab_word_to_index[unk_token] = len(vocab)
embedding_matrix = np.vstack([embedding_matrix, unk_embedding])

# %%
# embedding_matrix[17841]

# %% [markdown]
# ## Alternative methods to test
# - semantic similarity with cosine similarity
# - use model to predict oov embeddings Mimick https://github.com/yuvalpinter/Mimick

# %% [markdown]
# # Finally, save embedding matrix and vocab_to_index mapping

# %%
import pickle


with open('augmented_embedding_matrix_200d.pkl', 'wb') as f:
    pickle.dump(embedding_matrix, f)
    
with open('augmented_vocab_word_to_index_200d.pkl', 'wb') as f:
    pickle.dump(vocab_word_to_index, f)
